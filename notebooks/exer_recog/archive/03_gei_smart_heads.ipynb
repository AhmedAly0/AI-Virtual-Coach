# %% [markdown]
# ## Architecture-Specific Head Designs (v3)
#
# ### Design Principles
#
# 1. **GlobalAveragePooling2D for all backbones**
#    - Better for spatially-aggregated GEI motion patterns
#    - More robust to position variations
#    - Smoother gradients → better convergence
#
# 2. **2-layer heads**
#    - More capacity than 1-layer universal head
#    - Less prone to overfitting than 3-layer complex heads
#
# 3. **Activation matching**
#    - EfficientNet: `swish` (native to EfficientNet design)
#    - ResNet/VGG/MobileNet: `relu` (standard, proven activation)
#
# 4. **Progressive dropout**
#    - Higher dropout in first Dense layer
#    - Lower dropout in second Dense layer
#    - Prevents overfitting while maintaining capacity
#
# 5. **Size scaling**
#    - Larger heads for deeper backbones (ResNet50: 1024→512)
#    - Smaller heads for efficient architectures (MobileNet: 256→128)
#
# ---
#
# ### Head Architectures
#
# **EfficientNet Family (B0, B2, B3):**
# ```
# GlobalAveragePooling2D
#     ↓
# Dense(512, activation='swish')
#     ↓
# BatchNormalization
#     ↓
# Dropout(0.3)
#     ↓
# Dense(256, activation='swish')
#     ↓
# Dropout(0.2)
#     ↓
# Dense(num_classes, activation='softmax')
# ```
# - **Rationale:** EfficientNet uses swish activation internally, BatchNorm for stability
# - **Capacity:** 512→256 sufficient for moderate-sized backbone
#
# **ResNet50:**
# ```
# GlobalAveragePooling2D
#     ↓
# Dense(1024, activation='relu')
#     ↓
# Dropout(0.4)
#     ↓
# Dense(512, activation='relu')
#     ↓
# Dropout(0.3)
#     ↓
# Dense(num_classes, activation='softmax')
# ```
# - **Rationale:** ResNet50 is deep (50 layers) → larger head capacity needed
# - **Capacity:** 1024→512 to match backbone complexity
#
# **VGG16:**
# ```
# GlobalAveragePooling2D
#     ↓
# Dense(512, activation='relu')
#     ↓
# Dropout(0.5)
#     ↓
# Dense(256, activation='relu')
#     ↓
# Dropout(0.4)
#     ↓
# Dense(num_classes, activation='softmax')
# ```
# - **Rationale:** VGG16 has simple architecture but many parameters → higher dropout
# - **Capacity:** 512→256 balanced for VGG's feature space
#
# **MobileNet Family (V2, V3-Large):**
# ```
# GlobalAveragePooling2D
#     ↓
# Dense(256, activation='relu')
#     ↓
# Dropout(0.25)
#     ↓
# Dense(128, activation='relu')
#     ↓
# Dropout(0.15)
#     ↓
# Dense(num_classes, activation='softmax')
# ```
# - **Rationale:** MobileNet is lightweight → smaller head maintains efficiency
# - **Capacity:** 256→128 matched to compact backbone
#
# ---

# %% [markdown]
# ## Training Strategy (3-Way Split with Validation Monitoring)
#
# ### Data Split (Subject-Independent)
# - **Training set (~55% of subjects)**: Used for model learning
# - **Validation set (~15% of subjects)**: Used for early stopping and learning rate scheduling
# - **Test set (~30% of subjects)**: Used ONLY for final evaluation (never seen during training)
#
# ✅ **No Data Leakage:** All samples from a subject stay in the same group (train/val/test)
#
# **Example:** If "Volunteer_18" is in the test set → ALL their samples (front view, side view, all exercises) remain in test set
#
# ### Phase 1: Frozen Backbone (up to 50 epochs)
# - All backbone layers frozen
# - Train only architecture-specific classification head
# - Learning rate: 0.001
# - **Callbacks:** EarlyStopping (patience=10), ReduceLROnPlateau, ModelCheckpoint
# - **Monitoring:** Validation loss (stops when validation stops improving)
#
# ### Phase 2: Full Fine-tuning (up to 100 epochs)
# - Unfreeze ALL layers (simple 100% unfreezing)
# - Learning rate: 0.0001 (10× reduction)
# - **Same callbacks** with validation monitoring
# - Allows backbone to adapt to GEI patterns
#
# ### Data Augmentation (Basic)
# - Horizontal flip: `True`
# - Translation: ±15% (height + width)
# - **No rotation/zoom/brightness** (keep it simple)
#
# ### Why This Approach?
#
# **Problem with no validation set:**
# - Model might overfit after epoch 30, but keeps training to epoch 60
# - Final weights could be worse than intermediate checkpoints
# - No way to know when to stop training
#
# **With validation monitoring:**
# - EarlyStopping saves best weights when validation loss stops improving
# - ReduceLROnPlateau reduces learning rate when stuck
# - Test accuracy becomes a TRUE unseen benchmark
#
# ### Evaluation Protocol
# - **5 runs per backbone** (quick validation phase)
# - Subject-independent 3-way split (55%/15%/30%)
# - Test set evaluated ONLY at the end (after all training completes)
# - Metrics: Training accuracy, validation accuracy, test accuracy, confusion matrix
# - **Success criteria (mean test accuracy across 5 runs):**
#   - Minimum: At least one backbone achieves **mean > 84%** (beats baseline 83.25%)
#   - Good: Best backbone achieves **mean > 86%** with **std < 2.5%**
#   - Excellent: Best backbone achieves **mean > 88%** with **std < 2%**
#
# ---

# %% [markdown]
# ## Setup: TensorFlow Configuration
#
# This cell configures TensorFlow to suppress warnings and enable GPU memory growth.
#
# **Key configurations:**
# - Suppress TensorFlow/CUDA warnings for cleaner output
# - Enable GPU memory growth (prevents out-of-memory errors)
# - Set logging levels to ERROR only

# %%
# CRITICAL: Run this cell FIRST before any other imports
# Suppress TensorFlow warnings at the OS level before TensorFlow loads
import os
import sys
import warnings
import io
import tensorflow as tf

# Set environment variables BEFORE TensorFlow is imported anywhere
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # 0=all, 1=filter INFO, 2=filter WARNING, 3=errors only
os.environ['AUTOGRAPH_VERBOSITY'] = '0'   # Disable AutoGraph conversion warnings

# Filter Python warnings
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)
warnings.filterwarnings('ignore', category=DeprecationWarning)

# Suppress absl logging (used by TensorFlow internally)
try:
    from absl import logging as absl_logging
    absl_logging.set_verbosity(absl_logging.ERROR)
except ImportError:
    pass

# Redirect stderr temporarily to suppress any remaining warnings during TF import
stderr_backup = sys.stderr
sys.stderr = io.StringIO()

# Restore stderr
sys.stderr = stderr_backup

# Final TensorFlow logging configuration
try:
    tf.get_logger().setLevel('ERROR')
    tf.autograph.set_verbosity(0)
except Exception:
    pass

# Enable GPU memory growth
try:
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
except Exception:
    pass

print("   TF_CPP_MIN_LOG_LEVEL:", os.environ.get('TF_CPP_MIN_LOG_LEVEL'))
print("   AUTOGRAPH_VERBOSITY:", os.environ.get('AUTOGRAPH_VERBOSITY'))
print("   TensorFlow version:", tf.__version__)
print("   GPUs detected:", len(tf.config.list_physical_devices('GPU')))
# Out:
# ✅ TensorFlow imported with all warnings suppressed
#    TF_CPP_MIN_LOG_LEVEL: 3
#    AUTOGRAPH_VERBOSITY: 0
#    TensorFlow version: 2.10.0
#    GPUs detected: 1

# %% [markdown]
# ## Import Modules
#
# **Key imports for Experiment 3:**
# - `build_model_for_backbone_v3` - New refined architecture-specific heads
# - `train_one_run` from `experiment_3` - Training script with v3 heads
# - Same data loading and utility functions as Experiment 1

# %%
# Standard libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import logging
import yaml
from tqdm import tqdm
from pathlib import Path
import sys

# Add project root to path
project_root = Path.cwd().parent.parent
sys.path.insert(0, str(project_root))

# Import project modules
from src.data import load_front_side_geis
from src.scripts.experiment_4 import train_experiment_4
from src.utils.io_utils import load_config
from src.utils import (
    set_global_seed,
    setup_results_folder_for_backbone,
    save_experiment_summary,
    get_all_model_parameters,
    load_backbone_results_with_config,
    create_comprehensive_comparison,
    generate_statistical_comparison,
)

root_logger = logging.getLogger()
if root_logger.hasHandlers():
    for handler in root_logger.handlers[:]:
        root_logger.removeHandler(handler)

logging.basicConfig(level=logging.WARNING, format='%(message)s')
logger = logging.getLogger(__name__)

print("✅ All modules imported successfully")
# Out:
# ✅ All modules imported successfully

# %%
# Load YAML configuration
config_path = project_root / 'config' / 'experiment_4.yaml'
config = load_config(str(config_path))

print("✅ Configuration loaded from:", config_path)
print("\nKey parameters:")
print(f"  Val ratio: {config['dataset']['val_ratio']}")
print(f"  Test ratio: {config['dataset']['test_ratio']}")
print(f"  Batch size: {config['training']['batch_size']}")
print(f"  Frozen epochs: {config['training']['frozen_epochs']}")
print(f"  Fine-tune epochs: {config['training']['fine_tune_epochs']}")

print("\nUnfreezing strategy (Phase 2):")
for backbone, params in config['unfreezing'].items():
    print(f"  {backbone}: {params['phase2_unfreeze_percent']*100:.0f}%")
# Out:
# ✅ Configuration loaded from: ../../config/experiment_3.yaml
#
# Key parameters:
#   Val ratio: 0.15
#   Test ratio: 0.3
#   Batch size: 32
#   Frozen epochs: 50
#   Fine-tune epochs: 100
#
# Unfreezing strategy (Phase 2):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 16
#      14 print("\nUnfreezing strategy (Phase 2):")
#      15 for backbone, params in config['unfreezing'].items():
# ---> 16     print(f"  {backbone}: {params['phase2_unfreeze_percent']*100:.0f}%")
#
# TypeError: string indices must be integers

# %% [markdown]
# ## Data Loading (Front + Side Views)

# %%
# Load datasets from shared helper
front_base_folder = str(project_root / 'datasets/GEIs_of_rgb_front/GEIs')
side_base_folder = str(project_root / 'datasets/GEIs_of_rgb_side/GEIs')

print(f"Loading GEIs from:\n  Front: {front_base_folder}\n  Side : {side_base_folder}")

dataset, dataset_summary = load_front_side_geis(
    front_base_folder=front_base_folder,
    side_base_folder=side_base_folder,
    seed=42,
    shuffle=True
)

print(f"Merged dataset size: {dataset_summary['total_count']} (front: {dataset_summary['front_count']}, side: {dataset_summary['side_count']})")

if dataset:
    sample_label, sample_img, sample_subject = dataset[0]
    print("Sample tuple structure: (label:str, image:np.ndarray[H,W], subject:str)")
    print(f"Types: {type(sample_label).__name__}, {sample_img.shape}, {type(sample_subject).__name__}")
# Out:
# Merged dataset size: 3142 (front: 1574, side: 1568)
# Sample tuple structure: (label:str, image:np.ndarray[H,W], subject:str) -> str (1280, 720) str

# %% [markdown]
# ## Training Execution (7 Backbones × 5 Runs)
#
# **What's different from Experiment 1:**
# - Uses `build_model_for_backbone_v3()` with architecture-specific heads
# - **Only 5 runs per backbone** (vs 10 in Experiment 1) for quick validation
# - Same 2-phase training strategy (frozen → full unfreeze)
# - **3-way subject split (55%/15%/30%)** - validation set for early stopping
# - **Higher max epochs** (50+100) but early stopping decides actual epochs
#
# **Expected duration:** ~5-10 minutes per backbone (early stopping reduces training time)
#
# **Total:** 7 backbones × 5 runs = 35 training runs (vs 70 in Experiment 1)
#
# ⚠️ **Note:** This cell will take 1-2 hours to complete all training runs!

# %%
# Configure training sweep
BACKBONES_TO_TEST = [
    'efficientnet_b0',
    'efficientnet_b2',
    'efficientnet_b3',
    'resnet50',
    'vgg16',
    'mobilenet_v2',
    'mobilenet_v3_large',
]
N_RUNS = 5

print("="*80)
print("EXPERIMENT 3: Smart Heads Pipeline (delegating to Experiment 4 trainer)")
print("="*80)
print(f"Backbones: {BACKBONES_TO_TEST}")
print(f"Runs per backbone: {N_RUNS}")
print(f"Total training runs: {len(BACKBONES_TO_TEST) * N_RUNS}")
print("="*80)

exp3_run_results = train_experiment_4(
    dataset=dataset,
    backbones=BACKBONES_TO_TEST,
    config_path=str(config_path),
    num_runs=N_RUNS
)

print("\n" + "="*80)
print("✅ TRAINING COMPLETE")
print("="*80)
print("Results saved to: experiments/exer_recog/results/exp_04_regularized/")
# Out:
# Backbones:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.6281 - accuracy: 0.8079
# Epoch 1: val_accuracy improved from -inf to 0.75452, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_000_frozen.keras
# 53/53 [==============================] - 14s 66ms/step - loss: 0.6281 - accuracy: 0.8079 - val_loss: 1.4250 - val_accuracy: 0.7545 - lr: 0.0010
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0757 - accuracy: 0.9767
# Epoch 2: val_accuracy did not improve from 0.75452
# 53/53 [==============================] - 2s 39ms/step - loss: 0.0757 - accuracy: 0.9767 - val_loss: 1.1320 - val_accuracy: 0.7442 - lr: 0.0010
# Epoch 3/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0421 - accuracy: 0.9896
# Epoch 3: val_accuracy did not improve from 0.75452
# 53/53 [==============================] - 2s 39ms/step - loss: 0.0415 - accuracy: 0.9899 - val_loss: 0.8337 - val_accuracy: 0.7364 - lr: 0.0010
# Epoch 4/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0241 - accuracy: 0.9951
# Epoch 4: val_accuracy improved from 0.75452 to 0.77261, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_000_frozen.keras
# 53/53 [==============================] - 2s 44ms/step - loss: 0.0238 - accuracy: 0.9952 - val_loss: 0.6570 - val_accuracy: 0.7726 - lr: 0.0010
# Epoch 5/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0223 - accuracy: 0.9926
# Epoch 5: val_accuracy did not improve from 0.77261
# 53/53 [==============================] - 2s 39ms/step - loss: 0.0220 - accuracy: 0.9928 - val_loss: 0.6843 - val_accuracy: 0.7649 - lr: 0.0010
# Epoch 6/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0182 - accuracy: 0.9957
# Epoch 6: val_accuracy improved from 0.77261 to 0.81654, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_000_frozen.keras
# 53/53 [==============================] - 2s 44ms/step - loss: 0.0181 - accuracy: 0.9958 - val_loss: 0.5063 - val_accuracy: 0.8165 - lr: 0.0010
# Epoch 7/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0169 - accuracy: 0.9975
# Epoch 7: val_accuracy did not improve from 0.81654
# 53/53 [==============================] - 2s 39ms/step - loss: 0.0168 - accuracy: 0.9976 - val_loss: 0.6298 - val_accuracy: 0.7674 - lr: 0.0010
# Epoch 8/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0204 - accuracy: 0.9939
# Epoch 8: val_accuracy did not improve from 0.81654
# 53/53 [==============================] - 2s 39ms/step - loss: 0.0199 - accuracy: 0.9940 - val_loss: 0.8301 - val_accuracy: 0.7209 - lr: 0.0010
# Epoch 9/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0203 - accuracy: 0.9939
# Epoch 9: val_accuracy did not improve from 0.81654
# 53/53 [==============================] - 2s 39ms/step - loss: 0.0199 - accuracy: 0.9940 - val_loss: 0.9736 - val_accuracy: 0.7261 - lr: 0.0010
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0296 - accuracy: 0.9911
# Epoch 10: val_accuracy did not improve from 0.81654
# 53/53 [==============================] - 2s 42ms/step - loss: 0.0296 - accuracy: 0.9911 - val_loss: 1.0806 - val_accuracy: 0.7442 - lr: 0.0010
# Epoch 11/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0432 - accuracy: 0.9884
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 11: val_accuracy did not improve from 0.81654
# 53/53 [==============================] - 2s 45ms/step - loss: 0.0430 - accuracy: 0.9881 - val_loss: 0.7770 - val_accuracy: 0.7881 - lr: 0.0010
# Epoch 12/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0145 - accuracy: 0.9957
# Epoch 12: val_accuracy did not improve from 0.81654
# 53/53 [==============================] - 2s 47ms/step - loss: 0.0141 - accuracy: 0.9958 - val_loss: 0.8455 - val_accuracy: 0.7907 - lr: 5.0000e-04
# Epoch 13/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0107 - accuracy: 0.9963
# Epoch 13: val_accuracy did not improve from 0.81654
# 53/53 [==============================] - 2s 46ms/step - loss: 0.0105 - accuracy: 0.9964 - val_loss: 0.6983 - val_accuracy: 0.8036 - lr: 5.0000e-04
# Epoch 14/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0117 - accuracy: 0.9975
# Epoch 14: val_accuracy did not improve from 0.81654
# 53/53 [==============================] - 2s 46ms/step - loss: 0.0114 - accuracy: 0.9976 - val_loss: 0.6425 - val_accuracy: 0.8036 - lr: 5.0000e-04
# Epoch 15/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0064 - accuracy: 0.9975
# Epoch 15: val_accuracy improved from 0.81654 to 0.82946, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_000_frozen.keras
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0066 - accuracy: 0.9976 - val_loss: 0.5326 - val_accuracy: 0.8295 - lr: 5.0000e-04
# Epoch 16/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0048 - accuracy: 0.9988Restoring model weights from the end of the best epoch: 6.
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 16: val_accuracy did not improve from 0.82946
# 53/53 [==============================] - 3s 48ms/step - loss: 0.0047 - accuracy: 0.9988 - val_loss: 0.5518 - val_accuracy: 0.8295 - lr: 5.0000e-04
# Epoch 16: early stopping
# Epoch 1/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0189 - accuracy: 0.9964
# Epoch 1: val_accuracy improved from -inf to 0.80620, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_000_fine.keras
# 53/53 [==============================] - 10s 85ms/step - loss: 0.0188 - accuracy: 0.9964 - val_loss: 0.5654 - val_accuracy: 0.8062 - lr: 1.0000e-04
# Epoch 2/100
# 53/53 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9982
# Epoch 2: val_accuracy did not improve from 0.80620
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.6466 - val_accuracy: 0.8062 - lr: 1.0000e-04
# Epoch 3/100
# 53/53 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 3: val_accuracy improved from 0.80620 to 0.81912, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_000_fine.keras
# 53/53 [==============================] - 3s 64ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.6108 - val_accuracy: 0.8191 - lr: 1.0000e-04
# Epoch 4/100
# 53/53 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9982
# Epoch 4: val_accuracy did not improve from 0.81912
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0054 - accuracy: 0.9982 - val_loss: 0.7649 - val_accuracy: 0.7442 - lr: 1.0000e-04
# Epoch 5/100
# 53/53 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9982
# Epoch 5: val_accuracy did not improve from 0.81912
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0115 - accuracy: 0.9982 - val_loss: 0.7144 - val_accuracy: 0.7778 - lr: 1.0000e-04
# Epoch 6/100
# 53/53 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9988
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 6: val_accuracy did not improve from 0.81912
# 53/53 [==============================] - 3s 58ms/step - loss: 0.0075 - accuracy: 0.9988 - val_loss: 0.9297 - val_accuracy: 0.7571 - lr: 1.0000e-04
# Epoch 7/100
# 53/53 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 7: val_accuracy did not improve from 0.81912
# 53/53 [==============================] - 3s 57ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.6172 - val_accuracy: 0.7984 - lr: 5.0000e-05
# Epoch 8/100
# 53/53 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 8: val_accuracy did not improve from 0.81912
# 53/53 [==============================] - 3s 62ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5493 - val_accuracy: 0.8062 - lr: 5.0000e-05
# Epoch 9/100
# 52/53 [============================>.] - ETA: 0s - loss: 9.4087e-04 - accuracy: 1.0000
# Epoch 9: val_accuracy improved from 0.81912 to 0.82171, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_000_fine.keras
# 53/53 [==============================] - 4s 67ms/step - loss: 9.4291e-04 - accuracy: 1.0000 - val_loss: 0.5001 - val_accuracy: 0.8217 - lr: 5.0000e-05
# Epoch 10/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9994
# Epoch 10: val_accuracy improved from 0.82171 to 0.82687, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_000_fine.keras
# 53/53 [==============================] - 4s 66ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.4888 - val_accuracy: 0.8269 - lr: 5.0000e-05
# Epoch 11/100
# 53/53 [==============================] - ETA: 0s - loss: 8.6361e-04 - accuracy: 1.0000
# Epoch 11: val_accuracy improved from 0.82687 to 0.83204, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_000_fine.keras
# 53/53 [==============================] - 4s 69ms/step - loss: 8.6361e-04 - accuracy: 1.0000 - val_loss: 0.4597 - val_accuracy: 0.8320 - lr: 5.0000e-05
# Epoch 12/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 12: val_accuracy did not improve from 0.83204
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5055 - val_accuracy: 0.8191 - lr: 5.0000e-05
# Epoch 13/100
# 53/53 [==============================] - ETA: 0s - loss: 6.9935e-04 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 0.83204
# 53/53 [==============================] - 3s 57ms/step - loss: 6.9935e-04 - accuracy: 1.0000 - val_loss: 0.5002 - val_accuracy: 0.8217 - lr: 5.0000e-05
# Epoch 14/100
# 53/53 [==============================] - ETA: 0s - loss: 5.3955e-04 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.83204
# 53/53 [==============================] - 3s 61ms/step - loss: 5.3955e-04 - accuracy: 1.0000 - val_loss: 0.4668 - val_accuracy: 0.8295 - lr: 5.0000e-05
# Epoch 15/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 15: val_accuracy improved from 0.83204 to 0.84755, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_000_fine.keras
# 53/53 [==============================] - 4s 67ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4427 - val_accuracy: 0.8475 - lr: 5.0000e-05
# Epoch 16/100
# 53/53 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 16: val_accuracy did not improve from 0.84755
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5624 - val_accuracy: 0.8243 - lr: 5.0000e-05
# Epoch 17/100
# 53/53 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9994
# Epoch 17: val_accuracy did not improve from 0.84755
# 53/53 [==============================] - 3s 60ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.5506 - val_accuracy: 0.8243 - lr: 5.0000e-05
# Epoch 18/100
# 53/53 [==============================] - ETA: 0s - loss: 6.1611e-04 - accuracy: 1.0000
# Epoch 18: val_accuracy improved from 0.84755 to 0.85530, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_000_fine.keras
# 53/53 [==============================] - 4s 67ms/step - loss: 6.1611e-04 - accuracy: 1.0000 - val_loss: 0.4689 - val_accuracy: 0.8553 - lr: 5.0000e-05
# Epoch 19/100
# 53/53 [==============================] - ETA: 0s - loss: 5.3132e-04 - accuracy: 1.0000
# Epoch 19: val_accuracy did not improve from 0.85530
# 53/53 [==============================] - 3s 59ms/step - loss: 5.3132e-04 - accuracy: 1.0000 - val_loss: 0.4555 - val_accuracy: 0.8501 - lr: 5.0000e-05
# Epoch 20/100
# 53/53 [==============================] - ETA: 0s - loss: 6.5770e-04 - accuracy: 1.0000
# Epoch 20: val_accuracy did not improve from 0.85530
# 53/53 [==============================] - 3s 62ms/step - loss: 6.5770e-04 - accuracy: 1.0000 - val_loss: 0.4363 - val_accuracy: 0.8501 - lr: 5.0000e-05
# Epoch 21/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9994
# Epoch 21: val_accuracy did not improve from 0.85530
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 0.7854 - val_accuracy: 0.8062 - lr: 5.0000e-05
# Epoch 22/100
# 53/53 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9994
# Epoch 22: val_accuracy did not improve from 0.85530
# 53/53 [==============================] - 3s 59ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.4891 - val_accuracy: 0.8295 - lr: 5.0000e-05
# Epoch 23/100
# 53/53 [==============================] - ETA: 0s - loss: 4.1849e-04 - accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 0.85530
# 53/53 [==============================] - 3s 62ms/step - loss: 4.1849e-04 - accuracy: 1.0000 - val_loss: 0.4661 - val_accuracy: 0.8295 - lr: 5.0000e-05
# Epoch 24/100
# 53/53 [==============================] - ETA: 0s - loss: 3.6326e-04 - accuracy: 1.0000
# Epoch 24: val_accuracy did not improve from 0.85530
# 53/53 [==============================] - 3s 61ms/step - loss: 3.6326e-04 - accuracy: 1.0000 - val_loss: 0.4892 - val_accuracy: 0.8320 - lr: 5.0000e-05
# Epoch 25/100
# 53/53 [==============================] - ETA: 0s - loss: 3.0138e-04 - accuracy: 1.0000
# Epoch 25: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 25: val_accuracy did not improve from 0.85530
# 53/53 [==============================] - 3s 59ms/step - loss: 3.0138e-04 - accuracy: 1.0000 - val_loss: 0.4801 - val_accuracy: 0.8320 - lr: 5.0000e-05
# Epoch 26/100
# 53/53 [==============================] - ETA: 0s - loss: 2.6459e-04 - accuracy: 1.0000
# Epoch 26: val_accuracy did not improve from 0.85530
# 53/53 [==============================] - 3s 61ms/step - loss: 2.6459e-04 - accuracy: 1.0000 - val_loss: 0.4805 - val_accuracy: 0.8372 - lr: 2.5000e-05
# Epoch 27/100
# 52/53 [============================>.] - ETA: 0s - loss: 5.3163e-04 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 0.85530
# 53/53 [==============================] - 3s 60ms/step - loss: 5.2961e-04 - accuracy: 1.0000 - val_loss: 0.4572 - val_accuracy: 0.8501 - lr: 2.5000e-05
# Epoch 28/100
# 53/53 [==============================] - ETA: 0s - loss: 5.1886e-04 - accuracy: 1.0000
# Epoch 28: val_accuracy improved from 0.85530 to 0.86047, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_000_fine.keras
# 53/53 [==============================] - 4s 67ms/step - loss: 5.1886e-04 - accuracy: 1.0000 - val_loss: 0.4382 - val_accuracy: 0.8605 - lr: 2.5000e-05
# Epoch 29/100
# 53/53 [==============================] - ETA: 0s - loss: 2.9902e-04 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 0.86047
# 53/53 [==============================] - 3s 61ms/step - loss: 2.9902e-04 - accuracy: 1.0000 - val_loss: 0.4534 - val_accuracy: 0.8475 - lr: 2.5000e-05
# Epoch 30/100
# 53/53 [==============================] - ETA: 0s - loss: 3.9808e-04 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 0.86047
# 53/53 [==============================] - 3s 61ms/step - loss: 3.9808e-04 - accuracy: 1.0000 - val_loss: 0.4310 - val_accuracy: 0.8527 - lr: 2.5000e-05
# Epoch 31/100
# 52/53 [============================>.] - ETA: 0s - loss: 3.5942e-04 - accuracy: 1.0000
# Epoch 31: val_accuracy did not improve from 0.86047
# 53/53 [==============================] - 3s 59ms/step - loss: 3.5738e-04 - accuracy: 1.0000 - val_loss: 0.4328 - val_accuracy: 0.8553 - lr: 2.5000e-05
# Epoch 32/100
# 53/53 [==============================] - ETA: 0s - loss: 2.7076e-04 - accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 0.86047
# 53/53 [==============================] - 3s 63ms/step - loss: 2.7076e-04 - accuracy: 1.0000 - val_loss: 0.4259 - val_accuracy: 0.8553 - lr: 2.5000e-05
# Epoch 33/100
# 53/53 [==============================] - ETA: 0s - loss: 1.5109e-04 - accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 0.86047
# 53/53 [==============================] - 3s 62ms/step - loss: 1.5109e-04 - accuracy: 1.0000 - val_loss: 0.4218 - val_accuracy: 0.8579 - lr: 2.5000e-05
# Epoch 34/100
# 53/53 [==============================] - ETA: 0s - loss: 2.4622e-04 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 0.86047
# 53/53 [==============================] - 3s 59ms/step - loss: 2.4622e-04 - accuracy: 1.0000 - val_loss: 0.4241 - val_accuracy: 0.8501 - lr: 2.5000e-05
# Epoch 35/100
# 52/53 [============================>.] - ETA: 0s - loss: 2.4879e-04 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 0.86047
# 53/53 [==============================] - 3s 60ms/step - loss: 2.4734e-04 - accuracy: 1.0000 - val_loss: 0.4301 - val_accuracy: 0.8501 - lr: 2.5000e-05
# Epoch 36/100
# 53/53 [==============================] - ETA: 0s - loss: 2.9682e-04 - accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 0.86047
# 53/53 [==============================] - 3s 60ms/step - loss: 2.9682e-04 - accuracy: 1.0000 - val_loss: 0.4360 - val_accuracy: 0.8527 - lr: 2.5000e-05
# Epoch 37/100
# 53/53 [==============================] - ETA: 0s - loss: 1.7028e-04 - accuracy: 1.0000
# Epoch 37: val_accuracy did not improve from 0.86047
# 53/53 [==============================] - 3s 59ms/step - loss: 1.7028e-04 - accuracy: 1.0000 - val_loss: 0.4334 - val_accuracy: 0.8553 - lr: 2.5000e-05
# Epoch 38/100
# 53/53 [==============================] - ETA: 0s - loss: 3.2521e-04 - accuracy: 1.0000
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 38: val_accuracy did not improve from 0.86047
# 53/53 [==============================] - 3s 60ms/step - loss: 3.2521e-04 - accuracy: 1.0000 - val_loss: 0.4325 - val_accuracy: 0.8501 - lr: 2.5000e-05
# Epoch 39/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9994
# Epoch 39: val_accuracy did not improve from 0.86047
# 53/53 [==============================] - 3s 61ms/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 0.4316 - val_accuracy: 0.8450 - lr: 1.2500e-05
# Epoch 40/100
# 53/53 [==============================] - ETA: 0s - loss: 2.1573e-04 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 0.86047
# 53/53 [==============================] - 3s 60ms/step - loss: 2.1573e-04 - accuracy: 1.0000 - val_loss: 0.4328 - val_accuracy: 0.8475 - lr: 1.2500e-05
# Epoch 41/100
# 52/53 [============================>.] - ETA: 0s - loss: 2.5139e-04 - accuracy: 1.0000
# Epoch 41: val_accuracy did not improve from 0.86047
# 53/53 [==============================] - 3s 60ms/step - loss: 2.5006e-04 - accuracy: 1.0000 - val_loss: 0.4369 - val_accuracy: 0.8475 - lr: 1.2500e-05
# Epoch 42/100
# 52/53 [============================>.] - ETA: 0s - loss: 2.9633e-04 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.86047
# 53/53 [==============================] - 3s 62ms/step - loss: 2.9610e-04 - accuracy: 1.0000 - val_loss: 0.4316 - val_accuracy: 0.8475 - lr: 1.2500e-05
# Epoch 43/100
# 53/53 [==============================] - ETA: 0s - loss: 2.0380e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 33.
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 43: val_accuracy did not improve from 0.86047
# 53/53 [==============================] - 3s 64ms/step - loss: 2.0380e-04 - accuracy: 1.0000 - val_loss: 0.4344 - val_accuracy: 0.8527 - lr: 1.2500e-05
# Epoch 43: early stopping
# Epoch 1/50
# 62/62 [==============================] - ETA: 0s - loss: 0.6860 - accuracy: 0.7802
# Epoch 1: val_accuracy improved from -inf to 0.65405, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_001_frozen.keras
# 62/62 [==============================] - 10s 75ms/step - loss: 0.6860 - accuracy: 0.7802 - val_loss: 1.4039 - val_accuracy: 0.6541 - lr: 0.0010
# Epoch 2/50
# 61/62 [============================>.] - ETA: 0s - loss: 0.0821 - accuracy: 0.9790
# Epoch 2: val_accuracy improved from 0.65405 to 0.70811, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_001_frozen.keras
# 62/62 [==============================] - 3s 50ms/step - loss: 0.0832 - accuracy: 0.9785 - val_loss: 1.0818 - val_accuracy: 0.7081 - lr: 0.0010
# Epoch 3/50
# 61/62 [============================>.] - ETA: 0s - loss: 0.0627 - accuracy: 0.9816
# Epoch 3: val_accuracy improved from 0.70811 to 0.71081, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_001_frozen.keras
# 62/62 [==============================] - 3s 56ms/step - loss: 0.0628 - accuracy: 0.9816 - val_loss: 0.9102 - val_accuracy: 0.7108 - lr: 0.0010
# Epoch 4/50
# 61/62 [============================>.] - ETA: 0s - loss: 0.0389 - accuracy: 0.9882
# Epoch 4: val_accuracy improved from 0.71081 to 0.72973, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_001_frozen.keras
# 62/62 [==============================] - 3s 49ms/step - loss: 0.0388 - accuracy: 0.9882 - val_loss: 0.8781 - val_accuracy: 0.7297 - lr: 0.0010
# Epoch 5/50
# 60/62 [============================>.] - ETA: 0s - loss: 0.0332 - accuracy: 0.9917
# Epoch 5: val_accuracy did not improve from 0.72973
# 62/62 [==============================] - 3s 44ms/step - loss: 0.0334 - accuracy: 0.9918 - val_loss: 1.0558 - val_accuracy: 0.6622 - lr: 0.0010
# Epoch 6/50
# 61/62 [============================>.] - ETA: 0s - loss: 0.0344 - accuracy: 0.9898
# Epoch 6: val_accuracy did not improve from 0.72973
# 62/62 [==============================] - 3s 44ms/step - loss: 0.0344 - accuracy: 0.9898 - val_loss: 1.2238 - val_accuracy: 0.6459 - lr: 0.0010
# Epoch 7/50
# 61/62 [============================>.] - ETA: 0s - loss: 0.0178 - accuracy: 0.9959
# Epoch 7: val_accuracy did not improve from 0.72973
# 62/62 [==============================] - 3s 44ms/step - loss: 0.0178 - accuracy: 0.9959 - val_loss: 1.2178 - val_accuracy: 0.6757 - lr: 0.0010
# Epoch 8/50
# 61/62 [============================>.] - ETA: 0s - loss: 0.0244 - accuracy: 0.9944
# Epoch 8: val_accuracy did not improve from 0.72973
# 62/62 [==============================] - 3s 45ms/step - loss: 0.0244 - accuracy: 0.9944 - val_loss: 1.3853 - val_accuracy: 0.6486 - lr: 0.0010
# Epoch 9/50
# 61/62 [============================>.] - ETA: 0s - loss: 0.0222 - accuracy: 0.9923
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 9: val_accuracy did not improve from 0.72973
# 62/62 [==============================] - 3s 45ms/step - loss: 0.0222 - accuracy: 0.9923 - val_loss: 1.4486 - val_accuracy: 0.6514 - lr: 0.0010
# Epoch 10/50
# 61/62 [============================>.] - ETA: 0s - loss: 0.0160 - accuracy: 0.9969
# Epoch 10: val_accuracy did not improve from 0.72973
# 62/62 [==============================] - 3s 44ms/step - loss: 0.0160 - accuracy: 0.9969 - val_loss: 1.4315 - val_accuracy: 0.6649 - lr: 5.0000e-04
# Epoch 11/50
# 62/62 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9980
# Epoch 11: val_accuracy did not improve from 0.72973
# 62/62 [==============================] - 3s 46ms/step - loss: 0.0085 - accuracy: 0.9980 - val_loss: 1.5238 - val_accuracy: 0.6541 - lr: 5.0000e-04
# Epoch 12/50
# 60/62 [============================>.] - ETA: 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 12: val_accuracy did not improve from 0.72973
# 62/62 [==============================] - 3s 45ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.4673 - val_accuracy: 0.6865 - lr: 5.0000e-04
# Epoch 13/50
# 61/62 [============================>.] - ETA: 0s - loss: 0.0087 - accuracy: 0.9954
# Epoch 13: val_accuracy did not improve from 0.72973
# 62/62 [==============================] - 3s 46ms/step - loss: 0.0087 - accuracy: 0.9954 - val_loss: 1.6409 - val_accuracy: 0.6514 - lr: 5.0000e-04
# Epoch 14/50
# 62/62 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9974Restoring model weights from the end of the best epoch: 4.
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 14: val_accuracy did not improve from 0.72973
# 62/62 [==============================] - 3s 47ms/step - loss: 0.0074 - accuracy: 0.9974 - val_loss: 1.4888 - val_accuracy: 0.6730 - lr: 5.0000e-04
# Epoch 14: early stopping
# Epoch 1/100
# 61/62 [============================>.] - ETA: 0s - loss: 0.0276 - accuracy: 0.9918
# Epoch 1: val_accuracy improved from -inf to 0.62703, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_001_fine.keras
# 62/62 [==============================] - 10s 85ms/step - loss: 0.0275 - accuracy: 0.9918 - val_loss: 0.9972 - val_accuracy: 0.6270 - lr: 1.0000e-04
# Epoch 2/100
# 61/62 [============================>.] - ETA: 0s - loss: 0.0068 - accuracy: 0.9990
# Epoch 2: val_accuracy improved from 0.62703 to 0.67568, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_001_fine.keras
# 62/62 [==============================] - 4s 62ms/step - loss: 0.0072 - accuracy: 0.9990 - val_loss: 1.0094 - val_accuracy: 0.6757 - lr: 1.0000e-04
# Epoch 3/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0163 - accuracy: 0.9959
# Epoch 3: val_accuracy did not improve from 0.67568
# 62/62 [==============================] - 4s 59ms/step - loss: 0.0163 - accuracy: 0.9959 - val_loss: 1.1342 - val_accuracy: 0.6649 - lr: 1.0000e-04
# Epoch 4/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9985
# Epoch 4: val_accuracy improved from 0.67568 to 0.68919, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_001_fine.keras
# 62/62 [==============================] - 4s 65ms/step - loss: 0.0061 - accuracy: 0.9985 - val_loss: 1.4188 - val_accuracy: 0.6892 - lr: 1.0000e-04
# Epoch 5/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 0.9974
# Epoch 5: val_accuracy did not improve from 0.68919
# 62/62 [==============================] - 4s 57ms/step - loss: 0.0099 - accuracy: 0.9974 - val_loss: 1.2198 - val_accuracy: 0.6757 - lr: 1.0000e-04
# Epoch 6/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9990
# Epoch 6: val_accuracy improved from 0.68919 to 0.72973, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_001_fine.keras
# 62/62 [==============================] - 4s 68ms/step - loss: 0.0074 - accuracy: 0.9990 - val_loss: 0.9221 - val_accuracy: 0.7297 - lr: 1.0000e-04
# Epoch 7/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9995
# Epoch 7: val_accuracy did not improve from 0.72973
# 62/62 [==============================] - 4s 58ms/step - loss: 0.0041 - accuracy: 0.9995 - val_loss: 1.3212 - val_accuracy: 0.6946 - lr: 1.0000e-04
# Epoch 8/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9964
# Epoch 8: val_accuracy did not improve from 0.72973
# 62/62 [==============================] - 4s 59ms/step - loss: 0.0094 - accuracy: 0.9964 - val_loss: 1.2288 - val_accuracy: 0.7000 - lr: 1.0000e-04
# Epoch 9/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9995
# Epoch 9: val_accuracy did not improve from 0.72973
# 62/62 [==============================] - 4s 58ms/step - loss: 0.0032 - accuracy: 0.9995 - val_loss: 1.1220 - val_accuracy: 0.7216 - lr: 1.0000e-04
# Epoch 10/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 10: val_accuracy did not improve from 0.72973
# 62/62 [==============================] - 4s 57ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.3025 - val_accuracy: 0.7081 - lr: 1.0000e-04
# Epoch 11/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 11: val_accuracy did not improve from 0.72973
# 62/62 [==============================] - 4s 59ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.4391 - val_accuracy: 0.6838 - lr: 1.0000e-04
# Epoch 12/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 12: val_accuracy did not improve from 0.72973
# 62/62 [==============================] - 4s 58ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.5016 - val_accuracy: 0.6757 - lr: 5.0000e-05
# Epoch 13/100
# 62/62 [==============================] - ETA: 0s - loss: 7.2844e-04 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 0.72973
# 62/62 [==============================] - 4s 57ms/step - loss: 7.2844e-04 - accuracy: 1.0000 - val_loss: 1.4520 - val_accuracy: 0.6838 - lr: 5.0000e-05
# Epoch 14/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9995
# Epoch 14: val_accuracy did not improve from 0.72973
# 62/62 [==============================] - 3s 56ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 1.3881 - val_accuracy: 0.6784 - lr: 5.0000e-05
# Epoch 15/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9995
# Epoch 15: val_accuracy did not improve from 0.72973
# 62/62 [==============================] - 4s 58ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 1.4656 - val_accuracy: 0.6811 - lr: 5.0000e-05
# Epoch 16/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 6.
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 16: val_accuracy did not improve from 0.72973
# 62/62 [==============================] - 4s 58ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.4205 - val_accuracy: 0.7027 - lr: 5.0000e-05
# Epoch 16: early stopping
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.7150 - accuracy: 0.7780
# Epoch 1: val_accuracy improved from -inf to 0.58858, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_002_frozen.keras
# 53/53 [==============================] - 10s 85ms/step - loss: 0.7150 - accuracy: 0.7780 - val_loss: 1.5793 - val_accuracy: 0.5886 - lr: 0.0010
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0933 - accuracy: 0.9763
# Epoch 2: val_accuracy improved from 0.58858 to 0.76575, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_002_frozen.keras
# 53/53 [==============================] - 3s 56ms/step - loss: 0.0933 - accuracy: 0.9763 - val_loss: 1.1300 - val_accuracy: 0.7657 - lr: 0.0010
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0473 - accuracy: 0.9905
# Epoch 3: val_accuracy did not improve from 0.76575
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0473 - accuracy: 0.9905 - val_loss: 0.9576 - val_accuracy: 0.7106 - lr: 0.0010
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0301 - accuracy: 0.9898
# Epoch 4: val_accuracy did not improve from 0.76575
# 53/53 [==============================] - 3s 51ms/step - loss: 0.0297 - accuracy: 0.9899 - val_loss: 0.7740 - val_accuracy: 0.7520 - lr: 0.0010
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9964
# Epoch 5: val_accuracy did not improve from 0.76575
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0176 - accuracy: 0.9964 - val_loss: 0.7273 - val_accuracy: 0.7598 - lr: 0.0010
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0090 - accuracy: 0.9994
# Epoch 6: val_accuracy did not improve from 0.76575
# 53/53 [==============================] - 3s 48ms/step - loss: 0.0090 - accuracy: 0.9994 - val_loss: 0.7950 - val_accuracy: 0.7618 - lr: 0.0010
# Epoch 7/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0194 - accuracy: 0.9951
# Epoch 7: val_accuracy did not improve from 0.76575
# 53/53 [==============================] - 3s 49ms/step - loss: 0.0197 - accuracy: 0.9947 - val_loss: 0.8151 - val_accuracy: 0.7283 - lr: 0.0010
# Epoch 8/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0252 - accuracy: 0.9940
# Epoch 8: val_accuracy did not improve from 0.76575
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0248 - accuracy: 0.9941 - val_loss: 0.9113 - val_accuracy: 0.7362 - lr: 0.0010
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 0.9947
# Epoch 9: val_accuracy did not improve from 0.76575
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0231 - accuracy: 0.9947 - val_loss: 0.8932 - val_accuracy: 0.7500 - lr: 0.0010
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9959
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 10: val_accuracy did not improve from 0.76575
# 53/53 [==============================] - 3s 49ms/step - loss: 0.0156 - accuracy: 0.9959 - val_loss: 1.3303 - val_accuracy: 0.7165 - lr: 0.0010
# Epoch 11/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0117 - accuracy: 0.9946
# Epoch 11: val_accuracy improved from 0.76575 to 0.80512, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_002_frozen.keras
# 53/53 [==============================] - 3s 54ms/step - loss: 0.0116 - accuracy: 0.9947 - val_loss: 0.8121 - val_accuracy: 0.8051 - lr: 5.0000e-04
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9976
# Epoch 12: val_accuracy did not improve from 0.80512
# 53/53 [==============================] - 3s 48ms/step - loss: 0.0093 - accuracy: 0.9976 - val_loss: 1.0049 - val_accuracy: 0.7815 - lr: 5.0000e-04
# Epoch 13/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0064 - accuracy: 0.9988
# Epoch 13: val_accuracy did not improve from 0.80512
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0063 - accuracy: 0.9988 - val_loss: 1.0745 - val_accuracy: 0.7992 - lr: 5.0000e-04
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9994
# Epoch 14: val_accuracy did not improve from 0.80512
# 53/53 [==============================] - 3s 50ms/step - loss: 0.0041 - accuracy: 0.9994 - val_loss: 1.0384 - val_accuracy: 0.7933 - lr: 5.0000e-04
# Epoch 15/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0056 - accuracy: 0.9975Restoring model weights from the end of the best epoch: 5.
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 15: val_accuracy did not improve from 0.80512
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0060 - accuracy: 0.9976 - val_loss: 1.1402 - val_accuracy: 0.7717 - lr: 5.0000e-04
# Epoch 15: early stopping
# Epoch 1/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0260 - accuracy: 0.9922
# Epoch 1: val_accuracy improved from -inf to 0.74606, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_002_fine.keras
# 53/53 [==============================] - 13s 98ms/step - loss: 0.0267 - accuracy: 0.9917 - val_loss: 0.8815 - val_accuracy: 0.7461 - lr: 1.0000e-04
# Epoch 2/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0112 - accuracy: 0.9958
# Epoch 2: val_accuracy improved from 0.74606 to 0.76378, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_002_fine.keras
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0111 - accuracy: 0.9959 - val_loss: 0.9044 - val_accuracy: 0.7638 - lr: 1.0000e-04
# Epoch 3/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0047 - accuracy: 0.9994
# Epoch 3: val_accuracy improved from 0.76378 to 0.77559, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_002_fine.keras
# 53/53 [==============================] - 4s 69ms/step - loss: 0.0046 - accuracy: 0.9994 - val_loss: 0.8983 - val_accuracy: 0.7756 - lr: 1.0000e-04
# Epoch 4/100
# 53/53 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 4: val_accuracy improved from 0.77559 to 0.79921, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_002_fine.keras
# 53/53 [==============================] - 4s 73ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.8762 - val_accuracy: 0.7992 - lr: 1.0000e-04
# Epoch 5/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0046 - accuracy: 0.9988
# Epoch 5: val_accuracy improved from 0.79921 to 0.81299, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_002_fine.keras
# 53/53 [==============================] - 4s 70ms/step - loss: 0.0046 - accuracy: 0.9988 - val_loss: 1.0246 - val_accuracy: 0.8130 - lr: 1.0000e-04
# Epoch 6/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 6: val_accuracy did not improve from 0.81299
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.8981 - val_accuracy: 0.7736 - lr: 1.0000e-04
# Epoch 7/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0053 - accuracy: 0.9988
# Epoch 7: val_accuracy did not improve from 0.81299
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0053 - accuracy: 0.9988 - val_loss: 0.9005 - val_accuracy: 0.7972 - lr: 1.0000e-04
# Epoch 8/100
# 53/53 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 8: val_accuracy did not improve from 0.81299
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.9185 - val_accuracy: 0.7815 - lr: 1.0000e-04
# Epoch 9/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0026 - accuracy: 0.9988
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 9: val_accuracy did not improve from 0.81299
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0025 - accuracy: 0.9988 - val_loss: 0.9715 - val_accuracy: 0.7874 - lr: 1.0000e-04
# Epoch 10/100
# 53/53 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 10: val_accuracy did not improve from 0.81299
# 53/53 [==============================] - 3s 63ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.0377 - val_accuracy: 0.7953 - lr: 5.0000e-05
# Epoch 11/100
# 52/53 [============================>.] - ETA: 0s - loss: 8.6898e-04 - accuracy: 1.0000
# Epoch 11: val_accuracy did not improve from 0.81299
# 53/53 [==============================] - 3s 64ms/step - loss: 8.6094e-04 - accuracy: 1.0000 - val_loss: 1.0171 - val_accuracy: 0.8012 - lr: 5.0000e-05
# Epoch 12/100
# 52/53 [============================>.] - ETA: 0s - loss: 6.9088e-04 - accuracy: 1.0000
# Epoch 12: val_accuracy did not improve from 0.81299
# 53/53 [==============================] - 3s 61ms/step - loss: 6.9460e-04 - accuracy: 1.0000 - val_loss: 1.0087 - val_accuracy: 0.8051 - lr: 5.0000e-05
# Epoch 13/100
# 53/53 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 13: val_accuracy improved from 0.81299 to 0.81890, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_002_fine.keras
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.9861 - val_accuracy: 0.8189 - lr: 5.0000e-05
# Epoch 14/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 4.
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 14: val_accuracy improved from 0.81890 to 0.82087, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_002_fine.keras
# 53/53 [==============================] - 4s 72ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.9950 - val_accuracy: 0.8209 - lr: 5.0000e-05
# Epoch 14: early stopping
# Epoch 1/50
# 57/57 [==============================] - ETA: 0s - loss: 0.6560 - accuracy: 0.8040
# Epoch 1: val_accuracy improved from -inf to 0.62445, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_003_frozen.keras
# 57/57 [==============================] - 12s 95ms/step - loss: 0.6560 - accuracy: 0.8040 - val_loss: 1.5146 - val_accuracy: 0.6245 - lr: 0.0010
# Epoch 2/50
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0996 - accuracy: 0.9705
# Epoch 2: val_accuracy improved from 0.62445 to 0.68122, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_003_frozen.keras
# 57/57 [==============================] - 3s 54ms/step - loss: 0.1000 - accuracy: 0.9695 - val_loss: 1.1760 - val_accuracy: 0.6812 - lr: 0.0010
# Epoch 3/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0543 - accuracy: 0.9856
# Epoch 3: val_accuracy improved from 0.68122 to 0.78603, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_003_frozen.keras
# 57/57 [==============================] - 3s 57ms/step - loss: 0.0543 - accuracy: 0.9856 - val_loss: 0.8390 - val_accuracy: 0.7860 - lr: 0.0010
# Epoch 4/50
# 57/57 [==============================] - ETA: 0s - loss: 0.0631 - accuracy: 0.9828
# Epoch 4: val_accuracy did not improve from 0.78603
# 57/57 [==============================] - 3s 48ms/step - loss: 0.0631 - accuracy: 0.9828 - val_loss: 0.7989 - val_accuracy: 0.7773 - lr: 0.0010
# Epoch 5/50
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0295 - accuracy: 0.9920
# Epoch 5: val_accuracy improved from 0.78603 to 0.80349, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_003_frozen.keras
# 57/57 [==============================] - 3s 55ms/step - loss: 0.0295 - accuracy: 0.9922 - val_loss: 0.5959 - val_accuracy: 0.8035 - lr: 0.0010
# Epoch 6/50
# 56/57 [============================>.] - ETA: 0s - loss: 0.0209 - accuracy: 0.9927
# Epoch 6: val_accuracy improved from 0.80349 to 0.81878, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_003_frozen.keras
# 57/57 [==============================] - 3s 56ms/step - loss: 0.0210 - accuracy: 0.9928 - val_loss: 0.5786 - val_accuracy: 0.8188 - lr: 0.0010
# Epoch 7/50
# 56/57 [============================>.] - ETA: 0s - loss: 0.0249 - accuracy: 0.9916
# Epoch 7: val_accuracy did not improve from 0.81878
# 57/57 [==============================] - 3s 47ms/step - loss: 0.0254 - accuracy: 0.9917 - val_loss: 0.6665 - val_accuracy: 0.7926 - lr: 0.0010
# Epoch 8/50
# 56/57 [============================>.] - ETA: 0s - loss: 0.0257 - accuracy: 0.9927
# Epoch 8: val_accuracy did not improve from 0.81878
# 57/57 [==============================] - 3s 47ms/step - loss: 0.0261 - accuracy: 0.9928 - val_loss: 0.8567 - val_accuracy: 0.7817 - lr: 0.0010
# Epoch 9/50
# 56/57 [============================>.] - ETA: 0s - loss: 0.0211 - accuracy: 0.9939
# Epoch 9: val_accuracy did not improve from 0.81878
# 57/57 [==============================] - 3s 47ms/step - loss: 0.0212 - accuracy: 0.9939 - val_loss: 0.6982 - val_accuracy: 0.8079 - lr: 0.0010
# Epoch 10/50
# 56/57 [============================>.] - ETA: 0s - loss: 0.0278 - accuracy: 0.9939
# Epoch 10: val_accuracy did not improve from 0.81878
# 57/57 [==============================] - 3s 47ms/step - loss: 0.0276 - accuracy: 0.9939 - val_loss: 0.9904 - val_accuracy: 0.7467 - lr: 0.0010
# Epoch 11/50
# 56/57 [============================>.] - ETA: 0s - loss: 0.0333 - accuracy: 0.9927
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 11: val_accuracy did not improve from 0.81878
# 57/57 [==============================] - 3s 47ms/step - loss: 0.0331 - accuracy: 0.9928 - val_loss: 1.0687 - val_accuracy: 0.7620 - lr: 0.0010
# Epoch 12/50
# 56/57 [============================>.] - ETA: 0s - loss: 0.0112 - accuracy: 0.9972
# Epoch 12: val_accuracy did not improve from 0.81878
# 57/57 [==============================] - 3s 46ms/step - loss: 0.0118 - accuracy: 0.9967 - val_loss: 0.7601 - val_accuracy: 0.7948 - lr: 5.0000e-04
# Epoch 13/50
# 56/57 [============================>.] - ETA: 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 13: val_accuracy improved from 0.81878 to 0.83624, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_003_frozen.keras
# 57/57 [==============================] - 3s 54ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.6569 - val_accuracy: 0.8362 - lr: 5.0000e-04
# Epoch 14/50
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0056 - accuracy: 0.9983
# Epoch 14: val_accuracy improved from 0.83624 to 0.85153, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_003_frozen.keras
# 57/57 [==============================] - 3s 53ms/step - loss: 0.0057 - accuracy: 0.9983 - val_loss: 0.5938 - val_accuracy: 0.8515 - lr: 5.0000e-04
# Epoch 15/50
# 56/57 [============================>.] - ETA: 0s - loss: 0.0071 - accuracy: 0.9978
# Epoch 15: val_accuracy did not improve from 0.85153
# 57/57 [==============================] - 3s 46ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.5800 - val_accuracy: 0.8253 - lr: 5.0000e-04
# Epoch 16/50
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0039 - accuracy: 0.9994Restoring model weights from the end of the best epoch: 6.
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 16: val_accuracy improved from 0.85153 to 0.85371, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_003_frozen.keras
# 57/57 [==============================] - 4s 65ms/step - loss: 0.0038 - accuracy: 0.9994 - val_loss: 0.6267 - val_accuracy: 0.8537 - lr: 5.0000e-04
# Epoch 16: early stopping
# Epoch 1/100
# 57/57 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9956
# Epoch 1: val_accuracy improved from -inf to 0.79039, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_003_fine.keras
# 57/57 [==============================] - 11s 91ms/step - loss: 0.0165 - accuracy: 0.9956 - val_loss: 0.6589 - val_accuracy: 0.7904 - lr: 1.0000e-04
# Epoch 2/100
# 57/57 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9978
# Epoch 2: val_accuracy improved from 0.79039 to 0.85371, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\efficientnet_b0\run_000_20251119_155602\checkpoints\run_003_fine.keras
# 57/57 [==============================] - 4s 68ms/step - loss: 0.0079 - accuracy: 0.9978 - val_loss: 0.4679 - val_accuracy: 0.8537 - lr: 1.0000e-04
# Epoch 3/100
# 57/57 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9972
# ...
#
# Epoch 21: val_accuracy did not improve from 0.79466
# 53/53 [==============================] - 2s 42ms/step - loss: 0.0125 - accuracy: 0.9976 - val_loss: 1.0788 - val_accuracy: 0.7639 - lr: 5.0000e-04
# Epoch 22/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9976
# Epoch 22: val_accuracy did not improve from 0.79466
# 53/53 [==============================] - 2s 41ms/step - loss: 0.0119 - accuracy: 0.9976 - val_loss: 0.9187 - val_accuracy: 0.7906 - lr: 2.5000e-04
# Epoch 23/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0091 - accuracy: 0.9988
# Epoch 23: val_accuracy did not improve from 0.79466
# 53/53 [==============================] - 2s 42ms/step - loss: 0.0091 - accuracy: 0.9988 - val_loss: 0.9799 - val_accuracy: 0.7762 - lr: 2.5000e-04
# Epoch 24/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9988
# Epoch 24: val_accuracy did not improve from 0.79466
# 53/53 [==============================] - 2s 42ms/step - loss: 0.0078 - accuracy: 0.9988 - val_loss: 0.9944 - val_accuracy: 0.7741 - lr: 2.5000e-04
# Epoch 25/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0071 - accuracy: 0.9988
# Epoch 25: val_accuracy did not improve from 0.79466
# 53/53 [==============================] - 2s 41ms/step - loss: 0.0071 - accuracy: 0.9988 - val_loss: 1.0579 - val_accuracy: 0.7700 - lr: 2.5000e-04
# Epoch 26/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0077 - accuracy: 0.9976Restoring model weights from the end of the best epoch: 16.
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 26: val_accuracy did not improve from 0.79466
# 53/53 [==============================] - 2s 44ms/step - loss: 0.0077 - accuracy: 0.9976 - val_loss: 1.0104 - val_accuracy: 0.7782 - lr: 2.5000e-04
# Epoch 26: early stopping
# Epoch 1/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0166 - accuracy: 0.9946
# Epoch 1: val_accuracy improved from -inf to 0.81314, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\mobilenet_v3_large\run_000_20251119_175545\checkpoints\run_003_fine.keras
# 53/53 [==============================] - 7s 67ms/step - loss: 0.0166 - accuracy: 0.9946 - val_loss: 0.7691 - val_accuracy: 0.8131 - lr: 1.0000e-04
# Epoch 2/100
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0372 - accuracy: 0.9871
# Epoch 2: val_accuracy did not improve from 0.81314
# 53/53 [==============================] - 2s 44ms/step - loss: 0.0366 - accuracy: 0.9874 - val_loss: 1.4531 - val_accuracy: 0.6858 - lr: 1.0000e-04
# Epoch 3/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0064 - accuracy: 0.9982
# Epoch 3: val_accuracy did not improve from 0.81314
# 53/53 [==============================] - 2s 46ms/step - loss: 0.0064 - accuracy: 0.9982 - val_loss: 1.1928 - val_accuracy: 0.7680 - lr: 1.0000e-04
# Epoch 4/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0074 - accuracy: 0.9988
# Epoch 4: val_accuracy did not improve from 0.81314
# 53/53 [==============================] - 3s 46ms/step - loss: 0.0074 - accuracy: 0.9988 - val_loss: 1.0708 - val_accuracy: 0.7680 - lr: 1.0000e-04
# Epoch 5/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0026 - accuracy: 0.9994
# Epoch 5: val_accuracy did not improve from 0.81314
# 53/53 [==============================] - 2s 45ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 1.1998 - val_accuracy: 0.7495 - lr: 1.0000e-04
# Epoch 6/100
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 6: val_accuracy did not improve from 0.81314
# 53/53 [==============================] - 3s 49ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.2306 - val_accuracy: 0.7639 - lr: 1.0000e-04
# Epoch 7/100
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 7: val_accuracy did not improve from 0.81314
# 53/53 [==============================] - 3s 52ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.2449 - val_accuracy: 0.7741 - lr: 5.0000e-05
# Epoch 8/100
# 51/53 [===========================>..] - ETA: 0s - loss: 4.7095e-04 - accuracy: 1.0000
# Epoch 8: val_accuracy did not improve from 0.81314
# 53/53 [==============================] - 2s 45ms/step - loss: 4.6565e-04 - accuracy: 1.0000 - val_loss: 1.2816 - val_accuracy: 0.7700 - lr: 5.0000e-05
# Epoch 9/100
# 51/53 [===========================>..] - ETA: 0s - loss: 6.9975e-04 - accuracy: 1.0000
# Epoch 9: val_accuracy did not improve from 0.81314
# 53/53 [==============================] - 2s 45ms/step - loss: 6.9525e-04 - accuracy: 1.0000 - val_loss: 1.2218 - val_accuracy: 0.7536 - lr: 5.0000e-05
# Epoch 10/100
# 51/53 [===========================>..] - ETA: 0s - loss: 4.5680e-04 - accuracy: 1.0000
# Epoch 10: val_accuracy did not improve from 0.81314
# 53/53 [==============================] - 3s 47ms/step - loss: 4.4801e-04 - accuracy: 1.0000 - val_loss: 1.2096 - val_accuracy: 0.7598 - lr: 5.0000e-05
# Epoch 11/100
# 51/53 [===========================>..] - ETA: 0s - loss: 4.9142e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 1.
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 11: val_accuracy did not improve from 0.81314
# 53/53 [==============================] - 3s 47ms/step - loss: 4.8346e-04 - accuracy: 1.0000 - val_loss: 1.2876 - val_accuracy: 0.7495 - lr: 5.0000e-05
# Epoch 11: early stopping
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 1.6127 - accuracy: 0.4982
# Epoch 1: val_accuracy improved from -inf to 0.64392, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\mobilenet_v3_large\run_000_20251119_175545\checkpoints\run_004_frozen.keras
# 53/53 [==============================] - 6s 65ms/step - loss: 1.6024 - accuracy: 0.5018 - val_loss: 1.1103 - val_accuracy: 0.6439 - lr: 0.0010
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.4513 - accuracy: 0.8609
# Epoch 2: val_accuracy improved from 0.64392 to 0.66098, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\mobilenet_v3_large\run_000_20251119_175545\checkpoints\run_004_frozen.keras
# 53/53 [==============================] - 2s 44ms/step - loss: 0.4513 - accuracy: 0.8609 - val_loss: 0.9560 - val_accuracy: 0.6610 - lr: 0.0010
# Epoch 3/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.2375 - accuracy: 0.9297
# Epoch 3: val_accuracy did not improve from 0.66098
# 53/53 [==============================] - 2s 38ms/step - loss: 0.2361 - accuracy: 0.9304 - val_loss: 0.9106 - val_accuracy: 0.6503 - lr: 0.0010
# Epoch 4/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.1571 - accuracy: 0.9537
# Epoch 4: val_accuracy improved from 0.66098 to 0.71215, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\mobilenet_v3_large\run_000_20251119_175545\checkpoints\run_004_frozen.keras
# 53/53 [==============================] - 2s 43ms/step - loss: 0.1574 - accuracy: 0.9536 - val_loss: 0.9670 - val_accuracy: 0.7122 - lr: 0.0010
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0988 - accuracy: 0.9744
# Epoch 5: val_accuracy did not improve from 0.71215
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0988 - accuracy: 0.9744 - val_loss: 1.0493 - val_accuracy: 0.6802 - lr: 0.0010
# Epoch 6/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0831 - accuracy: 0.9778
# Epoch 6: val_accuracy improved from 0.71215 to 0.76333, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\mobilenet_v3_large\run_000_20251119_175545\checkpoints\run_004_frozen.keras
# 53/53 [==============================] - 2s 41ms/step - loss: 0.0829 - accuracy: 0.9780 - val_loss: 0.9209 - val_accuracy: 0.7633 - lr: 0.0010
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0661 - accuracy: 0.9828
# Epoch 7: val_accuracy did not improve from 0.76333
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0661 - accuracy: 0.9828 - val_loss: 1.0679 - val_accuracy: 0.6972 - lr: 0.0010
# Epoch 8/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0547 - accuracy: 0.9814
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 8: val_accuracy did not improve from 0.76333
# 53/53 [==============================] - 2s 40ms/step - loss: 0.0545 - accuracy: 0.9816 - val_loss: 1.4863 - val_accuracy: 0.6055 - lr: 0.0010
# Epoch 9/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0371 - accuracy: 0.9904
# Epoch 9: val_accuracy did not improve from 0.76333
# 53/53 [==============================] - 2s 38ms/step - loss: 0.0372 - accuracy: 0.9905 - val_loss: 1.1144 - val_accuracy: 0.7036 - lr: 5.0000e-04
# Epoch 10/50
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0222 - accuracy: 0.9969
# Epoch 10: val_accuracy did not improve from 0.76333
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0213 - accuracy: 0.9970 - val_loss: 1.0387 - val_accuracy: 0.7356 - lr: 5.0000e-04
# Epoch 11/50
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0219 - accuracy: 0.9963
# Epoch 11: val_accuracy did not improve from 0.76333
# 53/53 [==============================] - 2s 37ms/step - loss: 0.0220 - accuracy: 0.9964 - val_loss: 1.1260 - val_accuracy: 0.7591 - lr: 5.0000e-04
# Epoch 12/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0172 - accuracy: 0.9970
# Epoch 12: val_accuracy improved from 0.76333 to 0.76546, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\mobilenet_v3_large\run_000_20251119_175545\checkpoints\run_004_frozen.keras
# 53/53 [==============================] - 2s 41ms/step - loss: 0.0171 - accuracy: 0.9970 - val_loss: 1.0969 - val_accuracy: 0.7655 - lr: 5.0000e-04
# Epoch 13/50
# 52/53 [============================>.] - ETA: 0s - loss: 0.0164 - accuracy: 0.9958Restoring model weights from the end of the best epoch: 3.
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 13: val_accuracy did not improve from 0.76546
# 53/53 [==============================] - 2s 39ms/step - loss: 0.0163 - accuracy: 0.9958 - val_loss: 1.1869 - val_accuracy: 0.7505 - lr: 5.0000e-04
# Epoch 13: early stopping
# Epoch 1/100
# 51/53 [===========================>..] - ETA: 0s - loss: 0.1112 - accuracy: 0.9632
# Epoch 1: val_accuracy improved from -inf to 0.76759, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\mobilenet_v3_large\run_000_20251119_175545\checkpoints\run_004_fine.keras
# 53/53 [==============================] - 7s 66ms/step - loss: 0.1095 - accuracy: 0.9631 - val_loss: 0.9466 - val_accuracy: 0.7676 - lr: 1.0000e-04
# Epoch 2/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0448 - accuracy: 0.9868
# Epoch 2: val_accuracy did not improve from 0.76759
# 53/53 [==============================] - 2s 40ms/step - loss: 0.0444 - accuracy: 0.9869 - val_loss: 0.9935 - val_accuracy: 0.7591 - lr: 1.0000e-04
# Epoch 3/100
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0333 - accuracy: 0.9884
# Epoch 3: val_accuracy did not improve from 0.76759
# 53/53 [==============================] - 2s 40ms/step - loss: 0.0342 - accuracy: 0.9875 - val_loss: 1.0178 - val_accuracy: 0.7633 - lr: 1.0000e-04
# Epoch 4/100
# 53/53 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9958
# Epoch 4: val_accuracy did not improve from 0.76759
# 53/53 [==============================] - 2s 41ms/step - loss: 0.0198 - accuracy: 0.9958 - val_loss: 1.0408 - val_accuracy: 0.7292 - lr: 1.0000e-04
# Epoch 5/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0149 - accuracy: 0.9964
# Epoch 5: val_accuracy did not improve from 0.76759
# 53/53 [==============================] - 2s 42ms/step - loss: 0.0147 - accuracy: 0.9964 - val_loss: 1.1777 - val_accuracy: 0.7356 - lr: 1.0000e-04
# Epoch 6/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0103 - accuracy: 0.9958
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 6: val_accuracy did not improve from 0.76759
# 53/53 [==============================] - 2s 41ms/step - loss: 0.0102 - accuracy: 0.9958 - val_loss: 1.0593 - val_accuracy: 0.7612 - lr: 1.0000e-04
# Epoch 7/100
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0084 - accuracy: 0.9975
# Epoch 7: val_accuracy improved from 0.76759 to 0.82090, saving model to ../../experiments/exer_recog/results/exp_03_smart_heads\mobilenet_v3_large\run_000_20251119_175545\checkpoints\run_004_fine.keras
# 53/53 [==============================] - 3s 48ms/step - loss: 0.0085 - accuracy: 0.9976 - val_loss: 0.8195 - val_accuracy: 0.8209 - lr: 5.0000e-05
# Epoch 8/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0081 - accuracy: 0.9982
# Epoch 8: val_accuracy did not improve from 0.82090
# 53/53 [==============================] - 2s 44ms/step - loss: 0.0080 - accuracy: 0.9982 - val_loss: 0.9743 - val_accuracy: 0.7996 - lr: 5.0000e-05
# Epoch 9/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0081 - accuracy: 0.9970
# Epoch 9: val_accuracy did not improve from 0.82090
# 53/53 [==============================] - 2s 43ms/step - loss: 0.0080 - accuracy: 0.9970 - val_loss: 1.0260 - val_accuracy: 0.7484 - lr: 5.0000e-05
# Epoch 10/100
# 53/53 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9994
# Epoch 10: val_accuracy did not improve from 0.82090
# 53/53 [==============================] - 2s 41ms/step - loss: 0.0037 - accuracy: 0.9994 - val_loss: 1.0318 - val_accuracy: 0.8145 - lr: 5.0000e-05
# Epoch 11/100
# 53/53 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9994
# Epoch 11: val_accuracy did not improve from 0.82090
# 53/53 [==============================] - 3s 48ms/step - loss: 0.0032 - accuracy: 0.9994 - val_loss: 1.0697 - val_accuracy: 0.8038 - lr: 5.0000e-05
# Epoch 12/100
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0026 - accuracy: 0.9994
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 12: val_accuracy did not improve from 0.82090
# 53/53 [==============================] - 2s 44ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 1.0832 - val_accuracy: 0.7676 - lr: 5.0000e-05
# Epoch 13/100
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0050 - accuracy: 0.9982
# Epoch 13: val_accuracy did not improve from 0.82090
# 53/53 [==============================] - 2s 44ms/step - loss: 0.0050 - accuracy: 0.9982 - val_loss: 1.0468 - val_accuracy: 0.7932 - lr: 2.5000e-05
# Epoch 14/100
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.82090
# 53/53 [==============================] - 2s 42ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.1582 - val_accuracy: 0.7569 - lr: 2.5000e-05
# Epoch 15/100
# 52/53 [============================>.] - ETA: 0s - loss: 0.0040 - accuracy: 0.9988
# Epoch 15: val_accuracy did not improve from 0.82090
# 53/53 [==============================] - 2s 42ms/step - loss: 0.0039 - accuracy: 0.9988 - val_loss: 1.1535 - val_accuracy: 0.7697 - lr: 2.5000e-05
# Epoch 16/100
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0030 - accuracy: 0.9994
# Epoch 16: val_accuracy did not improve from 0.82090
# 53/53 [==============================] - 2s 42ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 1.1211 - val_accuracy: 0.7633 - lr: 2.5000e-05
# Epoch 17/100
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 7.
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 17: val_accuracy did not improve from 0.82090
# 53/53 [==============================] - 2s 44ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.1331 - val_accuracy: 0.7569 - lr: 2.5000e-05
# Epoch 17: early stopping
# Backbones: 100%|██████████| 7/7 [2:07:53<00:00, 1096.27s/it]

# %% [markdown]
# ## Comprehensive Analysis

# %%
print("="*80)
print("COMPREHENSIVE BACKBONE COMPARISON (Experiment 3)")
print("="*80)

# Step 1: Count model parameters
backbones_to_analyze = [
    'efficientnet_b0',
    'efficientnet_b2',
    'efficientnet_b3',
    'resnet50',
    'vgg16',
    'mobilenet_v2',
    'mobilenet_v3_large',
]

print("\nStep 1: Counting model parameters...")
params_df = get_all_model_parameters(backbones_to_analyze, img_size=224, num_classes=15)

print("\nModel Parameter Comparison:")
print("="*80)
print(params_df.to_string(index=False))
print("="*80)

# Step 2: Load training results
print("\nStep 2: Loading training results...")
backbone_results = load_backbone_results_with_config(results_base_dir='../../experiments/exer_recog/results/exp_03_smart_heads')

# Step 3: Generate comparisons
print("\nStep 3: Generating comprehensive comparison...")
os.makedirs('experiments/exer_recog/results/exp_03_smart_heads/comparisons', exist_ok=True)
comparison_csv = create_comprehensive_comparison(
    all_backbone_results=backbone_results,
    model_params_df=params_df,
    output_dir='D:/Graduation Project/ai-virtual-coach/experiments/exer_recog/results/exp_03_smart_heads/comparisons'
)

# Step 4: Statistical analysis
print("\nStep 4: Performing statistical analysis...")
stats_txt = generate_statistical_comparison(
    all_backbone_results=backbone_results,
    output_dir='D:/Graduation Project/ai-virtual-coach/experiments/exer_recog/results/exp_03_smart_heads/comparisons'
)

print("\n✓ Analysis complete! Results saved to: experiments/exer_recog/results/exp_03_smart_heads/comparisons/")
# Out:
# ================================================================================
# COMPREHENSIVE BACKBONE COMPARISON (Experiment 3)
# ================================================================================
#
# Step 1: Counting model parameters...
# Counting parameters: 100%|██████████| 7/7 [00:14<00:00,  2.12s/it]
# No run folders found in ../../experiments/exer_recog/results/exp_03_smart_heads\exp_03_smart_heads
# Model Parameter Comparison:
# ================================================================================
#           backbone  total_params  trainable_params  non_trainable_params  num_layers  params_millions
#       mobilenet_v2       2589775            331791               2257984           6             2.59
# mobilenet_v3_large       3246223            249871               2996352           6             3.25
#    efficientnet_b0       6251103            331791               5919312           6             6.25
#    efficientnet_b2       9133933            364559               8769374           6             9.13
#    efficientnet_b3      13327949            397327              12930622           6            13.33
#              vgg16      14849871            135183              14714688           6            14.85
#           resnet50      24116111            528399              23587712           6            24.12
# ================================================================================
#
# Step 2: Loading training results...
#
# Step 3: Generating comprehensive comparison...
#
# Step 4: Performing statistical analysis...
#
# ✓ Analysis complete! Results saved to: experiments/exer_recog/results/exp_03_smart_heads/comparisons/

# %% [markdown]
# ## Compare with Experiment 1 Baseline
#
# This cell loads results from both Experiment 1 (baseline) and Experiment 3 (smart heads) to compare performance.

# %%
print("="*80)
print("EXPERIMENT 1 (BASELINE) vs EXPERIMENT 3 (SMART HEADS)")
print("="*80)

# Load Experiment 1 results
exp1_results = load_backbone_results_with_config(results_base_dir='experiments/exer_recog/results/exp_01_baseline')

# Load Experiment 3 results
exp3_results = load_backbone_results_with_config(results_base_dir='experiments/exer_recog/results/exp_03_smart_heads')

# Create comparison dataframe
comparison_data = []

for backbone in BACKBONES_TO_TEST:
    if backbone in exp1_results and backbone in exp3_results:
        exp1_accs = [r['test_acc'] for r in exp1_results[backbone]]
        exp3_accs = [r['test_acc'] for r in exp3_results[backbone]]
        
        comparison_data.append({
            'Backbone': backbone,
            'Exp1_Mean': np.mean(exp1_accs),
            'Exp1_Std': np.std(exp1_accs),
            'Exp1_Best': np.max(exp1_accs),
            'Exp3_Mean': np.mean(exp3_accs),
            'Exp3_Std': np.std(exp3_accs),
            'Exp3_Best': np.max(exp3_accs),
            'Mean_Improvement': np.mean(exp3_accs) - np.mean(exp1_accs),
            'Best_Improvement': np.max(exp3_accs) - np.max(exp1_accs)
        })

comparison_df = pd.DataFrame(comparison_data)
comparison_df = comparison_df.sort_values('Exp3_Mean', ascending=False)

print("\nDetailed Comparison:")
print(comparison_df.to_string(index=False))

# Summary statistics
print("\n" + "="*80)
print("SUMMARY")
print("="*80)
print(f"Best Exp1 Mean: {comparison_df['Exp1_Mean'].max():.4f} ({comparison_df.loc[comparison_df['Exp1_Mean'].idxmax(), 'Backbone']})")
print(f"Best Exp3 Mean: {comparison_df['Exp3_Mean'].max():.4f} ({comparison_df.loc[comparison_df['Exp3_Mean'].idxmax(), 'Backbone']})")
print(f"\nAverage improvement: {comparison_df['Mean_Improvement'].mean():.4f}")
print(f"Backbones improved: {(comparison_df['Mean_Improvement'] > 0).sum()}/{len(comparison_df)}")

# Check success criteria
best_exp3_mean = comparison_df['Exp3_Mean'].max()
best_exp3_std = comparison_df.loc[comparison_df['Exp3_Mean'].idxmax(), 'Exp3_Std']

print("\n" + "="*80)
print("SUCCESS CRITERIA CHECK")
print("="*80)
print(f"Best Exp3 mean: {best_exp3_mean:.4f} (std={best_exp3_std:.4f})")

if best_exp3_mean > 0.88 and best_exp3_std < 0.02:
    print("✅ EXCELLENT SUCCESS: Mean > 88% and std < 2%")
    print("   → Ready to scale to 30 runs!")
elif best_exp3_mean > 0.86 and best_exp3_std < 0.025:
    print("✅ GOOD SUCCESS: Mean > 86% and std < 2.5%")
    print("   → Consider scaling to 30 runs for top performers")
elif best_exp3_mean > 0.84:
    print("✅ MINIMUM SUCCESS: Mean > 84% (beats baseline 83.25%)")
    print("   → Architecture-specific heads show promise, but may need refinement")
else:
    print("❌ BELOW BASELINE: Mean ≤ 84%")
    print("   → Architecture-specific heads did not improve performance")
    print("   → Consider reverting to universal heads or refining head designs")

# Save comparison
comparison_df.to_csv('experiments/exer_recog/results/exp_03_smart_heads/exp1_vs_exp3_comparison.csv', index=False)
print("\nComparison saved to: experiments/exer_recog/results/exp_03_smart_heads/exp1_vs_exp3_comparison.csv")

# %% [markdown]
# ---
#
# ## Experiment 3 Complete! 🎉
#
# ### Results Summary
# All results saved to: `experiments/exer_recog/results/exp_03_smart_heads/`
#
# **Generated files:**
# - `backbone_comparison.csv` - Quick comparison table
# - `exp1_vs_exp3_comparison.csv` - Direct comparison with baseline
# - `comparisons/comprehensive_comparison.csv` - Detailed metrics
# - `comparisons/statistical_analysis.txt` - Statistical tests
# - Individual backbone folders with run-specific results
#
# ### Key Questions to Answer
#
# **1. Did architecture-specific heads improve performance?**
# - Compare mean test accuracy: Exp3 vs Exp1 baseline
# - Check if any backbone beats baseline 83.25%
#
# **2. Which backbone family benefits most?**
# - EfficientNet with swish activation?
# - ResNet50 with larger head?
# - MobileNet with compact head?
#
# **3. Is consistency improved?**
# - Compare std deviation: Exp3 vs Exp1
# - Lower std = more reliable deployment performance
#
# ### Next Steps
#
# **If Excellent Success (mean > 88%, std < 2%):**
# - 🚀 Scale to 30 runs for best backbone
# - Target: Find single model with >90% test accuracy
# - Deploy best performer for production
#
# **If Good Success (mean > 86%, std < 2.5%):**
# - 📈 Scale to 30 runs for top 2-3 backbones
# - Compare statistical significance
# - Consider ensemble of top performers
#
# **If Minimum Success (mean > 84%):**
# - 🔍 Analyze which head designs worked best
# - Refine underperforming heads
# - Try alternative dropout rates or layer sizes
#
# **If Below Baseline (mean ≤ 84%):**
# - ❌ Revert to universal heads (Experiment 1 approach)
# - Focus on other improvements: augmentation, ensemble methods
# - Consider that universal heads may be optimal for this task
#
# ### Design Philosophy Validated?
#
# This experiment tests the hypothesis that **architecture-specific heads outperform universal heads** when properly designed:
# - ✅ GlobalAveragePooling2D for all backbones
# - ✅ 2-layer heads (balanced capacity)
# - ✅ Activation matching (swish for EfficientNet, relu for others)
# - ✅ Progressive dropout
# - ✅ Size scaling to backbone complexity
#
# Results will confirm or refute this hypothesis and guide future experiments!
