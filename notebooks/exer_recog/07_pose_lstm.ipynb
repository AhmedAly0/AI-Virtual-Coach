# %% [markdown]
# ## Setup
#
# ### Environment Configuration
#
# Before running this notebook, ensure you have the following:
# - TensorFlow 2.x installed
# - The pose NPZ files generated (both static and temporal versions)
# - Config files for experiment 7 in the `config/` directory
#
# ### NPZ Files Required
# - `pose_data_front_temporal.npz` - Front view with 50 temporal frames per sample
# - `pose_data_side_temporal.npz` - Side view with 50 temporal frames per sample
# - `pose_data_front_static.npz` - Front view with 5 statistics per angle
# - `pose_data_side_static.npz` - Side view with 5 statistics per angle

# %% [markdown]
# ### Imports and Project Path Configuration

# %%
# Core imports
import sys
import os
from pathlib import Path

# Data and visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set project root
PROJECT_ROOT = Path.cwd().parent.parent
sys.path.insert(0, str(PROJECT_ROOT))

print(f"Project root: {PROJECT_ROOT}")
print(f"Working directory: {Path.cwd()}")
# Out:
# Project root: /mnt/d/Graduation_Project/ai-virtual-coach
# Working directory: /mnt/d/Graduation_Project/ai-virtual-coach/notebooks/exer_recog

# %%
# Reload modules for development
# %load_ext autoreload
# %autoreload 2

# %%
# Import project modules
from src.data import load_pose_data
from src.data.data_loader import load_pose_temporal_data
from src.scripts.experiment_7 import (
    train_experiment_7_temporal,
    train_experiment_7_temporal_multi_run,
    train_experiment_7_static,
    train_experiment_7_static_multi_run
)
from src.utils.visualization import (
    plot_training_history,
    plot_confusion_matrix_from_metrics
)

print("All modules imported successfully!")
# Out:
# All modules imported successfully!

# %% [markdown]
# ### Define Data Paths and Config Paths

# %%
# NPZ file paths
POSE_DATA_DIR = PROJECT_ROOT / 'datasets' / 'Mediapipe pose estimates'

# Temporal NPZ files (native LSTM input)
front_temporal_npz = POSE_DATA_DIR / 'pose_data_front_temporal.npz'
side_temporal_npz = POSE_DATA_DIR / 'pose_data_side_temporal.npz'

# Static NPZ files (reshaped for LSTM)
front_static_npz = POSE_DATA_DIR / 'pose_data_front_static.npz'
side_static_npz = POSE_DATA_DIR / 'pose_data_side_static.npz'

# Config paths
config_path_temporal_front = PROJECT_ROOT / 'config' / 'experiment_7_temporal_front.yaml'
config_path_temporal_side = PROJECT_ROOT / 'config' / 'experiment_7_temporal_side.yaml'
config_path_static_front = PROJECT_ROOT / 'config' / 'experiment_7_static_front.yaml'
config_path_static_side = PROJECT_ROOT / 'config' / 'experiment_7_static_side.yaml'

print("Data paths configured:")
print(f"  Temporal Front NPZ: {front_temporal_npz}")
print(f"  Temporal Side NPZ:  {side_temporal_npz}")
print(f"  Static Front NPZ:   {front_static_npz}")
print(f"  Static Side NPZ:    {side_static_npz}")
# Out:
# Data paths configured:
#   Temporal Front NPZ: /mnt/d/Graduation_Project/ai-virtual-coach/datasets/Mediapipe pose estimates/pose_data_front_temporal.npz
#   Temporal Side NPZ:  /mnt/d/Graduation_Project/ai-virtual-coach/datasets/Mediapipe pose estimates/pose_data_side_temporal.npz
#   Static Front NPZ:   /mnt/d/Graduation_Project/ai-virtual-coach/datasets/Mediapipe pose estimates/pose_data_front_static.npz
#   Static Side NPZ:    /mnt/d/Graduation_Project/ai-virtual-coach/datasets/Mediapipe pose estimates/pose_data_side_static.npz

# %% [markdown]
# ### Quick Data Inspection

# %%
# Load and inspect temporal data
front_temporal_dataset, front_temporal_summary = load_pose_temporal_data(str(front_temporal_npz))

print("Front Temporal Dataset Summary:")
print(f"  Total samples: {front_temporal_summary['count']}")
print(f"  Temporal shape: {front_temporal_summary['temporal_shape']}")
print(f"  Angle names: {front_temporal_summary.get('angle_names', 'Not available')}")
print(f"  Unique classes: {front_temporal_summary['unique_classes']}")
# Out:
# INFO - [load_pose_temporal_data] Loaded 1574 samples (49 subjects, 15 classes) from front view, temporal shape: (50, 9)
# Front Temporal Dataset Summary:
#   Total samples: 1574
#   Temporal shape: (50, 9)
#   Angle names: ['left_elbow', 'right_elbow', 'left_shoulder', 'right_shoulder', 'left_hip', 'right_hip', 'left_knee', 'right_knee', 'torso_lean']
#   Unique classes: 15

# %%
# Load and inspect static data
front_static_dataset, front_static_summary = load_pose_data(str(front_static_npz))

print("Front Static Dataset Summary:")
print(f"  Total samples: {front_static_summary['count']}")
print(f"  Unique subjects: {front_static_summary['unique_subjects']}")
print(f"  Angle names: {front_static_summary.get('angle_names', 'Not available')}")
print(f"  Unique classes: {front_static_summary['unique_classes']}")
# Out:
# INFO - [load_pose_data] Loaded 1574 samples (49 subjects, 15 classes) from front view
# Front Static Dataset Summary:
#   Total samples: 1574
#   Unique subjects: 49
#   Angle names: ['left_elbow', 'right_elbow', 'left_shoulder', 'right_shoulder', 'left_hip', 'right_hip', 'left_knee', 'right_knee', 'torso_lean']
#   Unique classes: 15

# %% [markdown]
# ---
#
# # Part 1: Temporal LSTM Training
#
# LSTM with native sequential input from temporal pose features.
#
# **Input shape:** `(50 timesteps, N angles)` where N depends on config's `selected_angles`

# %% [markdown]
# ## 1.1 Front View - Temporal LSTM

# %%
# Run multi-run training for front temporal LSTM
os.chdir(PROJECT_ROOT)  # Ensure we're in project root for relative paths in config

multi_run_results_temporal_front, aggregated_stats_temporal_front = train_experiment_7_temporal_multi_run(
    npz_path=str(front_temporal_npz),
    config_path=str(config_path_temporal_front)
)
# Out:
# INFO - Configuration loaded from /mnt/d/Graduation_Project/ai-virtual-coach/config/experiment_7_temporal_front.yaml
# INFO - Multi-run parent folder: /mnt/d/Graduation_Project/ai-virtual-coach/experiments/exer_recog/results/exp_07_pose_lstm_temporal/front/multi_run_001
# INFO -
# ================================================================================
# INFO - Starting run 1/30 (seed=43)
# INFO - ================================================================================
# INFO - Configuration loaded from /mnt/d/Graduation_Project/ai-virtual-coach/config/experiment_7_temporal_front.yaml
# INFO - Global random seed set to: 43
# INFO - [load_pose_temporal_data] Loaded 1574 samples (49 subjects, 15 classes) from front view, temporal shape: (50, 9)
# INFO - Filtered temporal features for LSTM: 8 angles selected (left_elbow, right_elbow, left_shoulder, right_shoulder, left_hip, right_hip, left_knee, right_knee) -> shape (50, 8)
# INFO - Using selected angles: ['left_elbow', 'right_elbow', 'left_shoulder', 'right_shoulder', 'left_hip', 'right_hip', 'left_knee', 'right_knee']
# INFO - Found 49 unique subject identities
# INFO - Subject split: 25 train, 10 val, 14 test subjects
# INFO - Sample split: 916 train, 252 val, 406 test samples
# INFO - Created label mapping for 15 classes
# INFO - Pose split (3-way): train=916, val=252, test=406
# INFO - Number of pose classes: 15
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1767132150.116700  515022 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5518 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Epoch 1/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 8s 242ms/step - accuracy: 0.2020 - loss: 2.5744 - val_accuracy: 0.4206 - val_loss: 2.3447
# Epoch 2/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 223ms/step - accuracy: 0.3362 - loss: 2.2907 - val_accuracy: 0.5159 - val_loss: 2.0045
# Epoch 3/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 212ms/step - accuracy: 0.4116 - loss: 1.9848 - val_accuracy: 0.5952 - val_loss: 1.6578
# Epoch 4/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - accuracy: 0.4913 - loss: 1.7155 - val_accuracy: 0.6349 - val_loss: 1.3862
# Epoch 5/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - accuracy: 0.5371 - loss: 1.5229 - val_accuracy: 0.7222 - val_loss: 1.1890
# Epoch 6/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 208ms/step - accuracy: 0.5546 - loss: 1.3578 - val_accuracy: 0.7103 - val_loss: 1.1299
# Epoch 7/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - accuracy: 0.5862 - loss: 1.2294 - val_accuracy: 0.7262 - val_loss: 1.0887
# Epoch 8/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - accuracy: 0.5983 - loss: 1.1833 - val_accuracy: 0.6825 - val_loss: 1.0273
# Epoch 9/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 307ms/step - accuracy: 0.6103 - loss: 1.1236 - val_accuracy: 0.7024 - val_loss: 1.0172
# Epoch 10/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - accuracy: 0.6474 - loss: 1.0506 - val_accuracy: 0.7103 - val_loss: 1.0157
# Epoch 11/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 213ms/step - accuracy: 0.6496 - loss: 1.0620 - val_accuracy: 0.7421 - val_loss: 0.9367
# Epoch 12/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step - accuracy: 0.6441 - loss: 0.9981 - val_accuracy: 0.7302 - val_loss: 0.9750
# Epoch 13/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 229ms/step - accuracy: 0.6681 - loss: 0.9672 - val_accuracy: 0.7421 - val_loss: 0.9646
# Epoch 14/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 207ms/step - accuracy: 0.6397 - loss: 0.9620 - val_accuracy: 0.7143 - val_loss: 0.9421
# Epoch 15/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - accuracy: 0.6900 - loss: 0.9013 - val_accuracy: 0.7103 - val_loss: 0.9541
# Epoch 16/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - accuracy: 0.6736 - loss: 0.8819 - val_accuracy: 0.7222 - val_loss: 0.9664
# Epoch 17/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - accuracy: 0.7107 - loss: 0.8344 - val_accuracy: 0.7579 - val_loss: 0.9412
# Epoch 18/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 208ms/step - accuracy: 0.6900 - loss: 0.8647 - val_accuracy: 0.7579 - val_loss: 0.9369
# Epoch 19/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 333ms/step - accuracy: 0.7216 - loss: 0.7679 - val_accuracy: 0.7063 - val_loss: 0.9390
# Epoch 20/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - accuracy: 0.7282 - loss: 0.7663 - val_accuracy: 0.7421 - val_loss: 0.9281
# Epoch 21/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 223ms/step - accuracy: 0.7380 - loss: 0.7569 - val_accuracy: 0.7460 - val_loss: 0.8899
# Epoch 22/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 245ms/step - accuracy: 0.7434 - loss: 0.7267 - val_accuracy: 0.7341 - val_loss: 0.8853
# Epoch 23/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 227ms/step - accuracy: 0.7544 - loss: 0.7062 - val_accuracy: 0.7063 - val_loss: 0.8677
# Epoch 24/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - accuracy: 0.7424 - loss: 0.6979 - val_accuracy: 0.7500 - val_loss: 0.8844
# Epoch 25/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - accuracy: 0.7587 - loss: 0.6829 - val_accuracy: 0.7381 - val_loss: 0.8756
# Epoch 26/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.7576 - loss: 0.7040 - val_accuracy: 0.7460 - val_loss: 0.8562
# Epoch 27/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - accuracy: 0.7631 - loss: 0.6624 - val_accuracy: 0.7143 - val_loss: 0.8534
# Epoch 28/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - accuracy: 0.7544 - loss: 0.6572 - val_accuracy: 0.7540 - val_loss: 0.8722
# Epoch 29/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - accuracy: 0.7806 - loss: 0.6213 - val_accuracy: 0.7302 - val_loss: 0.8691
# Epoch 30/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 271ms/step - accuracy: 0.7882 - loss: 0.6221 - val_accuracy: 0.7540 - val_loss: 0.9410
# Epoch 31/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - accuracy: 0.7664 - loss: 0.6341 - val_accuracy: 0.7143 - val_loss: 0.9119
# Epoch 32/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - accuracy: 0.7795 - loss: 0.6058 - val_accuracy: 0.7302 - val_loss: 0.8895
# Epoch 33/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 212ms/step - accuracy: 0.7948 - loss: 0.5514 - val_accuracy: 0.7302 - val_loss: 0.8785
# Epoch 34/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - accuracy: 0.7849 - loss: 0.6021 - val_accuracy: 0.7659 - val_loss: 0.8461
# Epoch 35/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - accuracy: 0.7806 - loss: 0.5761 - val_accuracy: 0.7738 - val_loss: 0.8457
# Epoch 36/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - accuracy: 0.8253 - loss: 0.5418 - val_accuracy: 0.7341 - val_loss: 0.8423
# Epoch 37/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.8133 - loss: 0.5501 - val_accuracy: 0.7738 - val_loss: 0.8581
# Epoch 38/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - accuracy: 0.8057 - loss: 0.5344 - val_accuracy: 0.7778 - val_loss: 0.8229
# Epoch 39/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - accuracy: 0.8166 - loss: 0.4998 - val_accuracy: 0.7738 - val_loss: 0.8582
# Epoch 40/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 175ms/step - accuracy: 0.8035 - loss: 0.5563 - val_accuracy: 0.7540 - val_loss: 0.8890
# Epoch 41/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 271ms/step - accuracy: 0.8210 - loss: 0.5153 - val_accuracy: 0.7698 - val_loss: 0.8130
# Epoch 42/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - accuracy: 0.8100 - loss: 0.4946 - val_accuracy: 0.7738 - val_loss: 0.8822
# Epoch 43/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - accuracy: 0.8210 - loss: 0.4950 - val_accuracy: 0.7817 - val_loss: 0.8679
# Epoch 44/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.8013 - loss: 0.5175 - val_accuracy: 0.7619 - val_loss: 0.8211
# Epoch 45/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - accuracy: 0.8199 - loss: 0.5057 - val_accuracy: 0.7460 - val_loss: 0.8286
# Epoch 46/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - accuracy: 0.8428 - loss: 0.4541 - val_accuracy: 0.7778 - val_loss: 0.8311
# Epoch 47/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 0.8341 - loss: 0.4521 - val_accuracy: 0.7381 - val_loss: 0.8544
# Epoch 48/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - accuracy: 0.8319 - loss: 0.4612 - val_accuracy: 0.7341 - val_loss: 0.9064
# Epoch 49/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - accuracy: 0.8253 - loss: 0.4568 - val_accuracy: 0.7738 - val_loss: 0.8500
# Epoch 50/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - accuracy: 0.8297 - loss: 0.4551 - val_accuracy: 0.7619 - val_loss: 0.8678
# Epoch 51/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 178ms/step - accuracy: 0.8253 - loss: 0.4501 - val_accuracy: 0.7897 - val_loss: 0.8265
# Epoch 52/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - accuracy: 0.8286 - loss: 0.4846 - val_accuracy: 0.7817 - val_loss: 0.8565
# Epoch 53/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 269ms/step - accuracy: 0.8330 - loss: 0.4396 - val_accuracy: 0.8016 - val_loss: 0.8166
# Epoch 54/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 178ms/step - accuracy: 0.8319 - loss: 0.4476 - val_accuracy: 0.7698 - val_loss: 0.8683
# Epoch 55/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 175ms/step - accuracy: 0.8417 - loss: 0.4259 - val_accuracy: 0.7579 - val_loss: 0.8150
# Epoch 56/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - accuracy: 0.8483 - loss: 0.4060 - val_accuracy: 0.7897 - val_loss: 0.8465
# Epoch 56: early stopping
# Restoring model weights from the end of the best epoch: 41.
# INFO - Saved metrics to /mnt/d/Graduation_Project/ai-virtual-coach/experiments/exer_recog/results/exp_07_pose_lstm_temporal/front/multi_run_001/run_001/metrics.json
# INFO - Experiment 7 (LSTM temporal) complete. Test acc=0.6675, macro F1=0.6579
# INFO - Run 1 complete: acc=0.6675, macro_f1=0.6579
# INFO -
# ================================================================================
# INFO - Starting run 2/30 (seed=44)
# INFO - ================================================================================
# INFO - Configuration loaded from /mnt/d/Graduation_Project/ai-virtual-coach/config/experiment_7_temporal_front.yaml
# INFO - Global random seed set to: 44
# INFO - [load_pose_temporal_data] Loaded 1574 samples (49 subjects, 15 classes) from front view, temporal shape: (50, 9)
# INFO - Filtered temporal features for LSTM: 8 angles selected (left_elbow, right_elbow, left_shoulder, right_shoulder, left_hip, right_hip, left_knee, right_knee) -> shape (50, 8)
# INFO - Using selected angles: ['left_elbow', 'right_elbow', 'left_shoulder', 'right_shoulder', 'left_hip', 'right_hip', 'left_knee', 'right_knee']
# INFO - Found 49 unique subject identities
# INFO - Subject split: 25 train, 10 val, 14 test subjects
# INFO - Sample split: 848 train, 200 val, 526 test samples
# INFO - Created label mapping for 15 classes
# INFO - Pose split (3-way): train=848, val=200, test=526
# INFO - Number of pose classes: 15
# Epoch 1/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 214ms/step - accuracy: 0.0955 - loss: 2.6451 - val_accuracy: 0.2050 - val_loss: 2.5323
# Epoch 2/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - accuracy: 0.2807 - loss: 2.3909 - val_accuracy: 0.3000 - val_loss: 2.2923
# Epoch 3/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - accuracy: 0.3844 - loss: 2.1250 - val_accuracy: 0.3400 - val_loss: 2.0387
# Epoch 4/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step - accuracy: 0.4116 - loss: 1.8639 - val_accuracy: 0.3100 - val_loss: 1.8919
# Epoch 5/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 0.4917 - loss: 1.6363 - val_accuracy: 0.3950 - val_loss: 1.7538
# Epoch 6/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - accuracy: 0.5566 - loss: 1.4593 - val_accuracy: 0.4250 - val_loss: 1.7112
# Epoch 7/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 276ms/step - accuracy: 0.5625 - loss: 1.3723 - val_accuracy: 0.4950 - val_loss: 1.5962
# Epoch 8/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step - accuracy: 0.6014 - loss: 1.2494 - val_accuracy: 0.5500 - val_loss: 1.3672
# Epoch 9/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - accuracy: 0.6038 - loss: 1.1809 - val_accuracy: 0.5150 - val_loss: 1.3982
# Epoch 10/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.6285 - loss: 1.1071 - val_accuracy: 0.5050 - val_loss: 1.3664
# Epoch 11/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 172ms/step - accuracy: 0.6285 - loss: 1.0751 - val_accuracy: 0.5000 - val_loss: 1.3629
# Epoch 12/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - accuracy: 0.6368 - loss: 1.0554 - val_accuracy: 0.5200 - val_loss: 1.3807
# Epoch 13/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - accuracy: 0.6333 - loss: 1.0379 - val_accuracy: 0.5650 - val_loss: 1.3684
# Epoch 14/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.6498 - loss: 0.9799 - val_accuracy: 0.5450 - val_loss: 1.2778
# Epoch 15/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 170ms/step - accuracy: 0.6828 - loss: 0.8940 - val_accuracy: 0.5800 - val_loss: 1.2652
# Epoch 16/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 0.6639 - loss: 0.9506 - val_accuracy: 0.5650 - val_loss: 1.3119
# Epoch 17/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.6698 - loss: 0.8950 - val_accuracy: 0.6350 - val_loss: 1.2469
# Epoch 18/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - accuracy: 0.6969 - loss: 0.8716 - val_accuracy: 0.5800 - val_loss: 1.1652
# Epoch 19/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - accuracy: 0.6981 - loss: 0.8306 - val_accuracy: 0.6250 - val_loss: 1.2549
# Epoch 20/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 268ms/step - accuracy: 0.6887 - loss: 0.8542 - val_accuracy: 0.6400 - val_loss: 1.2004
# Epoch 21/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - accuracy: 0.7099 - loss: 0.8174 - val_accuracy: 0.6100 - val_loss: 1.1803
# Epoch 22/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 224ms/step - accuracy: 0.7040 - loss: 0.7709 - val_accuracy: 0.6350 - val_loss: 1.1716
# Epoch 23/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step - accuracy: 0.7040 - loss: 0.8148 - val_accuracy: 0.6050 - val_loss: 1.2490
# Epoch 24/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 236ms/step - accuracy: 0.7323 - loss: 0.7552 - val_accuracy: 0.6000 - val_loss: 1.2495
# Epoch 25/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - accuracy: 0.7382 - loss: 0.7179 - val_accuracy: 0.5850 - val_loss: 1.2507
# Epoch 26/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step - accuracy: 0.7406 - loss: 0.7305 - val_accuracy: 0.6350 - val_loss: 1.2340
# Epoch 27/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 197ms/step - accuracy: 0.7547 - loss: 0.6950 - val_accuracy: 0.6600 - val_loss: 1.2187
# Epoch 28/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 299ms/step - accuracy: 0.7205 - loss: 0.7305 - val_accuracy: 0.6850 - val_loss: 1.1713
# Epoch 29/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.7429 - loss: 0.7205 - val_accuracy: 0.6450 - val_loss: 1.1230
# Epoch 30/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.7535 - loss: 0.6595 - val_accuracy: 0.6550 - val_loss: 1.2578
# Epoch 31/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 348ms/step - accuracy: 0.7429 - loss: 0.6866 - val_accuracy: 0.5950 - val_loss: 1.2493
# Epoch 32/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 265ms/step - accuracy: 0.7417 - loss: 0.6778 - val_accuracy: 0.6050 - val_loss: 1.2735
# Epoch 33/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 319ms/step - accuracy: 0.7783 - loss: 0.6158 - val_accuracy: 0.6900 - val_loss: 1.1112
# Epoch 34/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 284ms/step - accuracy: 0.7630 - loss: 0.6507 - val_accuracy: 0.6850 - val_loss: 1.1665
# Epoch 35/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 212ms/step - accuracy: 0.7724 - loss: 0.6384 - val_accuracy: 0.6750 - val_loss: 1.1401
# Epoch 36/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - accuracy: 0.7594 - loss: 0.6558 - val_accuracy: 0.6900 - val_loss: 1.1957
# Epoch 37/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 253ms/step - accuracy: 0.7736 - loss: 0.6449 - val_accuracy: 0.6850 - val_loss: 1.1369
# Epoch 38/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.7877 - loss: 0.5875 - val_accuracy: 0.6800 - val_loss: 1.0944
# Epoch 39/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 267ms/step - accuracy: 0.7677 - loss: 0.6136 - val_accuracy: 0.6650 - val_loss: 1.1028
# Epoch 40/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 349ms/step - accuracy: 0.7877 - loss: 0.5954 - val_accuracy: 0.6900 - val_loss: 1.2563
# Epoch 41/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 252ms/step - accuracy: 0.7854 - loss: 0.5634 - val_accuracy: 0.6950 - val_loss: 1.1977
# Epoch 42/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - accuracy: 0.7866 - loss: 0.5432 - val_accuracy: 0.6750 - val_loss: 1.3530
# Epoch 43/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - accuracy: 0.7830 - loss: 0.5747 - val_accuracy: 0.6800 - val_loss: 1.3773
# Epoch 44/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 175ms/step - accuracy: 0.8078 - loss: 0.5351 - val_accuracy: 0.6850 - val_loss: 1.3200
# Epoch 45/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 178ms/step - accuracy: 0.8031 - loss: 0.5711 - val_accuracy: 0.6800 - val_loss: 1.3146
# Epoch 46/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - accuracy: 0.7913 - loss: 0.5474 - val_accuracy: 0.7000 - val_loss: 1.2845
# Epoch 47/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 236ms/step - accuracy: 0.8149 - loss: 0.5136 - val_accuracy: 0.7050 - val_loss: 1.2690
# Epoch 48/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - accuracy: 0.8243 - loss: 0.5249 - val_accuracy: 0.6900 - val_loss: 1.1705
# Epoch 49/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 0.8113 - loss: 0.4996 - val_accuracy: 0.6800 - val_loss: 1.2099
# Epoch 50/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.8007 - loss: 0.5062 - val_accuracy: 0.6700 - val_loss: 1.2149
# Epoch 51/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 290ms/step - accuracy: 0.7866 - loss: 0.5487 - val_accuracy: 0.6800 - val_loss: 1.2899
# Epoch 52/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 224ms/step - accuracy: 0.8184 - loss: 0.5020 - val_accuracy: 0.7150 - val_loss: 1.2057
# Epoch 53/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 251ms/step - accuracy: 0.8042 - loss: 0.5226 - val_accuracy: 0.7300 - val_loss: 1.1515
# Epoch 53: early stopping
# Restoring model weights from the end of the best epoch: 38.
# INFO - Saved metrics to /mnt/d/Graduation_Project/ai-virtual-coach/experiments/exer_recog/results/exp_07_pose_lstm_temporal/front/multi_run_001/run_002/metrics.json
# INFO - Experiment 7 (LSTM temporal) complete. Test acc=0.6521, macro F1=0.6495
# INFO - Run 2 complete: acc=0.6521, macro_f1=0.6495
# INFO -
# ================================================================================
# INFO - Starting run 3/30 (seed=45)
# INFO - ================================================================================
# INFO - Configuration loaded from /mnt/d/Graduation_Project/ai-virtual-coach/config/experiment_7_temporal_front.yaml
# INFO - Global random seed set to: 45
# INFO - [load_pose_temporal_data] Loaded 1574 samples (49 subjects, 15 classes) from front view, temporal shape: (50, 9)
# INFO - Filtered temporal features for LSTM: 8 angles selected (left_elbow, right_elbow, left_shoulder, right_shoulder, left_hip, right_hip, left_knee, right_knee) -> shape (50, 8)
# INFO - Using selected angles: ['left_elbow', 'right_elbow', 'left_shoulder', 'right_shoulder', 'left_hip', 'right_hip', 'left_knee', 'right_knee']
# INFO - Found 49 unique subject identities
# INFO - Subject split: 25 train, 10 val, 14 test subjects
# INFO - Sample split: 862 train, 237 val, 475 test samples
# INFO - Created label mapping for 15 classes
# INFO - Pose split (3-way): train=862, val=237, test=475
# INFO - Number of pose classes: 15
# Epoch 1/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 251ms/step - accuracy: 0.1578 - loss: 2.6146 - val_accuracy: 0.2616 - val_loss: 2.3739
# Epoch 2/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 0.2355 - loss: 2.3458 - val_accuracy: 0.3038 - val_loss: 2.0987
# Epoch 3/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - accuracy: 0.3353 - loss: 2.0768 - val_accuracy: 0.3502 - val_loss: 1.8344
# Epoch 4/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - accuracy: 0.3956 - loss: 1.8653 - val_accuracy: 0.5527 - val_loss: 1.5933
# Epoch 5/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 207ms/step - accuracy: 0.4722 - loss: 1.6452 - val_accuracy: 0.5992 - val_loss: 1.4510
# Epoch 6/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - accuracy: 0.5418 - loss: 1.4323 - val_accuracy: 0.6793 - val_loss: 1.2967
# Epoch 7/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.5360 - loss: 1.3308 - val_accuracy: 0.6371 - val_loss: 1.2132
# Epoch 8/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 303ms/step - accuracy: 0.5534 - loss: 1.2397 - val_accuracy: 0.6582 - val_loss: 1.2107
# Epoch 9/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - accuracy: 0.5928 - loss: 1.1656 - val_accuracy: 0.6498 - val_loss: 1.1744
# Epoch 10/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 0.6067 - loss: 1.1106 - val_accuracy: 0.6498 - val_loss: 1.0935
# Epoch 11/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 213ms/step - accuracy: 0.6346 - loss: 1.0690 - val_accuracy: 0.6540 - val_loss: 1.0944
# Epoch 12/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - accuracy: 0.6636 - loss: 1.0105 - val_accuracy: 0.6582 - val_loss: 1.0580
# Epoch 13/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.6276 - loss: 1.0132 - val_accuracy: 0.6498 - val_loss: 1.1157
# Epoch 14/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 256ms/step - accuracy: 0.6671 - loss: 0.9182 - val_accuracy: 0.6624 - val_loss: 1.0726
# Epoch 15/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - accuracy: 0.6694 - loss: 0.9472 - val_accuracy: 0.6540 - val_loss: 1.0640
# Epoch 16/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - accuracy: 0.7019 - loss: 0.8828 - val_accuracy: 0.6456 - val_loss: 1.0798
# Epoch 17/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 232ms/step - accuracy: 0.6763 - loss: 0.8873 - val_accuracy: 0.6878 - val_loss: 1.0807
# Epoch 18/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 226ms/step - accuracy: 0.7019 - loss: 0.8543 - val_accuracy: 0.6624 - val_loss: 1.0427
# Epoch 19/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 321ms/step - accuracy: 0.7158 - loss: 0.8571 - val_accuracy: 0.6371 - val_loss: 1.1006
# Epoch 20/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - accuracy: 0.7111 - loss: 0.7914 - val_accuracy: 0.6414 - val_loss: 1.0740
# Epoch 21/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 0.7332 - loss: 0.7477 - val_accuracy: 0.6414 - val_loss: 0.9963
# Epoch 22/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - accuracy: 0.7123 - loss: 0.8184 - val_accuracy: 0.6667 - val_loss: 1.0157
# Epoch 23/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 212ms/step - accuracy: 0.7274 - loss: 0.7397 - val_accuracy: 0.6582 - val_loss: 1.0255
# Epoch 24/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 0.7239 - loss: 0.7441 - val_accuracy: 0.6582 - val_loss: 1.0850
# Epoch 25/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 0.7227 - loss: 0.7321 - val_accuracy: 0.6498 - val_loss: 1.0272
# Epoch 26/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.7297 - loss: 0.7529 - val_accuracy: 0.6751 - val_loss: 1.0357
# Epoch 27/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 170ms/step - accuracy: 0.7622 - loss: 0.6610 - val_accuracy: 0.6751 - val_loss: 1.0047
# Epoch 28/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - accuracy: 0.7494 - loss: 0.6720 - val_accuracy: 0.6667 - val_loss: 1.0688
# Epoch 29/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 170ms/step - accuracy: 0.7506 - loss: 0.6733 - val_accuracy: 0.6624 - val_loss: 1.0598
# Epoch 30/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 175ms/step - accuracy: 0.7726 - loss: 0.6041 - val_accuracy: 0.6624 - val_loss: 0.9958
# Epoch 31/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 294ms/step - accuracy: 0.7819 - loss: 0.6380 - val_accuracy: 0.6624 - val_loss: 1.0092
# Epoch 32/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - accuracy: 0.7738 - loss: 0.6275 - val_accuracy: 0.6582 - val_loss: 1.0178
# Epoch 33/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - accuracy: 0.7564 - loss: 0.6579 - val_accuracy: 0.6709 - val_loss: 1.0597
# Epoch 34/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - accuracy: 0.7726 - loss: 0.6038 - val_accuracy: 0.6582 - val_loss: 1.0837
# Epoch 35/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step - accuracy: 0.7761 - loss: 0.5978 - val_accuracy: 0.6793 - val_loss: 1.0925
# Epoch 36/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 172ms/step - accuracy: 0.7935 - loss: 0.5472 - val_accuracy: 0.6667 - val_loss: 1.1107
# Epoch 37/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 172ms/step - accuracy: 0.7715 - loss: 0.5936 - val_accuracy: 0.6793 - val_loss: 1.0523
# Epoch 38/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 179ms/step - accuracy: 0.7738 - loss: 0.6002 - val_accuracy: 0.6582 - val_loss: 1.0198
# Epoch 39/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - accuracy: 0.7923 - loss: 0.5580 - val_accuracy: 0.6835 - val_loss: 1.0620
# Epoch 40/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 169ms/step - accuracy: 0.7923 - loss: 0.5597 - val_accuracy: 0.6793 - val_loss: 1.0367
# Epoch 41/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step - accuracy: 0.8144 - loss: 0.5224 - val_accuracy: 0.6751 - val_loss: 1.0075
# Epoch 42/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - accuracy: 0.8097 - loss: 0.5357 - val_accuracy: 0.6498 - val_loss: 1.0115
# Epoch 43/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - accuracy: 0.8144 - loss: 0.5091 - val_accuracy: 0.6962 - val_loss: 1.0678
# Epoch 44/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 313ms/step - accuracy: 0.8016 - loss: 0.5247 - val_accuracy: 0.6667 - val_loss: 1.0873
# Epoch 45/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - accuracy: 0.8016 - loss: 0.5149 - val_accuracy: 0.6793 - val_loss: 1.1001
# Epoch 45: early stopping
# Restoring model weights from the end of the best epoch: 30.
# INFO - Saved metrics to /mnt/d/Graduation_Project/ai-virtual-coach/experiments/exer_recog/results/exp_07_pose_lstm_temporal/front/multi_run_001/run_003/metrics.json
# INFO - Experiment 7 (LSTM temporal) complete. Test acc=0.6421, macro F1=0.6254
# INFO - Run 3 complete: acc=0.6421, macro_f1=0.6254
# INFO -
# ================================================================================
# INFO - Starting run 4/30 (seed=46)
# INFO - ================================================================================
# INFO - Configuration loaded from /mnt/d/Graduation_Project/ai-virtual-coach/config/experiment_7_temporal_front.yaml
# INFO - Global random seed set to: 46
# INFO - [load_pose_temporal_data] Loaded 1574 samples (49 subjects, 15 classes) from front view, temporal shape: (50, 9)
# INFO - Filtered temporal features for LSTM: 8 angles selected (left_elbow, right_elbow, left_shoulder, right_shoulder, left_hip, right_hip, left_knee, right_knee) -> shape (50, 8)
# INFO - Using selected angles: ['left_elbow', 'right_elbow', 'left_shoulder', 'right_shoulder', 'left_hip', 'right_hip', 'left_knee', 'right_knee']
# INFO - Found 49 unique subject identities
# INFO - Subject split: 25 train, 10 val, 14 test subjects
# INFO - Sample split: 866 train, 298 val, 410 test samples
# INFO - Created label mapping for 15 classes
# INFO - Pose split (3-way): train=866, val=298, test=410
# INFO - Number of pose classes: 15
# Epoch 1/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 268ms/step - accuracy: 0.1409 - loss: 2.6141 - val_accuracy: 0.2181 - val_loss: 2.4753
# Epoch 2/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 236ms/step - accuracy: 0.2483 - loss: 2.3719 - val_accuracy: 0.3054 - val_loss: 2.2071
# Epoch 3/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 213ms/step - accuracy: 0.3591 - loss: 2.0851 - val_accuracy: 0.4396 - val_loss: 1.9053
# Epoch 4/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - accuracy: 0.4145 - loss: 1.8253 - val_accuracy: 0.4597 - val_loss: 1.6471
# Epoch 5/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - accuracy: 0.4734 - loss: 1.6221 - val_accuracy: 0.4262 - val_loss: 1.5151
# Epoch 6/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - accuracy: 0.5162 - loss: 1.4675 - val_accuracy: 0.4362 - val_loss: 1.4373
# Epoch 7/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 0.5162 - loss: 1.4152 - val_accuracy: 0.4765 - val_loss: 1.4012
# Epoch 8/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 232ms/step - accuracy: 0.5439 - loss: 1.3273 - val_accuracy: 0.5101 - val_loss: 1.3169
# Epoch 9/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 233ms/step - accuracy: 0.5774 - loss: 1.2381 - val_accuracy: 0.5369 - val_loss: 1.3415
# Epoch 10/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - accuracy: 0.5889 - loss: 1.1674 - val_accuracy: 0.5503 - val_loss: 1.2524
# Epoch 11/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 240ms/step - accuracy: 0.5797 - loss: 1.1389 - val_accuracy: 0.5638 - val_loss: 1.2639
# Epoch 12/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - accuracy: 0.6051 - loss: 1.0784 - val_accuracy: 0.5872 - val_loss: 1.1659
# Epoch 13/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - accuracy: 0.6247 - loss: 1.0340 - val_accuracy: 0.5772 - val_loss: 1.1671
# Epoch 14/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - accuracy: 0.6443 - loss: 0.9778 - val_accuracy: 0.5671 - val_loss: 1.1833
# Epoch 15/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - accuracy: 0.6570 - loss: 0.9703 - val_accuracy: 0.5772 - val_loss: 1.1646
# Epoch 16/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - accuracy: 0.6594 - loss: 0.9427 - val_accuracy: 0.5604 - val_loss: 1.2040
# Epoch 17/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 260ms/step - accuracy: 0.6663 - loss: 0.8816 - val_accuracy: 0.5940 - val_loss: 1.1214
# Epoch 18/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 262ms/step - accuracy: 0.6686 - loss: 0.8946 - val_accuracy: 0.5705 - val_loss: 1.1829
# Epoch 19/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 343ms/step - accuracy: 0.6928 - loss: 0.8681 - val_accuracy: 0.5671 - val_loss: 1.1581
# Epoch 20/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - accuracy: 0.7009 - loss: 0.7794 - val_accuracy: 0.5940 - val_loss: 1.1327
# Epoch 21/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 173ms/step - accuracy: 0.6998 - loss: 0.7633 - val_accuracy: 0.6007 - val_loss: 1.1113
# Epoch 22/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - accuracy: 0.7367 - loss: 0.7328 - val_accuracy: 0.5940 - val_loss: 1.0981
# Epoch 23/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - accuracy: 0.7217 - loss: 0.7451 - val_accuracy: 0.5973 - val_loss: 1.1465
# Epoch 24/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 173ms/step - accuracy: 0.7182 - loss: 0.7573 - val_accuracy: 0.6074 - val_loss: 1.0687
# Epoch 25/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - accuracy: 0.7113 - loss: 0.7171 - val_accuracy: 0.6376 - val_loss: 1.0060
# Epoch 26/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 225ms/step - accuracy: 0.7402 - loss: 0.7022 - val_accuracy: 0.6242 - val_loss: 1.0859
# Epoch 27/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 232ms/step - accuracy: 0.7471 - loss: 0.6721 - val_accuracy: 0.5872 - val_loss: 1.1385
# Epoch 28/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - accuracy: 0.7436 - loss: 0.6840 - val_accuracy: 0.6242 - val_loss: 1.0576
# Epoch 29/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 254ms/step - accuracy: 0.7356 - loss: 0.6744 - val_accuracy: 0.6275 - val_loss: 1.0859
# Epoch 30/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 334ms/step - accuracy: 0.7621 - loss: 0.6386 - val_accuracy: 0.6141 - val_loss: 1.1245
# Epoch 31/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 227ms/step - accuracy: 0.7390 - loss: 0.6826 - val_accuracy: 0.6040 - val_loss: 1.0998
# Epoch 32/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 218ms/step - accuracy: 0.7379 - loss: 0.6479 - val_accuracy: 0.6174 - val_loss: 1.0798
# Epoch 33/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - accuracy: 0.7598 - loss: 0.6129 - val_accuracy: 0.6477 - val_loss: 1.0412
# Epoch 34/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - accuracy: 0.7667 - loss: 0.6098 - val_accuracy: 0.6007 - val_loss: 1.0877
# Epoch 35/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step - accuracy: 0.7656 - loss: 0.6145 - val_accuracy: 0.6644 - val_loss: 1.0494
# Epoch 36/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 172ms/step - accuracy: 0.7771 - loss: 0.6015 - val_accuracy: 0.6342 - val_loss: 1.1034
# Epoch 37/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - accuracy: 0.7633 - loss: 0.5588 - val_accuracy: 0.6107 - val_loss: 1.1160
# Epoch 38/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 170ms/step - accuracy: 0.7540 - loss: 0.5924 - val_accuracy: 0.6477 - val_loss: 0.9976
# Epoch 39/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 173ms/step - accuracy: 0.7979 - loss: 0.5321 - val_accuracy: 0.6443 - val_loss: 1.0388
# Epoch 40/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 172ms/step - accuracy: 0.7806 - loss: 0.5527 - val_accuracy: 0.6342 - val_loss: 1.0454
# Epoch 41/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 0.7864 - loss: 0.5617 - val_accuracy: 0.6376 - val_loss: 1.0682
# Epoch 42/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 292ms/step - accuracy: 0.7921 - loss: 0.5549 - val_accuracy: 0.6376 - val_loss: 1.0798
# Epoch 43/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 0.7841 - loss: 0.5425 - val_accuracy: 0.7047 - val_loss: 0.9886
# Epoch 44/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step - accuracy: 0.8048 - loss: 0.4801 - val_accuracy: 0.6309 - val_loss: 1.1047
# Epoch 45/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 172ms/step - accuracy: 0.8118 - loss: 0.5104 - val_accuracy: 0.6879 - val_loss: 1.0432
# Epoch 46/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - accuracy: 0.7956 - loss: 0.4973 - val_accuracy: 0.7047 - val_loss: 0.9913
# Epoch 47/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - accuracy: 0.7979 - loss: 0.5248 - val_accuracy: 0.6779 - val_loss: 1.0971
# Epoch 48/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 0.8118 - loss: 0.4969 - val_accuracy: 0.7047 - val_loss: 1.0759
# Epoch 49/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.7898 - loss: 0.5031 - val_accuracy: 0.7013 - val_loss: 1.0333
# Epoch 50/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - accuracy: 0.7829 - loss: 0.5108 - val_accuracy: 0.7383 - val_loss: 0.9591
# Epoch 51/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - accuracy: 0.8245 - loss: 0.4263 - val_accuracy: 0.7114 - val_loss: 1.0931
# Epoch 52/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - accuracy: 0.8129 - loss: 0.4767 - val_accuracy: 0.6477 - val_loss: 1.1284
# Epoch 53/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - accuracy: 0.8095 - loss: 0.4825 - val_accuracy: 0.6745 - val_loss: 1.0778
# Epoch 54/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - accuracy: 0.8176 - loss: 0.4660 - val_accuracy: 0.7148 - val_loss: 1.0351
# Epoch 55/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 282ms/step - accuracy: 0.8187 - loss: 0.4533 - val_accuracy: 0.6678 - val_loss: 1.0692
# Epoch 56/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.8210 - loss: 0.4250 - val_accuracy: 0.6879 - val_loss: 1.0747
# Epoch 57/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - accuracy: 0.8199 - loss: 0.4429 - val_accuracy: 0.7114 - val_loss: 1.1760
# Epoch 58/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - accuracy: 0.8256 - loss: 0.4464 - val_accuracy: 0.6678 - val_loss: 1.0630
# Epoch 59/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - accuracy: 0.8441 - loss: 0.4325 - val_accuracy: 0.6980 - val_loss: 1.0648
# Epoch 60/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 172ms/step - accuracy: 0.8256 - loss: 0.4696 - val_accuracy: 0.7081 - val_loss: 1.0641
# Epoch 61/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - accuracy: 0.8349 - loss: 0.4326 - val_accuracy: 0.7013 - val_loss: 1.0479
# Epoch 62/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 0.8349 - loss: 0.4279 - val_accuracy: 0.7013 - val_loss: 1.1249
# Epoch 63/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - accuracy: 0.8279 - loss: 0.4433 - val_accuracy: 0.6745 - val_loss: 1.1618
# Epoch 64/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 177ms/step - accuracy: 0.8233 - loss: 0.4105 - val_accuracy: 0.7248 - val_loss: 1.0378
# Epoch 65/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 177ms/step - accuracy: 0.8279 - loss: 0.4451 - val_accuracy: 0.6846 - val_loss: 1.1266
# Epoch 65: early stopping
# Restoring model weights from the end of the best epoch: 50.
# WARNING - 5 out of the last 18 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f27b3fd1580> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# INFO - Saved metrics to /mnt/d/Graduation_Project/ai-virtual-coach/experiments/exer_recog/results/exp_07_pose_lstm_temporal/front/multi_run_001/run_004/metrics.json
# INFO - Experiment 7 (LSTM temporal) complete. Test acc=0.6707, macro F1=0.6051
# INFO - Run 4 complete: acc=0.6707, macro_f1=0.6051
# INFO -
# ================================================================================
# INFO - Starting run 5/30 (seed=47)
# INFO - ================================================================================
# INFO - Configuration loaded from /mnt/d/Graduation_Project/ai-virtual-coach/config/experiment_7_temporal_front.yaml
# INFO - Global random seed set to: 47
# INFO - [load_pose_temporal_data] Loaded 1574 samples (49 subjects, 15 classes) from front view, temporal shape: (50, 9)
# INFO - Filtered temporal features for LSTM: 8 angles selected (left_elbow, right_elbow, left_shoulder, right_shoulder, left_hip, right_hip, left_knee, right_knee) -> shape (50, 8)
# INFO - Using selected angles: ['left_elbow', 'right_elbow', 'left_shoulder', 'right_shoulder', 'left_hip', 'right_hip', 'left_knee', 'right_knee']
# INFO - Found 49 unique subject identities
# INFO - Subject split: 25 train, 10 val, 14 test subjects
# INFO - Sample split: 921 train, 195 val, 458 test samples
# INFO - Created label mapping for 15 classes
# INFO - Pose split (3-way): train=921, val=195, test=458
# INFO - Number of pose classes: 15
# Epoch 1/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 286ms/step - accuracy: 0.1455 - loss: 2.6293 - val_accuracy: 0.3128 - val_loss: 2.4241
# Epoch 2/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - accuracy: 0.2964 - loss: 2.3526 - val_accuracy: 0.4000 - val_loss: 2.2232
# Epoch 3/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - accuracy: 0.3550 - loss: 2.1103 - val_accuracy: 0.3744 - val_loss: 1.9820
# Epoch 4/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - accuracy: 0.4093 - loss: 1.8860 - val_accuracy: 0.4923 - val_loss: 1.7613
# Epoch 5/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - accuracy: 0.4799 - loss: 1.6455 - val_accuracy: 0.5077 - val_loss: 1.5597
# Epoch 6/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - accuracy: 0.5223 - loss: 1.4894 - val_accuracy: 0.5692 - val_loss: 1.4553
# Epoch 7/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - accuracy: 0.5635 - loss: 1.3421 - val_accuracy: 0.5436 - val_loss: 1.4222
# Epoch 8/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - accuracy: 0.5635 - loss: 1.2389 - val_accuracy: 0.5590 - val_loss: 1.3136
# Epoch 9/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - accuracy: 0.6200 - loss: 1.1774 - val_accuracy: 0.5846 - val_loss: 1.2238
# Epoch 10/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - accuracy: 0.6178 - loss: 1.0999 - val_accuracy: 0.5744 - val_loss: 1.3621
# Epoch 11/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - accuracy: 0.6287 - loss: 1.0490 - val_accuracy: 0.5641 - val_loss: 1.2859
# Epoch 12/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - accuracy: 0.6363 - loss: 1.0273 - val_accuracy: 0.6462 - val_loss: 1.2252
# Epoch 13/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - accuracy: 0.6580 - loss: 0.9431 - val_accuracy: 0.5897 - val_loss: 1.1816
# Epoch 14/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 264ms/step - accuracy: 0.6569 - loss: 0.9474 - val_accuracy: 0.5897 - val_loss: 1.2115
# Epoch 15/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 175ms/step - accuracy: 0.6623 - loss: 0.9203 - val_accuracy: 0.5795 - val_loss: 1.2435
# Epoch 16/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 178ms/step - accuracy: 0.6699 - loss: 0.9095 - val_accuracy: 0.6000 - val_loss: 1.2000
# Epoch 17/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - accuracy: 0.6580 - loss: 0.9282 - val_accuracy: 0.5897 - val_loss: 1.2635
# Epoch 18/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - accuracy: 0.7003 - loss: 0.8566 - val_accuracy: 0.5692 - val_loss: 1.2653
# Epoch 19/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - accuracy: 0.6992 - loss: 0.8313 - val_accuracy: 0.5846 - val_loss: 1.1873
# Epoch 20/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - accuracy: 0.6971 - loss: 0.8341 - val_accuracy: 0.6000 - val_loss: 1.2566
# Epoch 21/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - accuracy: 0.7112 - loss: 0.7535 - val_accuracy: 0.6051 - val_loss: 1.2294
# Epoch 22/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - accuracy: 0.6982 - loss: 0.7904 - val_accuracy: 0.5897 - val_loss: 1.3267
# Epoch 23/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - accuracy: 0.7394 - loss: 0.7439 - val_accuracy: 0.6205 - val_loss: 1.2436
# Epoch 24/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - accuracy: 0.7058 - loss: 0.7698 - val_accuracy: 0.6000 - val_loss: 1.2929
# Epoch 25/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - accuracy: 0.7340 - loss: 0.7291 - val_accuracy: 0.5949 - val_loss: 1.2330
# Epoch 26/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 261ms/step - accuracy: 0.7318 - loss: 0.7297 - val_accuracy: 0.6103 - val_loss: 1.1851
# Epoch 27/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - accuracy: 0.7405 - loss: 0.6826 - val_accuracy: 0.6308 - val_loss: 1.1070
# Epoch 28/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 178ms/step - accuracy: 0.7579 - loss: 0.6509 - val_accuracy: 0.5846 - val_loss: 1.2000
# Epoch 29/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - accuracy: 0.7850 - loss: 0.6227 - val_accuracy: 0.6462 - val_loss: 1.2024
# Epoch 30/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - accuracy: 0.7687 - loss: 0.6300 - val_accuracy: 0.6103 - val_loss: 1.2113
# Epoch 31/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - accuracy: 0.7470 - loss: 0.6703 - val_accuracy: 0.6462 - val_loss: 1.1983
# Epoch 32/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - accuracy: 0.7785 - loss: 0.6123 - val_accuracy: 0.6667 - val_loss: 1.1220
# Epoch 33/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - accuracy: 0.7622 - loss: 0.6204 - val_accuracy: 0.6359 - val_loss: 1.2201
# Epoch 34/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - accuracy: 0.7883 - loss: 0.5886 - val_accuracy: 0.6872 - val_loss: 1.2036
# Epoch 35/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - accuracy: 0.7698 - loss: 0.5781 - val_accuracy: 0.6564 - val_loss: 1.2198
# Epoch 36/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.7850 - loss: 0.5677 - val_accuracy: 0.6103 - val_loss: 1.1699
# Epoch 37/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - accuracy: 0.7980 - loss: 0.5578 - val_accuracy: 0.6308 - val_loss: 1.2752
# Epoch 38/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 263ms/step - accuracy: 0.7872 - loss: 0.5671 - val_accuracy: 0.6718 - val_loss: 1.2183
# Epoch 39/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - accuracy: 0.8002 - loss: 0.5635 - val_accuracy: 0.6256 - val_loss: 1.1711
# Epoch 40/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - accuracy: 0.8046 - loss: 0.5353 - val_accuracy: 0.6923 - val_loss: 1.1536
# Epoch 41/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - accuracy: 0.7970 - loss: 0.5411 - val_accuracy: 0.6667 - val_loss: 1.1971
# Epoch 42/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 178ms/step - accuracy: 0.8002 - loss: 0.5673 - val_accuracy: 0.6769 - val_loss: 1.2536
# Epoch 43/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - accuracy: 0.7894 - loss: 0.5223 - val_accuracy: 0.6256 - val_loss: 1.2355
# Epoch 44/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - accuracy: 0.7959 - loss: 0.5417 - val_accuracy: 0.5897 - val_loss: 1.3131
# Epoch 45/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 163ms/step - accuracy: 0.7959 - loss: 0.5561 - val_accuracy: 0.6667 - val_loss: 1.1987
# Epoch 46/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - accuracy: 0.8002 - loss: 0.5163 - val_accuracy: 0.7077 - val_loss: 1.2091
# Epoch 47/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - accuracy: 0.8067 - loss: 0.4964 - val_accuracy: 0.7026 - val_loss: 1.2530
# Epoch 48/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - accuracy: 0.8241 - loss: 0.4799 - val_accuracy: 0.6615 - val_loss: 1.2117
# Epoch 49/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - accuracy: 0.8187 - loss: 0.4676 - val_accuracy: 0.6615 - val_loss: 1.3377
# Epoch 50/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - accuracy: 0.8100 - loss: 0.4700 - val_accuracy: 0.6872 - val_loss: 1.2977
# Epoch 51/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 261ms/step - accuracy: 0.8100 - loss: 0.5409 - val_accuracy: 0.6769 - val_loss: 1.3065
# Epoch 52/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - accuracy: 0.8165 - loss: 0.4919 - val_accuracy: 0.6923 - val_loss: 1.1895
# Epoch 53/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 163ms/step - accuracy: 0.8295 - loss: 0.4860 - val_accuracy: 0.6974 - val_loss: 1.1462
# Epoch 54/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - accuracy: 0.8154 - loss: 0.4699 - val_accuracy: 0.6974 - val_loss: 1.2442
# Epoch 55/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - accuracy: 0.8360 - loss: 0.4342 - val_accuracy: 0.6821 - val_loss: 1.2240
# Epoch 56/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - accuracy: 0.8263 - loss: 0.4498 - val_accuracy: 0.6410 - val_loss: 1.1506
# Epoch 57/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - accuracy: 0.8111 - loss: 0.4797 - val_accuracy: 0.6974 - val_loss: 1.2548
# Epoch 57: early stopping
# Restoring model weights from the end of the best epoch: 27.
# WARNING - 5 out of the last 16 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f27b3bb2480> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# INFO - Saved metrics to /mnt/d/Graduation_Project/ai-virtual-coach/experiments/exer_recog/results/exp_07_pose_lstm_temporal/front/multi_run_001/run_005/metrics.json
# INFO - Experiment 7 (LSTM temporal) complete. Test acc=0.6878, macro F1=0.6848
# INFO - Run 5 complete: acc=0.6878, macro_f1=0.6848
# INFO -
# ================================================================================
# INFO - Starting run 6/30 (seed=48)
# INFO - ================================================================================
# INFO - Configuration loaded from /mnt/d/Graduation_Project/ai-virtual-coach/config/experiment_7_temporal_front.yaml
# INFO - Global random seed set to: 48
# INFO - [load_pose_temporal_data] Loaded 1574 samples (49 subjects, 15 classes) from front view, temporal shape: (50, 9)
# INFO - Filtered temporal features for LSTM: 8 angles selected (left_elbow, right_elbow, left_shoulder, right_shoulder, left_hip, right_hip, left_knee, right_knee) -> shape (50, 8)
# INFO - Using selected angles: ['left_elbow', 'right_elbow', 'left_shoulder', 'right_shoulder', 'left_hip', 'right_hip', 'left_knee', 'right_knee']
# INFO - Found 49 unique subject identities
# INFO - Subject split: 25 train, 10 val, 14 test subjects
# INFO - Sample split: 921 train, 264 val, 389 test samples
# INFO - Created label mapping for 15 classes
# INFO - Pose split (3-way): train=921, val=264, test=389
# INFO - Number of pose classes: 15
# Epoch 1/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.2020 - loss: 2.5984 - val_accuracy: 0.3939 - val_loss: 2.4144
# Epoch 2/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - accuracy: 0.3377 - loss: 2.3248 - val_accuracy: 0.4886 - val_loss: 2.1366
# Epoch 3/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - accuracy: 0.3637 - loss: 2.0490 - val_accuracy: 0.4697 - val_loss: 1.8460
# Epoch 4/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 175ms/step - accuracy: 0.4245 - loss: 1.7667 - val_accuracy: 0.4773 - val_loss: 1.5305
# Epoch 5/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 281ms/step - accuracy: 0.4647 - loss: 1.6020 - val_accuracy: 0.5682 - val_loss: 1.3391
# Epoch 6/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - accuracy: 0.5092 - loss: 1.4583 - val_accuracy: 0.6136 - val_loss: 1.2399
# Epoch 7/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - accuracy: 0.5472 - loss: 1.3342 - val_accuracy: 0.5909 - val_loss: 1.1067
# Epoch 8/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - accuracy: 0.5809 - loss: 1.2054 - val_accuracy: 0.6742 - val_loss: 0.9791
# Epoch 9/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - accuracy: 0.5993 - loss: 1.1891 - val_accuracy: 0.6629 - val_loss: 0.9558
# Epoch 10/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 176ms/step - accuracy: 0.6048 - loss: 1.1263 - val_accuracy: 0.6591 - val_loss: 0.9627
# Epoch 11/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - accuracy: 0.6265 - loss: 1.1049 - val_accuracy: 0.6591 - val_loss: 1.0075
# Epoch 12/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 0.6384 - loss: 1.0259 - val_accuracy: 0.6364 - val_loss: 0.9585
# Epoch 13/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - accuracy: 0.6200 - loss: 1.0259 - val_accuracy: 0.6705 - val_loss: 0.9977
# Epoch 14/80
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - accuracy: 0.6319 - loss: 1.0083 - val_accuracy: 0.6326 - val_loss: 0.9588
# Epoch 15/80
# ...
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 148ms/step - accuracy: 0.8078 - loss: 0.5306 - val_accuracy: 0.6763 - val_loss: 1.1903
# Epoch 38/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 0.8212 - loss: 0.5088 - val_accuracy: 0.6994 - val_loss: 1.1089
# Epoch 39/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 149ms/step - accuracy: 0.7955 - loss: 0.5444 - val_accuracy: 0.6763 - val_loss: 1.1768
# Epoch 40/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 146ms/step - accuracy: 0.8171 - loss: 0.5147 - val_accuracy: 0.7110 - val_loss: 1.0989
# Epoch 41/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 147ms/step - accuracy: 0.8140 - loss: 0.5212 - val_accuracy: 0.7052 - val_loss: 1.1341
# Epoch 42/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 0.8129 - loss: 0.4852 - val_accuracy: 0.6705 - val_loss: 1.1576
# Epoch 43/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - accuracy: 0.8314 - loss: 0.4613 - val_accuracy: 0.7052 - val_loss: 1.1284
# Epoch 44/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 155ms/step - accuracy: 0.7934 - loss: 0.5196 - val_accuracy: 0.6821 - val_loss: 1.1920
# Epoch 45/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 258ms/step - accuracy: 0.8191 - loss: 0.4989 - val_accuracy: 0.6936 - val_loss: 1.1206
# Epoch 46/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 154ms/step - accuracy: 0.8027 - loss: 0.4805 - val_accuracy: 0.6936 - val_loss: 1.1882
# Epoch 47/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 0.8201 - loss: 0.4618 - val_accuracy: 0.6705 - val_loss: 1.2028
# Epoch 48/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - accuracy: 0.8294 - loss: 0.4529 - val_accuracy: 0.7052 - val_loss: 1.0579
# Epoch 49/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - accuracy: 0.8201 - loss: 0.4523 - val_accuracy: 0.6590 - val_loss: 1.1744
# Epoch 50/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 147ms/step - accuracy: 0.8397 - loss: 0.4266 - val_accuracy: 0.6994 - val_loss: 1.2089
# Epoch 51/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 149ms/step - accuracy: 0.8376 - loss: 0.4384 - val_accuracy: 0.6821 - val_loss: 1.1231
# Epoch 52/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 150ms/step - accuracy: 0.8345 - loss: 0.4486 - val_accuracy: 0.6936 - val_loss: 1.1311
# Epoch 53/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 147ms/step - accuracy: 0.8212 - loss: 0.4602 - val_accuracy: 0.6821 - val_loss: 1.1378
# Epoch 54/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 147ms/step - accuracy: 0.8448 - loss: 0.4181 - val_accuracy: 0.6705 - val_loss: 1.1566
# Epoch 55/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 146ms/step - accuracy: 0.8397 - loss: 0.4437 - val_accuracy: 0.6705 - val_loss: 1.2184
# Epoch 56/80
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 0.8356 - loss: 0.4426 - val_accuracy: 0.6879 - val_loss: 1.1121
# Epoch 56: early stopping
# Restoring model weights from the end of the best epoch: 26.
# INFO - Saved metrics to /mnt/d/Graduation_Project/ai-virtual-coach/experiments/exer_recog/results/exp_07_pose_lstm_temporal/front/multi_run_001/run_029/metrics.json
# INFO - Experiment 7 (LSTM temporal) complete. Test acc=0.6612, macro F1=0.6295
# INFO - Run 29 complete: acc=0.6612, macro_f1=0.6295
# INFO -
# ================================================================================
# INFO - Starting run 30/30 (seed=72)
# INFO - ================================================================================
# INFO - Configuration loaded from /mnt/d/Graduation_Project/ai-virtual-coach/config/experiment_7_temporal_front.yaml
# INFO - Global random seed set to: 72
# INFO - [load_pose_temporal_data] Loaded 1574 samples (49 subjects, 15 classes) from front view, temporal shape: (50, 9)
# INFO - Filtered temporal features for LSTM: 8 angles selected (left_elbow, right_elbow, left_shoulder, right_shoulder, left_hip, right_hip, left_knee, right_knee) -> shape (50, 8)
# INFO - Using selected angles: ['left_elbow', 'right_elbow', 'left_shoulder', 'right_shoulder', 'left_hip', 'right_hip', 'left_knee', 'right_knee']
# INFO - Found 49 unique subject identities
# INFO - Subject split: 25 train, 10 val, 14 test subjects
# INFO - Sample split: 868 train, 264 val, 442 test samples
# INFO - Created label mapping for 15 classes
# INFO - Pose split (3-way): train=868, val=264, test=442
# INFO - Number of pose classes: 15
# Epoch 1/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 297ms/step - accuracy: 0.1624 - loss: 2.5836 - val_accuracy: 0.2045 - val_loss: 2.4106
# Epoch 2/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 169ms/step - accuracy: 0.2431 - loss: 2.3291 - val_accuracy: 0.2689 - val_loss: 2.1474
# Epoch 3/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - accuracy: 0.3065 - loss: 2.0969 - val_accuracy: 0.2386 - val_loss: 1.9583
# Epoch 4/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 154ms/step - accuracy: 0.3468 - loss: 1.9237 - val_accuracy: 0.3939 - val_loss: 1.7679
# Epoch 5/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 0.4055 - loss: 1.7756 - val_accuracy: 0.4886 - val_loss: 1.6110
# Epoch 6/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.4816 - loss: 1.5925 - val_accuracy: 0.5985 - val_loss: 1.4034
# Epoch 7/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.4931 - loss: 1.4938 - val_accuracy: 0.6250 - val_loss: 1.3003
# Epoch 8/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.5346 - loss: 1.4197 - val_accuracy: 0.6705 - val_loss: 1.2009
# Epoch 9/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.5438 - loss: 1.2711 - val_accuracy: 0.6477 - val_loss: 1.1385
# Epoch 10/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.5876 - loss: 1.2319 - val_accuracy: 0.7348 - val_loss: 1.0568
# Epoch 11/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.5991 - loss: 1.1650 - val_accuracy: 0.7311 - val_loss: 1.0074
# Epoch 12/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.6210 - loss: 1.0514 - val_accuracy: 0.7083 - val_loss: 0.9791
# Epoch 13/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 0.6336 - loss: 1.0115 - val_accuracy: 0.7386 - val_loss: 0.9444
# Epoch 14/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - accuracy: 0.6440 - loss: 0.9687 - val_accuracy: 0.7576 - val_loss: 0.9308
# Epoch 15/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 258ms/step - accuracy: 0.6590 - loss: 0.9874 - val_accuracy: 0.7348 - val_loss: 0.9005
# Epoch 16/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.6832 - loss: 0.8938 - val_accuracy: 0.7538 - val_loss: 0.9290
# Epoch 17/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.6809 - loss: 0.8975 - val_accuracy: 0.7576 - val_loss: 0.8961
# Epoch 18/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 167ms/step - accuracy: 0.7177 - loss: 0.8320 - val_accuracy: 0.7462 - val_loss: 0.8708
# Epoch 19/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 156ms/step - accuracy: 0.7143 - loss: 0.7959 - val_accuracy: 0.7424 - val_loss: 0.8286
# Epoch 20/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7154 - loss: 0.8074 - val_accuracy: 0.7652 - val_loss: 0.8869
# Epoch 21/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 163ms/step - accuracy: 0.7108 - loss: 0.8130 - val_accuracy: 0.7538 - val_loss: 0.8893
# Epoch 22/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.7500 - loss: 0.7327 - val_accuracy: 0.7652 - val_loss: 0.8829
# Epoch 23/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - accuracy: 0.7166 - loss: 0.7669 - val_accuracy: 0.7614 - val_loss: 0.8624
# Epoch 24/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7362 - loss: 0.7006 - val_accuracy: 0.7576 - val_loss: 0.8820
# Epoch 25/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 0.7304 - loss: 0.7471 - val_accuracy: 0.7500 - val_loss: 0.8877
# Epoch 26/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7408 - loss: 0.7121 - val_accuracy: 0.7311 - val_loss: 0.9501
# Epoch 27/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.7189 - loss: 0.7327 - val_accuracy: 0.7462 - val_loss: 0.9397
# Epoch 28/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 181ms/step - accuracy: 0.7500 - loss: 0.6632 - val_accuracy: 0.7614 - val_loss: 0.9498
# Epoch 29/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 240ms/step - accuracy: 0.7627 - loss: 0.6909 - val_accuracy: 0.7500 - val_loss: 0.9831
# Epoch 30/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7535 - loss: 0.6549 - val_accuracy: 0.7614 - val_loss: 0.9730
# Epoch 31/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.7569 - loss: 0.6694 - val_accuracy: 0.7500 - val_loss: 0.9209
# Epoch 32/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.7650 - loss: 0.6628 - val_accuracy: 0.7614 - val_loss: 0.8839
# Epoch 33/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7730 - loss: 0.6403 - val_accuracy: 0.7576 - val_loss: 0.8722
# Epoch 34/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.7742 - loss: 0.5987 - val_accuracy: 0.7727 - val_loss: 0.8513
# Epoch 35/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.7892 - loss: 0.6056 - val_accuracy: 0.7386 - val_loss: 0.8979
# Epoch 36/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.7823 - loss: 0.5782 - val_accuracy: 0.7689 - val_loss: 0.9378
# Epoch 37/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - accuracy: 0.7800 - loss: 0.5751 - val_accuracy: 0.7689 - val_loss: 0.9166
# Epoch 38/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - accuracy: 0.7753 - loss: 0.6087 - val_accuracy: 0.7083 - val_loss: 0.9276
# Epoch 39/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - accuracy: 0.7915 - loss: 0.5874 - val_accuracy: 0.7765 - val_loss: 0.8723
# Epoch 40/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - accuracy: 0.7892 - loss: 0.5763 - val_accuracy: 0.7614 - val_loss: 0.9432
# Epoch 41/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 168ms/step - accuracy: 0.8007 - loss: 0.5497 - val_accuracy: 0.7235 - val_loss: 0.9232
# Epoch 42/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 178ms/step - accuracy: 0.8191 - loss: 0.5316 - val_accuracy: 0.7348 - val_loss: 0.8123
# Epoch 43/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 261ms/step - accuracy: 0.8145 - loss: 0.5345 - val_accuracy: 0.7879 - val_loss: 0.7736
# Epoch 44/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 168ms/step - accuracy: 0.8053 - loss: 0.5396 - val_accuracy: 0.7727 - val_loss: 0.9207
# Epoch 45/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - accuracy: 0.8007 - loss: 0.5400 - val_accuracy: 0.7500 - val_loss: 0.9521
# Epoch 46/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - accuracy: 0.8214 - loss: 0.5069 - val_accuracy: 0.7424 - val_loss: 0.9412
# Epoch 47/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - accuracy: 0.8237 - loss: 0.4795 - val_accuracy: 0.7576 - val_loss: 0.8567
# Epoch 48/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.8134 - loss: 0.5152 - val_accuracy: 0.7652 - val_loss: 0.8819
# Epoch 49/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - accuracy: 0.8226 - loss: 0.4903 - val_accuracy: 0.7538 - val_loss: 0.8965
# Epoch 50/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - accuracy: 0.8099 - loss: 0.5237 - val_accuracy: 0.7803 - val_loss: 0.7849
# Epoch 51/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 166ms/step - accuracy: 0.8364 - loss: 0.4639 - val_accuracy: 0.7879 - val_loss: 0.7976
# Epoch 52/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - accuracy: 0.8226 - loss: 0.4637 - val_accuracy: 0.7879 - val_loss: 0.8035
# Epoch 53/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 0.8353 - loss: 0.4904 - val_accuracy: 0.7955 - val_loss: 0.7963
# Epoch 54/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 163ms/step - accuracy: 0.8260 - loss: 0.4886 - val_accuracy: 0.7689 - val_loss: 0.8573
# Epoch 55/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - accuracy: 0.8272 - loss: 0.4399 - val_accuracy: 0.7727 - val_loss: 0.8408
# Epoch 56/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 169ms/step - accuracy: 0.8491 - loss: 0.4236 - val_accuracy: 0.7803 - val_loss: 0.8677
# Epoch 57/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 258ms/step - accuracy: 0.8456 - loss: 0.4474 - val_accuracy: 0.8030 - val_loss: 0.8830
# Epoch 58/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - accuracy: 0.8226 - loss: 0.4548 - val_accuracy: 0.7727 - val_loss: 0.8748
# Epoch 59/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.8318 - loss: 0.4514 - val_accuracy: 0.7955 - val_loss: 0.7870
# Epoch 60/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 0.8525 - loss: 0.3996 - val_accuracy: 0.7955 - val_loss: 0.8047
# Epoch 61/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.8629 - loss: 0.3841 - val_accuracy: 0.7803 - val_loss: 0.8421
# Epoch 62/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 163ms/step - accuracy: 0.8295 - loss: 0.4569 - val_accuracy: 0.7841 - val_loss: 0.7624
# Epoch 63/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.8376 - loss: 0.4353 - val_accuracy: 0.7727 - val_loss: 0.8532
# Epoch 64/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - accuracy: 0.8364 - loss: 0.4245 - val_accuracy: 0.7727 - val_loss: 0.8140
# Epoch 65/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - accuracy: 0.8399 - loss: 0.4414 - val_accuracy: 0.7955 - val_loss: 0.7901
# Epoch 66/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 155ms/step - accuracy: 0.8376 - loss: 0.4480 - val_accuracy: 0.7879 - val_loss: 0.8440
# Epoch 67/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 155ms/step - accuracy: 0.8583 - loss: 0.4155 - val_accuracy: 0.7727 - val_loss: 0.7782
# Epoch 68/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.8560 - loss: 0.4007 - val_accuracy: 0.7917 - val_loss: 0.7815
# Epoch 69/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - accuracy: 0.8456 - loss: 0.4351 - val_accuracy: 0.7803 - val_loss: 0.8208
# Epoch 70/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.8514 - loss: 0.3913 - val_accuracy: 0.7955 - val_loss: 0.8390
# Epoch 71/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - accuracy: 0.8548 - loss: 0.4068 - val_accuracy: 0.7803 - val_loss: 0.8953
# Epoch 72/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8502 - loss: 0.3783 - val_accuracy: 0.7727 - val_loss: 0.9829
# Epoch 73/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.8571 - loss: 0.3814 - val_accuracy: 0.7689 - val_loss: 0.9182
# Epoch 74/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 155ms/step - accuracy: 0.8583 - loss: 0.4040 - val_accuracy: 0.7614 - val_loss: 0.9101
# Epoch 75/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.8479 - loss: 0.4062 - val_accuracy: 0.7841 - val_loss: 0.8814
# Epoch 76/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8537 - loss: 0.3948 - val_accuracy: 0.7652 - val_loss: 0.9105
# Epoch 77/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.8571 - loss: 0.3718 - val_accuracy: 0.7652 - val_loss: 0.9444
# Epoch 78/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 156ms/step - accuracy: 0.8710 - loss: 0.3885 - val_accuracy: 0.7689 - val_loss: 0.9258
# Epoch 79/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - accuracy: 0.8687 - loss: 0.3590 - val_accuracy: 0.7689 - val_loss: 0.9569
# Epoch 80/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.8629 - loss: 0.3689 - val_accuracy: 0.7689 - val_loss: 0.8998
# Restoring model weights from the end of the best epoch: 62.
# INFO - Saved metrics to /mnt/d/Graduation_Project/ai-virtual-coach/experiments/exer_recog/results/exp_07_pose_lstm_temporal/front/multi_run_001/run_030/metrics.json
# INFO - Experiment 7 (LSTM temporal) complete. Test acc=0.7398, macro F1=0.7257
# INFO - Run 30 complete: acc=0.7398, macro_f1=0.7257
# INFO -
# ================================================================================
# INFO - Computing aggregated statistics across 30 runs
# INFO - ================================================================================
# INFO - Saved aggregated stats to /mnt/d/Graduation_Project/ai-virtual-coach/experiments/exer_recog/results/exp_07_pose_lstm_temporal/front/multi_run_001/aggregated_stats.json
# INFO - Saved summary to /mnt/d/Graduation_Project/ai-virtual-coach/experiments/exer_recog/results/exp_07_pose_lstm_temporal/front/multi_run_001/aggregated_summary.txt
# INFO - Saved all run results to /mnt/d/Graduation_Project/ai-virtual-coach/experiments/exer_recog/results/exp_07_pose_lstm_temporal/front/multi_run_001/all_runs.json
# INFO -
# ================================================================================
# INFO - MULTI-RUN EXPERIMENT 7 (LSTM TEMPORAL) COMPLETE
# INFO - ================================================================================
# INFO - Test Accuracy: 0.6818 ± 0.0455
# INFO - Test Macro F1: 0.6514 ± 0.0560
# INFO - Results saved to: /mnt/d/Graduation_Project/ai-virtual-coach/experiments/exer_recog/results/exp_07_pose_lstm_temporal/front/multi_run_001
# INFO - ================================================================================

# %% [markdown]
# ### Temporal Front Results Analysis

# %%
# Display aggregated statistics
print("=" * 60)
print("TEMPORAL FRONT LSTM - Multi-Run Results (30 runs)")
print("=" * 60)
print(f"Test Accuracy: {aggregated_stats_temporal_front['test_accuracy']['mean']:.4f} ± {aggregated_stats_temporal_front['test_accuracy']['std']:.4f}")
print(f"Test Macro F1: {aggregated_stats_temporal_front['test_macro_f1']['mean']:.4f} ± {aggregated_stats_temporal_front['test_macro_f1']['std']:.4f}")
print(f"Best Accuracy: {aggregated_stats_temporal_front['test_accuracy']['max']:.4f}")
print(f"Best Macro F1: {aggregated_stats_temporal_front['test_macro_f1']['max']:.4f}")

# %%
# Find best run by macro F1
best_run_temporal_front = max(multi_run_results_temporal_front, key=lambda x: x['test_metrics']['macro_f1'])
plot_training_history(best_run_temporal_front['history'], title="Temporal Front LSTM - Best Run Training History")

# %%
# Confusion matrix from best run
conf_matrix_temporal_front = np.array(best_run_temporal_front['test_metrics']['confusion_matrix'])
idx_to_label_temporal_front = best_run_temporal_front['int_to_label']
label_names_temporal_front = [idx_to_label_temporal_front[i] for i in range(len(idx_to_label_temporal_front))]

fig, ax = plt.subplots(figsize=(12, 10))
sns.heatmap(conf_matrix_temporal_front, annot=True, fmt='d', cmap='Blues',
            xticklabels=label_names_temporal_front, yticklabels=label_names_temporal_front, ax=ax)
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.set_title('Temporal Front LSTM - Confusion Matrix (Best Run)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Per-class F1 scores
per_class_f1_temporal_front = pd.Series(aggregated_stats_temporal_front['per_class_f1']).apply(
    lambda x: f"{x['mean']:.4f} ± {x['std']:.4f}"
)
per_class_f1_temporal_front.index = [idx_to_label_temporal_front[i] for i in per_class_f1_temporal_front.index]

summary_df_temporal_front = pd.DataFrame({
    'Mean F1 ± Std': per_class_f1_temporal_front
})
print("Per-Class F1 Scores (Temporal Front LSTM):")
print(summary_df_temporal_front.to_string())

# %% [markdown]
# ## 1.2 Side View - Temporal LSTM

# %%
# Run multi-run training for side temporal LSTM
os.chdir(PROJECT_ROOT)

multi_run_results_temporal_side, aggregated_stats_temporal_side = train_experiment_7_temporal_multi_run(
    npz_path=str(side_temporal_npz),
    config_path=str(config_path_temporal_side)
)

# %% [markdown]
# ### Temporal Side Results Analysis

# %%
# Display aggregated statistics
print("=" * 60)
print("TEMPORAL SIDE LSTM - Multi-Run Results (30 runs)")
print("=" * 60)
print(f"Test Accuracy: {aggregated_stats_temporal_side['test_accuracy']['mean']:.4f} ± {aggregated_stats_temporal_side['test_accuracy']['std']:.4f}")
print(f"Test Macro F1: {aggregated_stats_temporal_side['test_macro_f1']['mean']:.4f} ± {aggregated_stats_temporal_side['test_macro_f1']['std']:.4f}")
print(f"Best Accuracy: {aggregated_stats_temporal_side['test_accuracy']['max']:.4f}")
print(f"Best Macro F1: {aggregated_stats_temporal_side['test_macro_f1']['max']:.4f}")

# %%
# Find best run
best_run_temporal_side = max(multi_run_results_temporal_side, key=lambda x: x['test_metrics']['macro_f1'])
plot_training_history(best_run_temporal_side['history'], title="Temporal Side LSTM - Best Run Training History")

# %%
# Confusion matrix from best run
conf_matrix_temporal_side = np.array(best_run_temporal_side['test_metrics']['confusion_matrix'])
idx_to_label_temporal_side = best_run_temporal_side['int_to_label']
label_names_temporal_side = [idx_to_label_temporal_side[i] for i in range(len(idx_to_label_temporal_side))]

fig, ax = plt.subplots(figsize=(12, 10))
sns.heatmap(conf_matrix_temporal_side, annot=True, fmt='d', cmap='Greens',
            xticklabels=label_names_temporal_side, yticklabels=label_names_temporal_side, ax=ax)
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.set_title('Temporal Side LSTM - Confusion Matrix (Best Run)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Per-class F1 scores
per_class_f1_temporal_side = pd.Series(aggregated_stats_temporal_side['per_class_f1']).apply(
    lambda x: f"{x['mean']:.4f} ± {x['std']:.4f}"
)
per_class_f1_temporal_side.index = [idx_to_label_temporal_side[i] for i in per_class_f1_temporal_side.index]

summary_df_temporal_side = pd.DataFrame({
    'Mean F1 ± Std': per_class_f1_temporal_side
})
print("Per-Class F1 Scores (Temporal Side LSTM):")
print(summary_df_temporal_side.to_string())

# %% [markdown]
# ### Temporal Front vs Side Comparison

# %%
# Build comparison DataFrame for temporal models
comparison_df_temporal = pd.DataFrame({
    'Model': ['Temporal LSTM Front', 'Temporal LSTM Side'],
    'Test Accuracy (mean)': [
        aggregated_stats_temporal_front['test_accuracy']['mean'],
        aggregated_stats_temporal_side['test_accuracy']['mean']
    ],
    'Test Accuracy (std)': [
        aggregated_stats_temporal_front['test_accuracy']['std'],
        aggregated_stats_temporal_side['test_accuracy']['std']
    ],
    'Test Macro F1 (mean)': [
        aggregated_stats_temporal_front['test_macro_f1']['mean'],
        aggregated_stats_temporal_side['test_macro_f1']['mean']
    ],
    'Test Macro F1 (std)': [
        aggregated_stats_temporal_front['test_macro_f1']['std'],
        aggregated_stats_temporal_side['test_macro_f1']['std']
    ],
})

print("Temporal LSTM Models Comparison:")
print(comparison_df_temporal.to_string(index=False))

# %%
# Visualize temporal models comparison
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

models = ['Temporal Front', 'Temporal Side']
acc_means = [aggregated_stats_temporal_front['test_accuracy']['mean'],
             aggregated_stats_temporal_side['test_accuracy']['mean']]
acc_stds = [aggregated_stats_temporal_front['test_accuracy']['std'],
            aggregated_stats_temporal_side['test_accuracy']['std']]

f1_means = [aggregated_stats_temporal_front['test_macro_f1']['mean'],
            aggregated_stats_temporal_side['test_macro_f1']['mean']]
f1_stds = [aggregated_stats_temporal_front['test_macro_f1']['std'],
           aggregated_stats_temporal_side['test_macro_f1']['std']]

colors = ['steelblue', 'seagreen']

axes[0].bar(models, acc_means, yerr=acc_stds, capsize=5, color=colors, alpha=0.8)
axes[0].set_ylabel('Test Accuracy')
axes[0].set_title('Temporal LSTM - Accuracy Comparison')
axes[0].set_ylim(0, 1)

axes[1].bar(models, f1_means, yerr=f1_stds, capsize=5, color=colors, alpha=0.8)
axes[1].set_ylabel('Test Macro F1')
axes[1].set_title('Temporal LSTM - Macro F1 Comparison')
axes[1].set_ylim(0, 1)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# # Part 2: Static LSTM Training
#
# LSTM with reshaped static features.
#
# **Input shape:** `(N angles, 5 statistics)` where angles are treated as timesteps.

# %% [markdown]
# ## 2.1 Front View - Static LSTM

# %%
# Run multi-run training for front static LSTM
os.chdir(PROJECT_ROOT)

multi_run_results_static_front, aggregated_stats_static_front = train_experiment_7_static_multi_run(
    npz_path=str(front_static_npz),
    config_path=str(config_path_static_front)
)

# %% [markdown]
# ### Static Front Results Analysis

# %%
# Display aggregated statistics
print("=" * 60)
print("STATIC FRONT LSTM - Multi-Run Results (30 runs)")
print("=" * 60)
print(f"Test Accuracy: {aggregated_stats_static_front['test_accuracy']['mean']:.4f} ± {aggregated_stats_static_front['test_accuracy']['std']:.4f}")
print(f"Test Macro F1: {aggregated_stats_static_front['test_macro_f1']['mean']:.4f} ± {aggregated_stats_static_front['test_macro_f1']['std']:.4f}")
print(f"Best Accuracy: {aggregated_stats_static_front['test_accuracy']['max']:.4f}")
print(f"Best Macro F1: {aggregated_stats_static_front['test_macro_f1']['max']:.4f}")

# %%
# Find best run
best_run_static_front = max(multi_run_results_static_front, key=lambda x: x['test_metrics']['macro_f1'])
plot_training_history(best_run_static_front['history'], title="Static Front LSTM - Best Run Training History")

# %%
# Confusion matrix from best run
conf_matrix_static_front = np.array(best_run_static_front['test_metrics']['confusion_matrix'])
idx_to_label_static_front = best_run_static_front['int_to_label']
label_names_static_front = [idx_to_label_static_front[i] for i in range(len(idx_to_label_static_front))]

fig, ax = plt.subplots(figsize=(12, 10))
sns.heatmap(conf_matrix_static_front, annot=True, fmt='d', cmap='Oranges',
            xticklabels=label_names_static_front, yticklabels=label_names_static_front, ax=ax)
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.set_title('Static Front LSTM - Confusion Matrix (Best Run)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Per-class F1 scores
per_class_f1_static_front = pd.Series(aggregated_stats_static_front['per_class_f1']).apply(
    lambda x: f"{x['mean']:.4f} ± {x['std']:.4f}"
)
per_class_f1_static_front.index = [idx_to_label_static_front[i] for i in per_class_f1_static_front.index]

summary_df_static_front = pd.DataFrame({
    'Mean F1 ± Std': per_class_f1_static_front
})
print("Per-Class F1 Scores (Static Front LSTM):")
print(summary_df_static_front.to_string())

# %% [markdown]
# ## 2.2 Side View - Static LSTM

# %%
# Run multi-run training for side static LSTM
os.chdir(PROJECT_ROOT)

multi_run_results_static_side, aggregated_stats_static_side = train_experiment_7_static_multi_run(
    npz_path=str(side_static_npz),
    config_path=str(config_path_static_side)
)

# %% [markdown]
# ### Static Side Results Analysis

# %%
# Display aggregated statistics
print("=" * 60)
print("STATIC SIDE LSTM - Multi-Run Results (30 runs)")
print("=" * 60)
print(f"Test Accuracy: {aggregated_stats_static_side['test_accuracy']['mean']:.4f} ± {aggregated_stats_static_side['test_accuracy']['std']:.4f}")
print(f"Test Macro F1: {aggregated_stats_static_side['test_macro_f1']['mean']:.4f} ± {aggregated_stats_static_side['test_macro_f1']['std']:.4f}")
print(f"Best Accuracy: {aggregated_stats_static_side['test_accuracy']['max']:.4f}")
print(f"Best Macro F1: {aggregated_stats_static_side['test_macro_f1']['max']:.4f}")

# %%
# Find best run
best_run_static_side = max(multi_run_results_static_side, key=lambda x: x['test_metrics']['macro_f1'])
plot_training_history(best_run_static_side['history'], title="Static Side LSTM - Best Run Training History")

# %%
# Confusion matrix from best run
conf_matrix_static_side = np.array(best_run_static_side['test_metrics']['confusion_matrix'])
idx_to_label_static_side = best_run_static_side['int_to_label']
label_names_static_side = [idx_to_label_static_side[i] for i in range(len(idx_to_label_static_side))]

fig, ax = plt.subplots(figsize=(12, 10))
sns.heatmap(conf_matrix_static_side, annot=True, fmt='d', cmap='Purples',
            xticklabels=label_names_static_side, yticklabels=label_names_static_side, ax=ax)
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.set_title('Static Side LSTM - Confusion Matrix (Best Run)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Per-class F1 scores
per_class_f1_static_side = pd.Series(aggregated_stats_static_side['per_class_f1']).apply(
    lambda x: f"{x['mean']:.4f} ± {x['std']:.4f}"
)
per_class_f1_static_side.index = [idx_to_label_static_side[i] for i in per_class_f1_static_side.index]

summary_df_static_side = pd.DataFrame({
    'Mean F1 ± Std': per_class_f1_static_side
})
print("Per-Class F1 Scores (Static Side LSTM):")
print(summary_df_static_side.to_string())

# %% [markdown]
# ### Static Front vs Side Comparison

# %%
# Build comparison DataFrame for static models
comparison_df_static = pd.DataFrame({
    'Model': ['Static LSTM Front', 'Static LSTM Side'],
    'Test Accuracy (mean)': [
        aggregated_stats_static_front['test_accuracy']['mean'],
        aggregated_stats_static_side['test_accuracy']['mean']
    ],
    'Test Accuracy (std)': [
        aggregated_stats_static_front['test_accuracy']['std'],
        aggregated_stats_static_side['test_accuracy']['std']
    ],
    'Test Macro F1 (mean)': [
        aggregated_stats_static_front['test_macro_f1']['mean'],
        aggregated_stats_static_side['test_macro_f1']['mean']
    ],
    'Test Macro F1 (std)': [
        aggregated_stats_static_front['test_macro_f1']['std'],
        aggregated_stats_static_side['test_macro_f1']['std']
    ],
})

print("Static LSTM Models Comparison:")
print(comparison_df_static.to_string(index=False))

# %%
# Visualize static models comparison
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

models = ['Static Front', 'Static Side']
acc_means = [aggregated_stats_static_front['test_accuracy']['mean'],
             aggregated_stats_static_side['test_accuracy']['mean']]
acc_stds = [aggregated_stats_static_front['test_accuracy']['std'],
            aggregated_stats_static_side['test_accuracy']['std']]

f1_means = [aggregated_stats_static_front['test_macro_f1']['mean'],
            aggregated_stats_static_side['test_macro_f1']['mean']]
f1_stds = [aggregated_stats_static_front['test_macro_f1']['std'],
           aggregated_stats_static_side['test_macro_f1']['std']]

colors = ['darkorange', 'purple']

axes[0].bar(models, acc_means, yerr=acc_stds, capsize=5, color=colors, alpha=0.8)
axes[0].set_ylabel('Test Accuracy')
axes[0].set_title('Static LSTM - Accuracy Comparison')
axes[0].set_ylim(0, 1)

axes[1].bar(models, f1_means, yerr=f1_stds, capsize=5, color=colors, alpha=0.8)
axes[1].set_ylabel('Test Macro F1')
axes[1].set_title('Static LSTM - Macro F1 Comparison')
axes[1].set_ylim(0, 1)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# # Part 3: Comprehensive Comparison
#
# Compare all 4 LSTM models (Temporal Front, Temporal Side, Static Front, Static Side)

# %% [markdown]
# ## All Models Summary Table

# %%
# Comprehensive comparison table
all_models_stats = {
    'Temporal Front LSTM': aggregated_stats_temporal_front,
    'Temporal Side LSTM': aggregated_stats_temporal_side,
    'Static Front LSTM': aggregated_stats_static_front,
    'Static Side LSTM': aggregated_stats_static_side,
}

comparison_data = []
for model_name, stats in all_models_stats.items():
    comparison_data.append({
        'Model': model_name,
        'Test Accuracy (mean ± std)': f"{stats['test_accuracy']['mean']:.4f} ± {stats['test_accuracy']['std']:.4f}",
        'Test Macro F1 (mean ± std)': f"{stats['test_macro_f1']['mean']:.4f} ± {stats['test_macro_f1']['std']:.4f}",
        'Best Accuracy': f"{stats['test_accuracy']['max']:.4f}",
        'Best Macro F1': f"{stats['test_macro_f1']['max']:.4f}",
    })

comparison_df_all = pd.DataFrame(comparison_data)
print("=" * 100)
print("EXPERIMENT 7 - ALL LSTM MODELS COMPARISON")
print("=" * 100)
print(comparison_df_all.to_string(index=False))

# %%
# Identify best model
best_model_name = max(all_models_stats.keys(), 
                      key=lambda x: all_models_stats[x]['test_macro_f1']['mean'])
best_f1 = all_models_stats[best_model_name]['test_macro_f1']['mean']
best_f1_std = all_models_stats[best_model_name]['test_macro_f1']['std']

print(f"\n🏆 Best Model: {best_model_name}")
print(f"   Macro F1: {best_f1:.4f} ± {best_f1_std:.4f}")

# %% [markdown]
# ## All Models Bar Chart Comparison

# %%
# Comprehensive bar chart comparison
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

model_names = ['Temporal\nFront', 'Temporal\nSide', 'Static\nFront', 'Static\nSide']
colors = ['steelblue', 'seagreen', 'darkorange', 'purple']

# Accuracy comparison
acc_means = [
    aggregated_stats_temporal_front['test_accuracy']['mean'],
    aggregated_stats_temporal_side['test_accuracy']['mean'],
    aggregated_stats_static_front['test_accuracy']['mean'],
    aggregated_stats_static_side['test_accuracy']['mean']
]
acc_stds = [
    aggregated_stats_temporal_front['test_accuracy']['std'],
    aggregated_stats_temporal_side['test_accuracy']['std'],
    aggregated_stats_static_front['test_accuracy']['std'],
    aggregated_stats_static_side['test_accuracy']['std']
]

bars1 = axes[0].bar(model_names, acc_means, yerr=acc_stds, capsize=5, color=colors, alpha=0.8)
axes[0].set_ylabel('Test Accuracy', fontsize=12)
axes[0].set_title('All LSTM Models - Accuracy Comparison', fontsize=14)
axes[0].set_ylim(0, 1)
axes[0].axhline(y=max(acc_means), color='red', linestyle='--', alpha=0.5, label='Best')

# Add value labels
for bar, mean, std in zip(bars1, acc_means, acc_stds):
    axes[0].text(bar.get_x() + bar.get_width()/2, bar.get_height() + std + 0.02,
                 f'{mean:.3f}', ha='center', va='bottom', fontsize=10)

# Macro F1 comparison
f1_means = [
    aggregated_stats_temporal_front['test_macro_f1']['mean'],
    aggregated_stats_temporal_side['test_macro_f1']['mean'],
    aggregated_stats_static_front['test_macro_f1']['mean'],
    aggregated_stats_static_side['test_macro_f1']['mean']
]
f1_stds = [
    aggregated_stats_temporal_front['test_macro_f1']['std'],
    aggregated_stats_temporal_side['test_macro_f1']['std'],
    aggregated_stats_static_front['test_macro_f1']['std'],
    aggregated_stats_static_side['test_macro_f1']['std']
]

bars2 = axes[1].bar(model_names, f1_means, yerr=f1_stds, capsize=5, color=colors, alpha=0.8)
axes[1].set_ylabel('Test Macro F1', fontsize=12)
axes[1].set_title('All LSTM Models - Macro F1 Comparison', fontsize=14)
axes[1].set_ylim(0, 1)
axes[1].axhline(y=max(f1_means), color='red', linestyle='--', alpha=0.5, label='Best')

# Add value labels
for bar, mean, std in zip(bars2, f1_means, f1_stds):
    axes[1].text(bar.get_x() + bar.get_width()/2, bar.get_height() + std + 0.02,
                 f'{mean:.3f}', ha='center', va='bottom', fontsize=10)

plt.suptitle('Experiment 7: LSTM Models Comparison (30 runs each)', fontsize=16, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Temporal vs Static Comparison

# %%
# Grouped bar chart: Temporal vs Static per view
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

x = np.arange(2)  # Front, Side
width = 0.35

# Accuracy subplot
temporal_acc = [aggregated_stats_temporal_front['test_accuracy']['mean'],
                aggregated_stats_temporal_side['test_accuracy']['mean']]
static_acc = [aggregated_stats_static_front['test_accuracy']['mean'],
              aggregated_stats_static_side['test_accuracy']['mean']]

temporal_acc_std = [aggregated_stats_temporal_front['test_accuracy']['std'],
                    aggregated_stats_temporal_side['test_accuracy']['std']]
static_acc_std = [aggregated_stats_static_front['test_accuracy']['std'],
                  aggregated_stats_static_side['test_accuracy']['std']]

axes[0].bar(x - width/2, temporal_acc, width, yerr=temporal_acc_std, label='Temporal', capsize=5, color='steelblue')
axes[0].bar(x + width/2, static_acc, width, yerr=static_acc_std, label='Static', capsize=5, color='darkorange')
axes[0].set_xlabel('View')
axes[0].set_ylabel('Test Accuracy')
axes[0].set_title('Temporal vs Static - Accuracy')
axes[0].set_xticks(x)
axes[0].set_xticklabels(['Front', 'Side'])
axes[0].legend()
axes[0].set_ylim(0, 1)

# Macro F1 subplot
temporal_f1 = [aggregated_stats_temporal_front['test_macro_f1']['mean'],
               aggregated_stats_temporal_side['test_macro_f1']['mean']]
static_f1 = [aggregated_stats_static_front['test_macro_f1']['mean'],
             aggregated_stats_static_side['test_macro_f1']['mean']]

temporal_f1_std = [aggregated_stats_temporal_front['test_macro_f1']['std'],
                   aggregated_stats_temporal_side['test_macro_f1']['std']]
static_f1_std = [aggregated_stats_static_front['test_macro_f1']['std'],
                 aggregated_stats_static_side['test_macro_f1']['std']]

axes[1].bar(x - width/2, temporal_f1, width, yerr=temporal_f1_std, label='Temporal', capsize=5, color='steelblue')
axes[1].bar(x + width/2, static_f1, width, yerr=static_f1_std, label='Static', capsize=5, color='darkorange')
axes[1].set_xlabel('View')
axes[1].set_ylabel('Test Macro F1')
axes[1].set_title('Temporal vs Static - Macro F1')
axes[1].set_xticks(x)
axes[1].set_xticklabels(['Front', 'Side'])
axes[1].legend()
axes[1].set_ylim(0, 1)

plt.suptitle('Temporal vs Static LSTM Comparison', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary Statistics

# %%
# Final summary
print("=" * 100)
print("EXPERIMENT 7 - LSTM MODELS FINAL SUMMARY")
print("=" * 100)
print("\n📊 Model Performance Summary (30 runs each):\n")

for model_name, stats in all_models_stats.items():
    print(f"🔹 {model_name}:")
    print(f"   Accuracy: {stats['test_accuracy']['mean']:.4f} ± {stats['test_accuracy']['std']:.4f} "
          f"(range: {stats['test_accuracy']['min']:.4f} - {stats['test_accuracy']['max']:.4f})")
    print(f"   Macro F1: {stats['test_macro_f1']['mean']:.4f} ± {stats['test_macro_f1']['std']:.4f} "
          f"(range: {stats['test_macro_f1']['min']:.4f} - {stats['test_macro_f1']['max']:.4f})")
    print()

print("=" * 100)
print(f"\n🏆 Best Model by Mean Macro F1: {best_model_name}")
print(f"   Mean F1: {all_models_stats[best_model_name]['test_macro_f1']['mean']:.4f}")
print("=" * 100)

# %% [markdown]
# ## Key Findings
#
# Run this cell after training to see the conclusions.

# %%
# Compute differences
temporal_avg_f1 = (aggregated_stats_temporal_front['test_macro_f1']['mean'] + 
                   aggregated_stats_temporal_side['test_macro_f1']['mean']) / 2
static_avg_f1 = (aggregated_stats_static_front['test_macro_f1']['mean'] + 
                 aggregated_stats_static_side['test_macro_f1']['mean']) / 2

front_avg_f1 = (aggregated_stats_temporal_front['test_macro_f1']['mean'] + 
                aggregated_stats_static_front['test_macro_f1']['mean']) / 2
side_avg_f1 = (aggregated_stats_temporal_side['test_macro_f1']['mean'] + 
               aggregated_stats_static_side['test_macro_f1']['mean']) / 2

print("📈 Key Findings:")
print()
print(f"1. Temporal vs Static (avg Macro F1):")
print(f"   Temporal: {temporal_avg_f1:.4f}")
print(f"   Static:   {static_avg_f1:.4f}")
print(f"   Difference: {abs(temporal_avg_f1 - static_avg_f1):.4f} in favor of {'Temporal' if temporal_avg_f1 > static_avg_f1 else 'Static'}")
print()
print(f"2. Front vs Side (avg Macro F1):")
print(f"   Front: {front_avg_f1:.4f}")
print(f"   Side:  {side_avg_f1:.4f}")
print(f"   Difference: {abs(front_avg_f1 - side_avg_f1):.4f} in favor of {'Front' if front_avg_f1 > side_avg_f1 else 'Side'}")
