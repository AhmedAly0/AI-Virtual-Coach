# %% [markdown]
# # Pose Preprocessing with MediaPipe Tasks API
#
# This notebook extracts pose landmarks from exercise videos using the **new MediaPipe Tasks API**.

# %%
import sys
import os
import logging
import numpy as np
from pathlib import Path

# Setup paths
project_root = Path.cwd().parent.parent

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)

print(f"Project root: {project_root}")
# Out:
# Project root: /mnt/d/Graduation Project/ai-virtual-coach

# %% [markdown]
# ## Download MediaPipe Model (First Time Only)
#
# The new MediaPipe Tasks API requires a model file. We're using the **lite** model for faster inference.

# %%
import urllib.request
from pathlib import Path

# Model download URL - Using LITE model for faster inference
MODEL_URL = 'https://storage.googleapis.com/mediapipe-models/pose_landmarker/pose_landmarker_lite/float16/latest/pose_landmarker_lite.task'
MODEL_PATH = project_root / 'datasets' / 'pose_landmarker_lite.task'

# Download if not exists
if not MODEL_PATH.exists():
    print(f"Downloading MediaPipe pose model (LITE) to {MODEL_PATH}...")
    MODEL_PATH.parent.mkdir(parents=True, exist_ok=True)
    urllib.request.urlretrieve(MODEL_URL, MODEL_PATH)
    print(f"✅ Model downloaded successfully ({MODEL_PATH.stat().st_size / 1024 / 1024:.1f} MB)")
else:
    print(f"✅ Model already exists at {MODEL_PATH} ({MODEL_PATH.stat().st_size / 1024 / 1024:.1f} MB)")

# NOW import the preprocessing module (after model is available)
print("\nImporting preprocessing module...")
sys.path.insert(0, str(project_root / 'src'))
from preprocessing.preprocess_pose_RGB import extract_pose_estimates
print("✅ Module imported successfully!")
# Out:
# ✅ Model already exists at /mnt/d/Graduation Project/ai-virtual-coach/datasets/pose_landmarker_lite.task (5.5 MB)
#
# Importing preprocessing module...
# ✅ Module imported successfully!

# %% [markdown]
# ## Configuration

# %%
# Paths
CLIPS_PATH = project_root / 'datasets' / 'Clips'
OUTPUT_DIR = project_root / 'datasets' / 'Mediapipe pose estimates'

# Create output directory if it doesn't exist
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Parameters
T_FIXED = 50  # Fixed length for temporal sequences
VIEWS = ['front', 'side']  # Views to process
VERSION = "lite_13_angles"  # Change to v2, v3, etc. for different versions

print(f"Clips directory: {CLIPS_PATH}")
print(f"Output directory: {OUTPUT_DIR}")

print(f"Fixed temporal length: {T_FIXED} frames")
print(f"Version: {VERSION}")
# Out:
# Clips directory: /mnt/d/Graduation Project/ai-virtual-coach/datasets/Clips
# Output directory: /mnt/d/Graduation Project/ai-virtual-coach/datasets/Mediapipe pose estimates
# Fixed temporal length: 50 frames
# Version: lite_13_angles

# %% [markdown]
# ## Process Front View

# %%
print("="*60)
print("PROCESSING FRONT VIEW")
print("="*60)

front_output_path = OUTPUT_DIR / 'pose_data_front.npz'

front_dataset, front_stats, front_failed = extract_pose_estimates(
    clips_path=str(CLIPS_PATH),
    view='front',
    T_fixed=T_FIXED,
    output_path=str(front_output_path),
    version_tag=VERSION
)

print("\n" + "="*60)
print("FRONT VIEW SUMMARY")
print("="*60)
print(f"Total reps extracted: {front_stats['total_reps']}")
print(f"Unique subjects: {front_stats['unique_subjects']}")
print(f"Unique exercises: {front_stats['unique_exercises']}")
print(f"Videos processed: {front_stats['total_videos_processed']}")
print(f"Total frames extracted: {front_stats['total_frames_extracted']}")
print(f"Failed videos: {front_stats['failed_videos']}")
print(f"\nTemporal features shape: {front_dataset['X_temporal'].shape}")
print(f"\n⏱️ Tempo Statistics:")
print(f"  Duration (mean/median): {front_stats['tempo_stats']['duration_mean']:.2f}s / {front_stats['tempo_stats']['duration_median']:.2f}s")
print(f"  Frame count (mean/median): {front_stats['tempo_stats']['frame_count_mean']:.1f} / {front_stats['tempo_stats']['frame_count_median']:.0f}")
print(f"  FPS values: {front_stats['tempo_stats']['fps_unique']}")
# Out:
# INFO - Scanning clips directory for front view...
# ============================================================
# PROCESSING FRONT VIEW
# ============================================================
# Scanning front videos: 100%|██████████| 15/15 [00:04<00:00,  3.55it/s]
# INFO - [scan_clips_directory] Scanned front view: 147 samples, 1574 videos, 49 subjects, 15 exercises
# INFO - Found 147 sample(s) to process
# Extracting front poses:   0%|          | 0/147 [00:00<?, ?it/s]INFO -
# Processing: Dumbbell shoulder press / volunteer_001
# W0000 00:00:1769174751.090988   18832 landmark_projection_calculator.cc:78] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front poses:   1%|          | 1/147 [00:10<24:47, 10.19s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_010
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front poses:   1%|▏         | 2/147 [00:24<30:16, 12.53s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_002
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front poses:   2%|▏         | 3/147 [00:37<30:58, 12.91s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_003
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front poses:   3%|▎         | 4/147 [00:51<31:27, 13.20s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_031
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front poses:   3%|▎         | 5/147 [01:04<30:52, 13.05s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_004
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front poses:   4%|▍         | 6/147 [01:14<28:51, 12.28s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_046
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front poses:   5%|▍         | 7/147 [01:30<31:17, 13.41s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_005
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front poses:   5%|▌         | 8/147 [01:42<30:04, 12.98s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_050
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front poses:   6%|▌         | 9/147 [01:53<28:23, 12.34s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_006
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front poses:   7%|▋         | 10/147 [02:08<30:13, 13.24s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_007
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front poses:   7%|▋         | 11/147 [02:28<34:30, 15.22s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_008
# INFO -   ✓ Extracted 9 rep(s)
# Extracting front poses:   8%|▊         | 12/147 [02:45<35:33, 15.81s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_009
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front poses:   9%|▉         | 13/147 [02:59<33:56, 15.20s/it]INFO -
# Processing: Weighted Sqauts / volunteer_014
# INFO -   ✓ Extracted 8 rep(s)
# Extracting front poses:  10%|▉         | 14/147 [03:08<29:29, 13.30s/it]INFO -
# Processing: Weighted Sqauts / volunteer_015
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front poses:  10%|█         | 15/147 [03:27<32:56, 14.97s/it]INFO -
# Processing: Weighted Sqauts / volunteer_020
# INFO -   ✓ Extracted 9 rep(s)
# Extracting front poses:  11%|█         | 16/147 [03:50<37:50, 17.33s/it]INFO -
# Processing: Weighted Sqauts / volunteer_021
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front poses:  12%|█▏        | 17/147 [04:26<49:58, 23.06s/it]INFO -
# Processing: Weighted Sqauts / volunteer_022
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front poses:  12%|█▏        | 18/147 [04:46<47:15, 21.98s/it]INFO -
# Processing: Weighted Sqauts / volunteer_023
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front poses:  13%|█▎        | 19/147 [05:07<46:47, 21.94s/it]INFO -
# Processing: Weighted Sqauts / volunteer_029
# INFO -   ✓ Extracted 9 rep(s)
# Extracting front poses:  14%|█▎        | 20/147 [05:23<42:30, 20.08s/it]INFO -
# Processing: Weighted Sqauts / volunteer_030
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front poses:  14%|█▍        | 21/147 [05:57<51:09, 24.36s/it]INFO -
# Processing: Weighted Sqauts / volunteer_032
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front poses:  15%|█▍        | 22/147 [06:14<46:01, 22.10s/it]INFO -
# Processing: Seated biceps curls / volunteer_031
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front poses:  16%|█▌        | 23/147 [06:28<40:37, 19.66s/it]INFO -
# Processing: Seated biceps curls / volunteer_038
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front poses:  16%|█▋        | 24/147 [06:43<37:35, 18.34s/it]INFO -
# Processing: Seated biceps curls / volunteer_039
# INFO -   ✓ Extracted 14 rep(s)
# Extracting
#   FPS values: [23.148148, 23.809525, 24.0, 24.019608, 24.038462, 24.074074, 24.09091, 24.107143, 24.122807, 24.152542, 24.180328, 24.404762, 24.468084, 24.479166, 24.489796, 27.894737, 28.891376, 28.947369, 29.085873, 29.111841, 29.186604, 29.290617, 29.355078, 29.401089, 29.425837, 29.438002, 29.473684, 29.496819, 29.504131, 29.513035, 29.519451, 29.550941, 29.56327, 29.570747, 29.587482, 29.605263, 29.645542, 29.650461, 29.653402, 29.65675, 29.665071, 29.67742, 29.70297, 29.707602, 29.721363, 29.736841, 29.739397, 29.748283, 29.757086, 29.764065, 29.776674, 29.779112, 29.78177, 29.794827, 29.799852, 29.807692, 29.813665, 29.824562, 29.834253, 29.838709, 29.840656, 29.848595, 29.856459, 29.8627, 29.864254, 29.871977, 29.878542, 29.881155, 29.887218, 29.89011, 29.891523, 29.894737, 29.899216, 29.910269, 29.916897, 29.9293, 29.93135, 29.938482, 29.94152, 29.945553, 29.950901, 29.951166, 29.959515, 29.967777, 29.96942, 29.97003, 29.972752, 29.973238, 29.975, 29.97543, 29.975826, 29.97621, 29.978586, 29.978888, 29.980013, 29.980532, 29.980782, 29.981262, 29.981493, 29.98405, 29.986732, 29.987185, 29.98864, 29.99007, 30.0, 30.003, 30.013, 30.015633, 30.019493, 30.025, 30.025885, 30.03096, 30.033125, 30.038, 30.038511, 30.042675, 30.045988, 30.050934, 30.05707, 30.060728, 30.063158, 30.065, 30.074257, 30.075188, 30.083103, 30.084349, 30.087029, 30.089375, 30.092878, 30.094044, 30.103296, 30.103806, 30.110159, 30.116959, 30.121458, 30.12704, 30.130371, 30.13561, 30.143541, 30.152802, 30.154333, 30.159668, 30.164965, 30.175438, 30.17988, 30.185759, 30.190863, 30.193905, 30.194805, 30.198019, 30.200308, 30.20595, 30.215828, 30.217787, 30.225563, 30.233767, 30.235163, 30.240856, 30.244625, 30.249308, 30.2521, 30.263159, 30.269524, 30.27027, 30.281183, 30.30303, 30.31579, 30.316742, 30.328297, 30.33241, 30.340557, 30.343512, 30.34682, 30.35343, 30.357143, 30.364372, 30.379747, 30.393997, 30.424528, 30.430622, 30.440588, 30.443975, 30.451128, 30.470915, 30.50109, 30.584707, 30.76923, 30.882353, 59.677418, 59.94006, 60.0, 60.007]

# %% [markdown]
# ## Process Side View

# %%
print("="*60)
print("PROCESSING SIDE VIEW")
print("="*60)

side_output_path = OUTPUT_DIR / 'pose_data_side.npz'

side_dataset, side_stats, side_failed = extract_pose_estimates(
    clips_path=str(CLIPS_PATH),
    view='side',
    T_fixed=T_FIXED,
    output_path=str(side_output_path),
    version_tag=VERSION
)

print("\n" + "="*60)
print("SIDE VIEW SUMMARY")
print("="*60)
print(f"Total reps extracted: {side_stats['total_reps']}")
print(f"Unique subjects: {side_stats['unique_subjects']}")
print(f"Unique exercises: {side_stats['unique_exercises']}")
print(f"Videos processed: {side_stats['total_videos_processed']}")
print(f"Total frames extracted: {side_stats['total_frames_extracted']}")
print(f"Failed videos: {side_stats['failed_videos']}")
print(f"\nTemporal features shape: {side_dataset['X_temporal'].shape}")
print(f"\n⏱️ Tempo Statistics:")
print(f"  Duration (mean/median): {side_stats['tempo_stats']['duration_mean']:.2f}s / {side_stats['tempo_stats']['duration_median']:.2f}s")
print(f"  Frame count (mean/median): {side_stats['tempo_stats']['frame_count_mean']:.1f} / {side_stats['tempo_stats']['frame_count_median']:.0f}")
print(f"  FPS values: {side_stats['tempo_stats']['fps_unique']}")
print(f"\n📁 Output Files:")
print(f"  Temporal: {side_stats.get('temporal_file', 'N/A')}")
# Out:
# INFO - Scanning clips directory for side view...
# ============================================================
# PROCESSING SIDE VIEW
# ============================================================
# Scanning side videos: 100%|██████████| 15/15 [00:03<00:00,  3.87it/s]
# INFO - [scan_clips_directory] Scanned side view: 149 samples, 1571 videos, 49 subjects, 15 exercises
# INFO - Found 149 sample(s) to process
# Extracting side poses:   0%|          | 0/149 [00:00<?, ?it/s]INFO -
# Processing: Dumbbell shoulder press / volunteer_001
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side poses:   1%|          | 1/149 [00:15<38:51, 15.75s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_010
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side poses:   1%|▏         | 2/149 [00:38<48:54, 19.96s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_002
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side poses:   2%|▏         | 3/149 [00:52<41:35, 17.09s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_003
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side poses:   3%|▎         | 4/149 [01:10<42:05, 17.42s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_031
# INFO -   ✓ Extracted 8 rep(s)
# Extracting side poses:   3%|▎         | 5/149 [01:17<32:42, 13.63s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_004
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side poses:   4%|▍         | 6/149 [01:28<30:48, 12.93s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_046
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side poses:   5%|▍         | 7/149 [01:44<32:46, 13.85s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_005
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side poses:   5%|▌         | 8/149 [01:58<32:57, 14.02s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_050
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side poses:   6%|▌         | 9/149 [02:09<30:00, 12.86s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_006
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side poses:   7%|▋         | 10/149 [02:24<31:46, 13.71s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_007
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side poses:   7%|▋         | 11/149 [02:43<34:51, 15.15s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_008
# INFO -   ✓ Extracted 9 rep(s)
# Extracting side poses:   8%|▊         | 12/149 [02:59<35:40, 15.62s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_009
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side poses:   9%|▊         | 13/149 [03:11<32:19, 14.26s/it]INFO -
# Processing: Weighted Sqauts / volunteer_014
# INFO -   ✓ Extracted 8 rep(s)
# Extracting side poses:   9%|▉         | 14/149 [03:18<27:33, 12.24s/it]INFO -
# Processing: Weighted Sqauts / volunteer_015
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side poses:  10%|█         | 15/149 [03:32<28:29, 12.76s/it]INFO -
# Processing: Weighted Sqauts / volunteer_020
# INFO -   ✓ Extracted 9 rep(s)
# Extracting side poses:  11%|█         | 16/149 [03:53<33:37, 15.17s/it]INFO -
# Processing: Weighted Sqauts / volunteer_021
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side poses:  11%|█▏        | 17/149 [04:11<35:27, 16.12s/it]INFO -
# Processing: Weighted Sqauts / volunteer_022
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side poses:  12%|█▏        | 18/149 [04:30<36:51, 16.88s/it]INFO -
# Processing: Weighted Sqauts / volunteer_023
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side poses:  13%|█▎        | 19/149 [04:44<35:03, 16.18s/it]INFO -
# Processing: Weighted Sqauts / volunteer_029
# INFO -   ✓ Extracted 9 rep(s)
# Extracting side poses:  13%|█▎        | 20/149 [05:00<34:36, 16.09s/it]INFO -
# Processing: Weighted Sqauts / volunteer_030
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side poses:  14%|█▍        | 21/149 [05:14<32:35, 15.28s/it]INFO -
# Processing: Weighted Sqauts / volunteer_032
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side poses:  15%|█▍        | 22/149 [05:25<29:55, 14.14s/it]INFO -
# Processing: Seated biceps curls / volunteer_031
# INFO -   ✓ Extracted 8 rep(s)
# Extracting side poses:  15%|█▌        | 23/149 [05:35<26:49, 12.77s/it]INFO -
# Processing: Seated biceps curls / volunteer_038
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side poses:  16%|█▌        | 24/149 [05:46<25:24, 12.19s/it]INFO -
# Processing: Seated biceps curls / volunteer_039
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side poses:  17%|█▋        | 25/149 [05:57<24:34, 11.89s/it]INFO -
# Processing: Seated biceps curls / volunteer_040
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side poses:
# INFO -   ✓ Extracted 9 rep(s)
# Extracting side poses:  81%|████████  | 120/149 [30:34<07:50, 16.22s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_011
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side poses:  81%|████████  | 121/149 [30:49<07:22, 15.81s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_012
# INFO -   ✓ Extracted 16 rep(s)
# Extracting side poses:  82%|████████▏ | 122/149 [31:08<07:32, 16.77s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_014
# INFO -   ✓ Extracted 8 rep(s)
# Extracting side poses:  83%|████████▎ | 123/149 [31:18<06:19, 14.59s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_015
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side poses:  83%|████████▎ | 124/149 [31:37<06:39, 15.98s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_016
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side poses:  84%|████████▍ | 125/149 [31:57<06:53, 17.22s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_017
# INFO -   ✓ Extracted 17 rep(s)
# Extracting side poses:  85%|████████▍ | 126/149 [32:19<07:07, 18.58s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_018
# INFO -   ✓ Extracted 13 rep(s)
# Extracting side poses:  85%|████████▌ | 127/149 [32:37<06:47, 18.51s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_022
# INFO -   ✓ Extracted 8 rep(s)
# Extracting side poses:  86%|████████▌ | 128/149 [32:55<06:24, 18.33s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_023
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side poses:  87%|████████▋ | 129/149 [33:15<06:15, 18.76s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_026
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side poses:  87%|████████▋ | 130/149 [33:29<05:32, 17.48s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_014
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side poses:  88%|████████▊ | 131/149 [33:49<05:28, 18.26s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_015
# INFO -   ✓ Extracted 13 rep(s)
# Extracting side poses:  89%|████████▊ | 132/149 [34:16<05:51, 20.68s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_016
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side poses:  89%|████████▉ | 133/149 [34:41<05:53, 22.10s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_019
# INFO -   ✓ Extracted 13 rep(s)
# Extracting side poses:  90%|████████▉ | 134/149 [35:05<05:38, 22.57s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_020
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side poses:  91%|█████████ | 135/149 [35:31<05:30, 23.58s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_021
# INFO -   ✓ Extracted 8 rep(s)
# Extracting side poses:  91%|█████████▏| 136/149 [35:54<05:07, 23.65s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_022
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side poses:  92%|█████████▏| 137/149 [36:16<04:35, 22.97s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_023
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side poses:  93%|█████████▎| 138/149 [36:45<04:32, 24.73s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_027
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side poses:  93%|█████████▎| 139/149 [37:02<03:46, 22.65s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_028
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side poses:  94%|█████████▍| 140/149 [37:14<02:54, 19.39s/it]INFO -
# Processing: Shrugs / volunteer_014
# INFO -   ✓ Extracted 6 rep(s)
# Extracting side poses:  95%|█████████▍| 141/149 [37:22<02:07, 15.94s/it]INFO -
# Processing: Shrugs / volunteer_015
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side poses:  95%|█████████▌| 142/149 [37:41<01:56, 16.69s/it]INFO -
# Processing: Shrugs / volunteer_020
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side poses:  96%|█████████▌| 143/149 [38:00<01:44, 17.40s/it]INFO -
# Processing: Shrugs / volunteer_022
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side poses:  97%|█████████▋| 144/149 [38:31<01:48, 21.73s/it]INFO -
# Processing: Shrugs / volunteer_023
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side poses:  97%|█████████▋| 145/149 [38:48<01:21, 20.26s/it]INFO -
# Processing: Shrugs / volunteer_033
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side poses:  98%|█████████▊| 146/149 [39:05<00:57, 19.13s/it]INFO -
# Processing: Shrugs / volunteer_034
# INFO -   ✓ Extracted 9 rep(s)
# Extracting side poses:  99%|█████████▊| 147/149 [39:25<00:38, 19.41s/it]INFO -
# Processing: Shrugs / volunteer_035
# INFO -   ✓ Extracted 14 rep(s)
# Extracting side poses:  99%|█████████▉| 148/149 [39:40<00:18, 18.07s/it]INFO -
# Processing: Shrugs / volunteer_036
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side poses: 100%|██████████| 149/149 [40:02<00:00, 16.12s/it]
# INFO -
# ✓ Successfully extracted 1571 reps from 1571 videos
# INFO - Building static features...
# INFO - Building temporal features (T_fixed=50)...
# INFO - Tempo features: frame_count range=22-244, fps range=28.9-60.0, duration range=0.73s-6.57s
# INFO -
# ============================================================
# [extract_pose_estimates] Completed side view:
#   - Total reps: 1571
#   - Videos processed: 1571
#   - Frames extracted: 126361
#   - Unique subjects: 49
#   - Unique exercises: 15
#   - Failed videos: 0
#   - Static features: (1571, 65)
#   - Temporal features: (1571, 50, 13)
#   - Tempo duration (mean): 2.53s
#   - Tempo frame count (median): 73
mnt/d/Graduation Project/ai-virtual-coach/datasets/Mediapipe pose estimates/pose_data_side_temporal_lite_13_angles.npz

# %% [markdown]
# ### Failed Videos (Side)

# %%
if side_failed:
    print(f"\n⚠️ {len(side_failed)} samples failed to process:")
    for item in side_failed[:10]:  # Show first 10
        print(f"  - {item['exercise']} / {item['subject']}: {item['error']}")
    if len(side_failed) > 10:
        print(f"  ... and {len(side_failed) - 10} more")
else:
    print("✅ All side view samples processed successfully!")
# Out:
# ✅ All side view samples processed successfully!

# %% [markdown]
# ## Combined Summary

# %%
print("="*60)
print("COMBINED SUMMARY (FRONT + SIDE)")
print("="*60)

total_reps = front_stats['total_reps'] + side_stats['total_reps']
total_videos = front_stats['total_videos_processed'] + side_stats['total_videos_processed']
total_frames = front_stats['total_frames_extracted'] + side_stats['total_frames_extracted']
total_failed = front_stats['failed_videos'] + side_stats['failed_videos']

# Combined unique counts
all_subjects = set(front_dataset['subject_ids']) | set(side_dataset['subject_ids'])
all_exercises = set(front_dataset['exercise_names']) | set(side_dataset['exercise_names'])

print(f"\n📄 Dataset Statistics:")
print(f"  Total reps: {total_reps}")
print(f"  Total videos: {total_videos}")
print(f"  Total frames: {total_frames}")
print(f"  Unique volunteers: {len(all_subjects)}")
print(f"  Unique exercises: {len(all_exercises)}")
print(f"  Failed samples: {total_failed}")

print(f"\n📁 Output Files:")
print(f"  Front Temporal: {front_stats.get('temporal_file', 'N/A')}")
print(f"  Side Temporal:  {side_stats.get('temporal_file', 'N/A')}")

print(f"\n✅ Preprocessing complete!")
# Out:
# ============================================================
# COMBINED SUMMARY (FRONT + SIDE)
# ============================================================
#
# 📊 Dataset Statistics:
#   Total reps: 3145
#   Total videos: 3145
#   Total frames: 263157
#   Unique volunteers: 49
#   Unique exercises: 15
#   Failed samples: 0
#
# 📁 Output Files:
#   Front Static:   /mnt/d/Graduation_Project/ai-virtual-coach/datasets/Mediapipe pose estimates/pose_data_front_static_v2.npz
#   Front Temporal: /mnt/d/Graduation_Project/ai-virtual-coach/datasets/Mediapipe pose estimates/pose_data_front_temporal_v2.npz
#   Side Static:    /mnt/d/Graduation_Project/ai-virtual-coach/datasets/Mediapipe pose estimates/pose_data_side_static_v2.npz
#   Side Temporal:  /mnt/d/Graduation_Project/ai-virtual-coach/datasets/Mediapipe pose estimates/pose_data_side_temporal_v2.npz
#
# ✅ Preprocessing complete!

# %% [markdown]
# ## Verify Output Files

# %%
# Load and inspect saved temporal files
print("Verifying saved temporal NPZ files...\n")

for view in ['front', 'side']:
    stats = front_stats if view == 'front' else side_stats
    
    # Verify temporal file
    temporal_file = stats.get('temporal_file')
    if temporal_file and os.path.exists(temporal_file):
        print(f"\n{view.upper()} VIEW - TEMPORAL:")
        data = np.load(temporal_file, allow_pickle=True)
        print(f"  File: {os.path.basename(temporal_file)}")
        print(f"  Keys: {list(data.keys())}")
        print(f"  X_temporal: {data['X_temporal'].shape} - {data['X_temporal'].dtype}")
        print(f"  exercise_names: {data['exercise_names'].shape}")
        print(f"  subject_ids: {data['subject_ids'].shape}")
        print(f"  tempo_duration_sec: {data['tempo_duration_sec'].shape}")
        print(f"  tempo_frame_count: {data['tempo_frame_count'].shape}")
        print(f"  tempo_fps: {data['tempo_fps'].shape}")
        print(f"  view: {data['view']}")
        print(f"  T_fixed: {data['T_fixed']}")
        print(f"  angle_names: {list(data['angle_names'])}")

print("\n✅ All files verified successfully!")
# Out:
# Verifying saved NPZ files...
#
#
# FRONT VIEW - STATIC:
#   File: pose_data_front_static_v2.npz
#   Keys: ['X_static', 'exercise_names', 'subject_ids', 'tempo_duration_sec', 'tempo_frame_count', 'tempo_fps', 'view', 'angle_names']
#   X_static: (1574, 45) - float32
#   exercise_names: (1574,)
#   subject_ids: (1574,)
#   tempo_duration_sec: (1574,)
#   tempo_frame_count: (1574,)
#   tempo_fps: (1574,)
#   view: front
#   angle_names: ['left_elbow', 'right_elbow', 'left_shoulder', 'right_shoulder', 'left_hip', 'right_hip', 'left_knee', 'right_knee', 'torso_lean']
#
# FRONT VIEW - TEMPORAL:
#   File: pose_data_front_temporal_v2.npz
#   Keys: ['X_temporal', 'exercise_names', 'subject_ids', 'tempo_duration_sec', 'tempo_frame_count', 'tempo_fps', 'view', 'T_fixed', 'angle_names']
#   X_temporal: (1574, 80, 9) - float32
#   exercise_names: (1574,)
#   subject_ids: (1574,)
#   tempo_duration_sec: (1574,)
#   tempo_frame_count: (1574,)
#   tempo_fps: (1574,)
#   view: front
#   T_fixed: 80
#   angle_names: ['left_elbow', 'right_elbow', 'left_shoulder', 'right_shoulder', 'left_hip', 'right_hip', 'left_knee', 'right_knee', 'torso_lean']
#
# SIDE VIEW - STATIC:
#   File: pose_data_side_static_v2.npz
#   Keys: ['X_static', 'exercise_names', 'subject_ids', 'tempo_duration_sec', 'tempo_frame_count', 'tempo_fps', 'view', 'angle_names']
#   X_static: (1571, 45) - float32
#   exercise_names: (1571,)
#   subject_ids: (1571,)
#   tempo_duration_sec: (1571,)
#   tempo_frame_count: (1571,)
#   tempo_fps: (1571,)
#   view: side
#   angle_names: ['left_elbow', 'right_elbow', 'left_shoulder', 'right_shoulder', 'left_hip', 'right_hip', 'left_knee', 'right_knee', 'torso_lean']
#
# SIDE VIEW - TEMPORAL:
#   File: pose_data_side_temporal_v2.npz
#   Keys: ['X_temporal', 'exercise_names', 'subject_ids', 'tempo_duration_sec', 'tempo_frame_count', 'tempo_fps', 'view', 'T_fixed', 'angle_names']
#   X_temporal: (1571, 80, 9) - float32
#   exercise_names: (1571,)
#   subject_ids: (1571,)
#   tempo_duration_sec: (1571,)
#   tempo_frame_count: (1571,)
#   tempo_fps: (1571,)
#   view: side
#   T_fixed: 80
#   angle_names: ['left_elbow', 'right_elbow', 'left_shoulder', 'right_shoulder', 'left_hip', 'right_hip', 'left_knee', 'right_knee', 'torso_lean']
#
# ✅ All files verified successfully!

# %% [markdown]
# ## Sample Data Inspection

# %%
# Inspect first few samples
print("Sample data from front view:\n")
print("First 5 exercises:")
for i in range(min(5, len(front_dataset['exercise_names']))):
    print(f"  {i+1}. {front_dataset['exercise_names'][i]} (Subject {front_dataset['subject_ids'][i]})")

print("\nTemporal features (first rep, first 5 frames):")
print(front_dataset['X_temporal'][0, :5, :])
# Out:
# Sample data from front view:
#
# First 5 exercises:
#   1. Dumbbell shoulder press (Subject 1)
#   2. Dumbbell shoulder press (Subject 1)
#   3. Dumbbell shoulder press (Subject 1)
#   4. Dumbbell shoulder press (Subject 1)
#   5. Dumbbell shoulder press (Subject 1)
#
# Static features (first rep, first 10 values):
# [128.39922   15.510805 101.697075 148.72682   47.029747 131.1648
#   19.645264  85.70126  161.67555   75.97429 ]
#
# Temporal features (first rep, first 5 frames):
# [[125.94949  131.30444  105.06773   94.97147  160.69958  130.76443
#   143.02394  166.71664   16.87413 ]
#  [116.06957  129.82344  101.49968   97.248924 164.11037  133.51707
#   134.34184  167.17041   16.920328]
#  [114.22898  130.19913  100.61363   98.5807   164.7034   135.01562
#   132.62128  167.30406   17.278519]
#  [114.594    130.73834  100.55692   99.13356  164.43755  135.65314
#   132.97652  167.35484   17.50489 ]
#  [115.18252  131.93718  100.53263   99.74887  164.18378  136.31961
#   133.1552   167.35368   17.760881]]
