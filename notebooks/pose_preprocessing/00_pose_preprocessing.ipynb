# %% [markdown]
# # Pose Preprocessing with MediaPipe Tasks API (v2 - Enhanced Features)
#
# This notebook extracts pose landmarks from exercise videos using the **MediaPipe Tasks API**.
#
# ## Version 2 Enhancements
# - **Raw landmark storage**: Saves normalized (33, 3) landmarks per frame for future feature experiments
# - **Enhanced feature set**: 13 angles + 6 distance-based features = 19 total features
# - **Distance features for problem exercises**:
#   - **Shrugs**: Ear-to-shoulder vertical distance (captures shoulder elevation)
#   - **Curl variants**: Wrist-shoulder distance, elbow-hip distance (differentiates arm positions)

# %%
import sys
import os
import logging
import numpy as np
from pathlib import Path

# Setup paths
project_root = Path.cwd().parent.parent

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)

print(f"Project root: {project_root}")
# Out:
# Project root: /mnt/d/Graduation Project/ai-virtual-coach

# %% [markdown]
# ## Download MediaPipe Model (First Time Only)
#
# The new MediaPipe Tasks API requires a model file. We're using the **lite** model for faster inference.

# %%
import urllib.request
from pathlib import Path

# Model download URL - Using LITE model for faster inference
MODEL_URL = 'https://storage.googleapis.com/mediapipe-models/pose_landmarker/pose_landmarker_lite/float16/latest/pose_landmarker_lite.task'
MODEL_PATH = project_root / 'datasets' / 'pose_landmarker_lite.task'

# Download if not exists
if not MODEL_PATH.exists():
    print(f"Downloading MediaPipe pose model (LITE) to {MODEL_PATH}...")
    MODEL_PATH.parent.mkdir(parents=True, exist_ok=True)
    urllib.request.urlretrieve(MODEL_URL, MODEL_PATH)
    print(f"✅ Model downloaded successfully ({MODEL_PATH.stat().st_size / 1024 / 1024:.1f} MB)")
else:
    print(f"✅ Model already exists at {MODEL_PATH} ({MODEL_PATH.stat().st_size / 1024 / 1024:.1f} MB)")

# NOW import the preprocessing module (after model is available)
print("\nImporting preprocessing module...")
sys.path.insert(0, str(project_root / 'src'))
from preprocessing.preprocess_pose_RGB import (
    extract_pose_estimates,
    extract_raw_pose_landmarks,
    ANGLE_NAMES,
    DISTANCE_NAMES,
    ALL_FEATURE_NAMES
)
print("✅ Module imported successfully!")
print(f"\nFeature sets available:")
print(f"  - Angles ({len(ANGLE_NAMES)}): {ANGLE_NAMES}")
print(f"  - Distances ({len(DISTANCE_NAMES)}): {DISTANCE_NAMES}")
print(f"  - All features ({len(ALL_FEATURE_NAMES)}): {len(ALL_FEATURE_NAMES)} total")
# Out:
# ✅ Model already exists at /mnt/d/Graduation Project/ai-virtual-coach/datasets/pose_landmarker_lite.task (5.5 MB)
#
# Importing preprocessing module...
# ✅ Module imported successfully!
#
# Feature sets available:
#   - Angles (13): ['left_elbow', 'right_elbow', 'left_shoulder', 'right_shoulder', 'left_hip', 'right_hip', 'left_knee', 'right_knee', 'torso_lean', 'left_ankle', 'right_ankle', 'left_wrist', 'right_wrist']
#   - Distances (6): ['left_ear_shoulder_vert', 'right_ear_shoulder_vert', 'left_wrist_shoulder_dist', 'right_wrist_shoulder_dist', 'left_elbow_hip_dist', 'right_elbow_hip_dist']
#   - All features (19): 19 total

# %% [markdown]
# ## Configuration

# %%
# Paths
CLIPS_PATH = project_root / 'datasets' / 'Clips'
OUTPUT_DIR = project_root / 'datasets' / 'Mediapipe pose estimates'

# Create output directory if it doesn't exist
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Parameters
T_FIXED = 50  # Fixed length for temporal sequences
VIEWS = ['front', 'side']  # Views to process
VERSION = "19features"  # v2: includes raw landmarks + 19 features (13 angles + 6 distances)

print(f"Clips directory: {CLIPS_PATH}")
print(f"Output directory: {OUTPUT_DIR}")
print(f"Fixed temporal length: {T_FIXED} frames")
print(f"Version: {VERSION}")
print(f"\n📊 Feature breakdown:")
print(f"  - 13 joint angles (elbow, shoulder, hip, knee, ankle, wrist, torso)")
print(f"  - 6 distance features (ear-shoulder, wrist-shoulder, elbow-hip)")
print(f"  - Total: 19 features per frame × 50 frames = 950 features (flattened)")
# Out:
# Clips directory: /mnt/d/Graduation Project/ai-virtual-coach/datasets/Clips
# Output directory: /mnt/d/Graduation Project/ai-virtual-coach/datasets/Mediapipe pose estimates
# Fixed temporal length: 50 frames
# Version: 19features
#
# 📊 Feature breakdown:
#   - 13 joint angles (elbow, shoulder, hip, knee, ankle, wrist, torso)
#   - 6 distance features (ear-shoulder, wrist-shoulder, elbow-hip)
#   - Total: 19 features per frame × 50 frames = 950 features (flattened)

# %% [markdown]
# ## Process Front View (Enhanced - Raw Landmarks + Features)
#
# Extract raw normalized landmarks and compute all feature types (angles, distances, combined).

# %%
print("="*60)
print("PROCESSING FRONT VIEW (Enhanced v2)")
print("="*60)

front_output_path = OUTPUT_DIR / 'pose_data_front.npz'

# Use the new extraction function that saves raw landmarks + all features
front_dataset, front_stats, front_failed = extract_raw_pose_landmarks(
    clips_path=str(CLIPS_PATH),
    view='front',
    T_fixed=T_FIXED,
    output_path=str(front_output_path),
    version_tag=VERSION
)

print("\n" + "="*60)
print("FRONT VIEW SUMMARY")
print("="*60)
print(f"Total reps extracted: {front_stats['total_reps']}")
print(f"Unique subjects: {front_stats['unique_subjects']}")
print(f"Unique exercises: {front_stats['unique_exercises']}")
print(f"Videos processed: {front_stats['total_videos_processed']}")
print(f"Total frames extracted: {front_stats['total_frames_extracted']}")
print(f"Failed videos: {front_stats['failed_videos']}")
print(f"\n📐 Feature shapes:")
print(f"  Raw landmarks: {front_stats['landmarks_shape']} (N, T, 33 landmarks, xyz)")
print(f"  Angles only:   {front_stats['angles_shape']} (N, T, 13 angles)")
print(f"  Distances:     {front_stats['distances_shape']} (N, T, 6 distances)")
print(f"  All features:  {front_stats['all_features_shape']} (N, T, 19 features)")
print(f"\n⏱️ Tempo Statistics:")
print(f"  Duration (mean/median): {front_stats['tempo_stats']['duration_mean']:.2f}s / {front_stats['tempo_stats']['duration_median']:.2f}s")
print(f"  Frame count (mean/median): {front_stats['tempo_stats']['frame_count_mean']:.1f} / {front_stats['tempo_stats']['frame_count_median']:.0f}")
print(f"  FPS values: {front_stats['tempo_stats']['fps_unique']}")
# Out:
# INFO - Scanning clips directory for front view...
# ============================================================
# PROCESSING FRONT VIEW (Enhanced v2)
# ============================================================
# Scanning front videos: 100%|██████████| 15/15 [00:04<00:00,  3.56it/s]
# INFO - [scan_clips_directory] Scanned front view: 147 samples, 1574 videos, 49 subjects, 15 exercises
# INFO - Found 147 sample(s) to process
# Extracting front landmarks:   0%|          | 0/147 [00:00<?, ?it/s]INFO -
# Processing: Dumbbell shoulder press / volunteer_001
# W0000 00:00:1769242329.677263   15964 landmark_projection_calculator.cc:78] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:   1%|          | 1/147 [00:13<32:36, 13.40s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_010
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:   1%|▏         | 2/147 [00:24<29:13, 12.09s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_002
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:   2%|▏         | 3/147 [00:39<32:26, 13.52s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_003
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:   3%|▎         | 4/147 [00:52<31:29, 13.22s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_031
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:   3%|▎         | 5/147 [01:01<27:55, 11.80s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_004
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:   4%|▍         | 6/147 [01:15<29:11, 12.42s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_046
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:   5%|▍         | 7/147 [01:27<28:52, 12.37s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_005
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:   5%|▌         | 8/147 [01:38<27:32, 11.89s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_050
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:   6%|▌         | 9/147 [01:52<28:31, 12.40s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_006
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:   7%|▋         | 10/147 [02:03<27:38, 12.11s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_007
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:   7%|▋         | 11/147 [02:20<30:57, 13.66s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_008
# INFO -   ✓ Extracted 9 rep(s)
# Extracting front landmarks:   8%|▊         | 12/147 [02:37<32:58, 14.66s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_009
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:   9%|▉         | 13/147 [02:49<30:52, 13.83s/it]INFO -
# Processing: Weighted Sqauts / volunteer_014
# INFO -   ✓ Extracted 8 rep(s)
# Extracting front landmarks:  10%|▉         | 14/147 [02:57<26:33, 11.98s/it]INFO -
# Processing: Weighted Sqauts / volunteer_015
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  10%|█         | 15/147 [03:15<30:40, 13.94s/it]INFO -
# Processing: Weighted Sqauts / volunteer_020
# INFO -   ✓ Extracted 9 rep(s)
# Extracting front landmarks:  11%|█         | 16/147 [03:34<33:29, 15.34s/it]INFO -
# Processing: Weighted Sqauts / volunteer_021
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  12%|█▏        | 17/147 [04:09<46:17, 21.37s/it]INFO -
# Processing: Weighted Sqauts / volunteer_022
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  12%|█▏        | 18/147 [04:31<46:15, 21.52s/it]INFO -
# Processing: Weighted Sqauts / volunteer_023
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  13%|█▎        | 19/147 [04:52<45:27, 21.31s/it]INFO -
# Processing: Weighted Sqauts / volunteer_029
# INFO -   ✓ Extracted 9 rep(s)
# Extracting front landmarks:  14%|█▎        | 20/147 [05:07<40:51, 19.31s/it]INFO -
# Processing: Weighted Sqauts / volunteer_030
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  14%|█▍        | 21/147 [05:40<49:14, 23.45s/it]INFO -
# Processing: Weighted Sqauts / volunteer_032
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  15%|█▍        | 22/147 [05:52<42:08, 20.22s/it]INFO -
# Processing: Seated biceps curls / volunteer_031
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front landmarks:  16%|█▌        | 23/147 [06:09<39:28, 19.10s/it]INFO -
# Processing: Seated biceps curls / volunteer_038
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  16%|█▋        | 24/147 [06:20<34:24, 16.79s/it]INFO -
# Processing: Seated biceps curls / volunteer_039
# INFO -   ✓ Extracted 14 rep(s)
# Extracting front landmarks:  17%|█▋        | 25/147 [06:42<37:01, 18.21s/it]INFO -
# Processing: Seated biceps curls / volunteer_040
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  18%|█▊        | 26/147 [06:52<31:47, 15.76s/it]INFO -
# Processing: Seated biceps curls / volunteer_041
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  18%|█▊        | 27/147 [07:03<28:55, 14.47s/it]INFO -
# Processing: Seated biceps curls / volunteer_042
# INFO -   ✓ Extracted 13 rep(s)
# Extracting front landmarks:  19%|█▉        | 28/147 [07:26<33:39, 16.97s/it]INFO -
# Processing: Seated biceps curls / volunteer_043
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  20%|█▉        | 29/147 [07:34<27:44, 14.10s/it]INFO -
# Processing: Seated biceps curls / volunteer_044
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  20%|██        | 30/147 [07:52<29:48, 15.29s/it]INFO -
# Processing: Triceps Kickbacks / volunteer_031
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  21%|██        | 31/147 [08:00<25:36, 13.24s/it]INFO -
# Processing: Triceps Kickbacks / volunteer_038
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  22%|██▏       | 32/147 [08:09<22:54, 11.95s/it]INFO -
# Processing: Triceps Kickbacks / volunteer_039
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front landmarks:  22%|██▏       | 33/147 [08:23<24:06, 12.69s/it]INFO -
# Processing: Triceps Kickbacks / volunteer_040
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  23%|██▎       | 34/147 [08:33<22:11, 11.79s/it]INFO -
# Processing: Triceps Kickbacks / volunteer_041
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  24%|██▍       | 35/147 [08:41<20:04, 10.75s/it]INFO -
# Processing: Triceps Kickbacks / volunteer_042
# INFO -   ✓ Extracted 9 rep(s)
# Extracting front landmarks:  24%|██▍       | 36/147 [08:50<18:53, 10.22s/it]INFO -
# Processing: Triceps Kickbacks / volunteer_043
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  25%|██▌       | 37/147 [09:02<19:37, 10.70s/it]INFO -
# Processing: Triceps Kickbacks / volunteer_044
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  26%|██▌       | 38/147 [09:13<19:27, 10.71s/it]INFO -
# Processing: Triceps Kickbacks / volunteer_045
# INFO -   ✓ Extracted 7 rep(s)
# Extracting front landmarks:  27%|██▋       | 39/147 [09:19<16:51,  9.36s/it]INFO -
# Processing: Rows / volunteer_031
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front landmarks:  27%|██▋       | 40/147 [09:28<16:36,  9.31s/it]INFO -
# Processing: Rows / volunteer_038
# INFO -   ✓ Extracted 13 rep(s)
# Extracting front landmarks:  28%|██▊       | 41/147 [09:42<18:43, 10.60s/it]INFO -
# Processing: Rows / volunteer_039
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  29%|██▊       | 42/147 [09:51<17:53, 10.23s/it]INFO -
# Processing: Rows / volunteer_040
# INFO -   ✓ Extracted 13 rep(s)
# Extracting front landmarks:  29%|██▉       | 43/147 [10:02<17:53, 10.33s/it]INFO -
# Processing: Rows / volunteer_041
# INFO -   ✓ Extracted 14 rep(s)
# Extracting front landmarks:  30%|██▉       | 44/147 [10:15<19:22, 11.29s/it]INFO -
# Processing: Rows / volunteer_042
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front landmarks:  31%|███       | 45/147 [10:28<19:39, 11.57s/it]INFO -
# Processing: Rows / volunteer_043
# INFO -   ✓ Extracted 13 rep(s)
# Extracting front landmarks:  31%|███▏      | 46/147 [10:35<17:29, 10.39s/it]INFO -
# Processing: Rows / volunteer_044
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  32%|███▏      | 47/147 [10:47<18:07, 10.88s/it]INFO -
# Processing: Rows / volunteer_045
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  33%|███▎      | 48/147 [10:56<17:01, 10.31s/it]INFO -
# Processing: Deadlift / volunteer_031
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  33%|███▎      | 49/147 [11:08<17:17, 10.58s/it]INFO -
# Processing: Deadlift / volunteer_038
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front landmarks:  34%|███▍      | 50/147 [11:23<19:36, 12.13s/it]INFO -
# Processing: Deadlift / volunteer_039
# INFO -   ✓ Extracted 13 rep(s)
# Extracting front landmarks:  35%|███▍      | 51/147 [11:38<20:51, 13.04s/it]INFO -
# Processing: Deadlift / volunteer_004
# INFO -   ✓ Extracted 8 rep(s)
# Extracting front landmarks:  35%|███▌      | 52/147 [11:50<19:52, 12.55s/it]INFO -
# Processing: Deadlift / volunteer_040
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  36%|███▌      | 53/147 [12:03<19:47, 12.64s/it]INFO -
# Processing: Deadlift / volunteer_041
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front landmarks:  37%|███▋      | 54/147 [12:15<19:31, 12.59s/it]INFO -
# Processing: Deadlift / volunteer_043
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  37%|███▋      | 55/147 [12:23<17:01, 11.10s/it]INFO -
# Processing: Deadlift / volunteer_044
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  38%|███▊      | 56/147 [12:41<20:08, 13.28s/it]INFO -
# Processing: Calf raises / volunteer_031
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front landmarks:  39%|███▉      | 57/147 [12:47<16:37, 11.09s/it]INFO -
# Processing: Calf raises / volunteer_038
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front landmarks:  39%|███▉      | 58/147 [12:58<16:09, 10.90s/it]INFO -
# Processing: Calf raises / volunteer_039
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front landmarks:  40%|████      | 59/147 [13:12<17:41, 12.06s/it]INFO -
# Processing: Calf raises / volunteer_040
# INFO -   ✓ Extracted 9 rep(s)
# Extracting front landmarks:  41%|████      | 60/147 [13:18<14:35, 10.07s/it]INFO -
# Processing: Calf raises / volunteer_041
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  41%|████▏     | 61/147 [13:24<12:34,  8.78s/it]INFO -
# Processing: Calf raises / volunteer_043
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  42%|████▏     | 62/147 [13:30<11:32,  8.15s/it]INFO -
# Processing: Calf raises / volunteer_044
# INFO -   ✓ Extracted 9 rep(s)
# Extracting front landmarks:  43%|████▎     | 63/147 [13:37<10:59,  7.85s/it]INFO -
# Processing: Calf raises / volunteer_045
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  44%|████▎     | 64/147 [13:49<12:18,  8.89s/it]INFO -
# Processing: Hummer curls / volunteer_001
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front landmarks:  44%|████▍     | 65/147 [14:00<13:17,  9.73s/it]INFO -
# Processing: Hummer curls / volunteer_010
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  45%|████▍     | 66/147 [14:13<14:21, 10.64s/it]INFO -
# Processing: Hummer curls / volunteer_002
# INFO -   ✓ Extracted 15 rep(s)
# Extracting front landmarks:  46%|████▌     | 67/147 [14:34<18:07, 13.60s/it]INFO -
# Processing: Hummer curls / volunteer_003
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  46%|████▋     | 68/147 [15:00<22:57, 17.44s/it]INFO -
# Processing: Hummer curls / volunteer_004
# INFO -   ✓ Extracted 9 rep(s)
# Extracting front landmarks:  47%|████▋     | 69/147 [15:14<21:28, 16.52s/it]INFO -
# Processing: Hummer curls / volunteer_046
# INFO -   ✓ Extracted 13 rep(s)
# Extracting front landmarks:  48%|████▊     | 70/147 [15:27<19:32, 15.22s/it]INFO -
# Processing: Hummer curls / volunteer_005
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  48%|████▊     | 71/147 [15:39<18:16, 14.42s/it]INFO -
# Processing: Hummer curls / volunteer_050
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front landmarks:  49%|████▉     | 72/147 [15:53<17:53, 14.32s/it]INFO -
# Processing: Hummer curls / volunteer_006
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front landmarks:  50%|████▉     | 73/147 [16:35<27:46, 22.51s/it]INFO -
# Processing: Hummer curls / volunteer_007
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  50%|█████     | 74/147 [16:54<26:07, 21.47s/it]INFO -
# Processing: Hummer curls / volunteer_008
# INFO -   ✓ Extracted 8 rep(s)
# Extracting front landmarks:  51%|█████     | 75/147 [17:04<21:47, 18.16s/it]INFO -
# Processing: Hummer curls / volunteer_009
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  52%|█████▏    | 76/147 [17:13<18:04, 15.28s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_001
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front landmarks:  52%|█████▏    | 77/147 [17:40<21:47, 18.68s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_010
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  53%|█████▎    | 78/147 [18:02<22:41, 19.73s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_002
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front landmarks:  54%|█████▎    | 79/147 [18:24<23:05, 20.38s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_039
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  54%|█████▍    | 80/147 [19:13<32:35, 29.18s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_004
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  55%|█████▌    | 81/147 [19:28<27:28, 24.98s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_046
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  56%|█████▌    | 82/147 [19:47<25:05, 23.16s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_049
# INFO -   ✓ Extracted 5 rep(s)
# Extracting front landmarks:  56%|█████▋    | 83/147 [20:00<21:27, 20.12s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_005
# INFO -   ✓ Extracted 6 rep(s)
# Extracting front landmarks:  57%|█████▋    | 84/147 [20:41<27:42, 26.39s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_050
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  58%|█████▊    | 85/147 [21:04<26:07, 25.29s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_006
# INFO -   ✓ Extracted 7 rep(s)
# Extracting front landmarks:  59%|█████▊    | 86/147 [21:55<33:21, 32.81s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_007
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  59%|█████▉    | 87/147 [22:31<33:58, 33.98s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_008
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  60%|█████▉    | 88/147 [22:58<31:13, 31.75s/it]INFO -
# Processing: Lateral Raises / volunteer_001
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  61%|██████    | 89/147 [23:08<24:32, 25.39s/it]INFO -
# Processing: Lateral Raises / volunteer_010
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  61%|██████    | 90/147 [23:23<20:58, 22.07s/it]INFO -
# Processing: Lateral Raises / volunteer_002
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front landmarks:  62%|██████▏   | 91/147 [23:36<18:16, 19.58s/it]INFO -
# Processing: Lateral Raises / volunteer_003
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  63%|██████▎   | 92/147 [23:53<17:14, 18.80s/it]INFO -
# Processing: Lateral Raises / volunteer_031
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  63%|██████▎   | 93/147 [24:03<14:21, 15.96s/it]INFO -
# Processing: Lateral Raises / volunteer_004
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  64%|██████▍   | 94/147 [24:12<12:18, 13.93s/it]INFO -
# Processing: Lateral Raises / volunteer_046
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  65%|██████▍   | 95/147 [24:22<11:08, 12.86s/it]INFO -
# Processing: Lateral Raises / volunteer_005
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  65%|██████▌   | 96/147 [24:38<11:44, 13.81s/it]INFO -
# Processing: Lateral Raises / volunteer_050
# INFO -   ✓ Extracted 16 rep(s)
# Extracting front landmarks:  66%|██████▌   | 97/147 [24:55<12:15, 14.71s/it]INFO -
# Processing: Lateral Raises / volunteer_007
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  67%|██████▋   | 98/147 [25:19<14:08, 17.32s/it]INFO -
# Processing: Lateral Raises / volunteer_008
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  67%|██████▋   | 99/147 [25:31<12:46, 15.96s/it]INFO -
# Processing: Bulgarian split squat / volunteer_003
# INFO -   ✓ Extracted 7 rep(s)
# Extracting front landmarks:  68%|██████▊   | 100/147 [25:43<11:31, 14.71s/it]INFO -
# Processing: Bulgarian split squat / volunteer_031
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  69%|██████▊   | 101/147 [25:54<10:27, 13.64s/it]INFO -
# Processing: Bulgarian split squat / volunteer_039
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front landmarks:  69%|██████▉   | 102/147 [26:24<13:52, 18.50s/it]INFO -
# Processing: Bulgarian split squat / volunteer_004
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  70%|███████   | 103/147 [26:36<12:10, 16.60s/it]INFO -
# Processing: Bulgarian split squat / volunteer_046
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  71%|███████   | 104/147 [26:47<10:40, 14.90s/it]INFO -
# Processing: Bulgarian split squat / volunteer_047
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  71%|███████▏  | 105/147 [27:09<11:56, 17.05s/it]INFO -
# Processing: Bulgarian split squat / volunteer_048
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  72%|███████▏  | 106/147 [27:30<12:26, 18.20s/it]INFO -
# Processing: Bulgarian split squat / volunteer_005
# INFO -   ✓ Extracted 9 rep(s)
# Extracting front landmarks:  73%|███████▎  | 107/147 [27:43<11:01, 16.53s/it]INFO -
# Processing: Bulgarian split squat / volunteer_050
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  73%|███████▎  | 108/147 [27:56<10:10, 15.67s/it]INFO -
# Processing: EZ Bar Curls / volunteer_011
# INFO -   ✓ Extracted 14 rep(s)
# Extracting front landmarks:  74%|███████▍  | 109/147 [28:26<12:29, 19.73s/it]INFO -
# Processing: EZ Bar Curls / volunteer_012
# INFO -   ✓ Extracted 13 rep(s)
# Extracting front landmarks:  75%|███████▍  | 110/147 [28:46<12:20, 20.00s/it]INFO -
# Processing: EZ Bar Curls / volunteer_013
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  76%|███████▌  | 111/147 [29:07<12:13, 20.36s/it]INFO -
# Processing: EZ Bar Curls / volunteer_014
# INFO -   ✓ Extracted 8 rep(s)
# Extracting front landmarks:  76%|███████▌  | 112/147 [29:25<11:20, 19.45s/it]INFO -
# Processing: EZ Bar Curls / volunteer_015
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  77%|███████▋  | 113/147 [29:37<09:49, 17.34s/it]INFO -
# Processing: EZ Bar Curls / volunteer_020
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front landmarks:  78%|███████▊  | 114/147 [30:12<12:29, 22.71s/it]INFO -
# Processing: EZ Bar Curls / volunteer_022
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  78%|███████▊  | 115/147 [30:46<13:49, 25.91s/it]INFO -
# Processing: EZ Bar Curls / volunteer_023
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  79%|███████▉  | 116/147 [31:24<15:19, 29.67s/it]INFO -
# Processing: EZ Bar Curls / volunteer_024
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  80%|███████▉  | 117/147 [31:53<14:37, 29.26s/it]INFO -
# Processing: EZ Bar Curls / volunteer_025
# INFO -   ✓ Extracted 9 rep(s)
# Extracting front landmarks:  80%|████████  | 118/147 [32:23<14:22, 29.73s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_011
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  81%|████████  | 119/147 [32:52<13:41, 29.34s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_012
# INFO -   ✓ Extracted 16 rep(s)
# Extracting front landmarks:  82%|████████▏ | 120/147 [33:08<11:26, 25.42s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_014
# INFO -   ✓ Extracted 8 rep(s)
# Extracting front landmarks:  82%|████████▏ | 121/147 [33:18<08:59, 20.75s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_015
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front landmarks:  83%|████████▎ | 122/147 [33:47<09:41, 23.24s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_016
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  84%|████████▎ | 123/147 [34:22<10:45, 26.88s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_017
# INFO -   ✓ Extracted 17 rep(s)
# Extracting front landmarks:  84%|████████▍ | 124/147 [34:58<11:15, 29.35s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_018
# INFO -   ✓ Extracted 13 rep(s)
# Extracting front landmarks:  85%|████████▌ | 125/147 [35:17<09:42, 26.49s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_022
# INFO -   ✓ Extracted 8 rep(s)
# Extracting front landmarks:  86%|████████▌ | 126/147 [35:33<08:06, 23.17s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_023
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  86%|████████▋ | 127/147 [35:55<07:36, 22.83s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_026
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front landmarks:  87%|████████▋ | 128/147 [36:10<06:27, 20.40s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_014
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front landmarks:  88%|████████▊ | 129/147 [36:31<06:10, 20.58s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_015
# INFO -   ✓ Extracted 13 rep(s)
# Extracting front landmarks:  88%|████████▊ | 130/147 [36:44<05:14, 18.48s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_016
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  89%|████████▉ | 131/147 [37:04<05:01, 18.82s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_019
# INFO -   ✓ Extracted 13 rep(s)
# Extracting front landmarks:  90%|████████▉ | 132/147 [37:17<04:19, 17.29s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_020
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  90%|█████████ | 133/147 [37:37<04:11, 17.97s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_021
# INFO -   ✓ Extracted 8 rep(s)
# Extracting front landmarks:  91%|█████████ | 134/147 [37:54<03:48, 17.55s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_022
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  92%|█████████▏| 135/147 [38:31<04:42, 23.51s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_023
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  93%|█████████▎| 136/147 [39:12<05:16, 28.79s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_027
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  93%|█████████▎| 137/147 [39:29<04:12, 25.24s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_028
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  94%|█████████▍| 138/147 [39:38<03:03, 20.42s/it]INFO -
# Processing: Shrugs / volunteer_014
# INFO -   ✓ Extracted 6 rep(s)
# Extracting front landmarks:  95%|█████████▍| 139/147 [39:45<02:10, 16.25s/it]INFO -
# Processing: Shrugs / volunteer_015
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front landmarks:  95%|█████████▌| 140/147 [40:04<01:59, 17.07s/it]INFO -
# Processing: Shrugs / volunteer_020
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front landmarks:  96%|█████████▌| 141/147 [40:20<01:40, 16.69s/it]INFO -
# Processing: Shrugs / volunteer_022
# INFO -   ✓ Extracted 11 rep(s)
# Extracting front landmarks:  97%|█████████▋| 142/147 [40:46<01:38, 19.69s/it]INFO -
# Processing: Shrugs / volunteer_023
# INFO -   ✓ Extracted 12 rep(s)
# Extracting front landmarks:  97%|█████████▋| 143/147 [41:00<01:12, 18.05s/it]INFO -
# Processing: Shrugs / volunteer_033
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks:  98%|█████████▊| 144/147 [41:20<00:55, 18.40s/it]INFO -
# Processing: Shrugs / volunteer_034
# INFO -   ✓ Extracted 9 rep(s)
# Extracting front landmarks:  99%|█████████▊| 145/147 [41:36<00:35, 17.73s/it]INFO -
# Processing: Shrugs / volunteer_035
# INFO -   ✓ Extracted 14 rep(s)
# Extracting front landmarks:  99%|█████████▉| 146/147 [41:53<00:17, 17.51s/it]INFO -
# Processing: Shrugs / volunteer_036
# INFO -   ✓ Extracted 10 rep(s)
# Extracting front landmarks: 100%|██████████| 147/147 [42:11<00:00, 17.22s/it]
# INFO -
# ✓ Successfully extracted 1574 reps from 1574 videos
# INFO - Building temporal landmarks (T_fixed=50)...
# INFO - Computing feature representations from landmarks...
# INFO -   - Angles: (1574, 50, 13) (13 features)
# INFO -   - Distances: (1574, 50, 6) (6 features)
# INFO -   - All features: (1574, 50, 19) (19 features)
# INFO -
# ============================================================
# [extract_raw_pose_landmarks] Completed front view:
#   - Total reps: 1574
#   - Videos processed: 1574
#   - Frames extracted: 136796
#   - Unique subjects: 49
#   - Unique exercises: 15
#   - Failed videos: 0
#   - Landmarks: (1574, 50, 33, 3)
#   - Angles (13): (1574, 50, 13)
#   - Distances (6): (1574, 50, 6)
#   - All features (19): (1574, 50, 19)
# ============================================================
# INFO - Saving to /mnt/d/Graduation Project/ai-virtual-coach/datasets/Mediapipe pose estimates/pose_data_front_19features.npz...
# INFO - ✓ Saved landmarks and features to /mnt/d/Graduation Project/ai-virtual-coach/datasets/Mediapipe pose estimates/pose_data_front_19features.npz
# ============================================================
# FRONT VIEW SUMMARY
# ============================================================
# Total reps extracted: 1574
# Unique subjects: 49
# Unique exercises: 15
# Videos processed: 1574
# Total frames extracted: 136796
# Failed videos: 0
#
# 📐 Feature shapes:
#   Raw landmarks: (1574, 50, 33, 3) (N, T, 33 landmarks, xyz)
#   Angles only:   (1574, 50, 13) (N, T, 13 angles)
#   Distances:     (1574, 50, 6) (N, T, 6 distances)
#   All features:  (1574, 50, 19) (N, T, 19 features)
#
# ⏱️ Tempo Statistics:
#   Duration (mean/median): 2.53s / 2.37s
#   Frame count (mean/median): 87.3 / 73
#   FPS values: [23.148148, 23.809525, 24.0, 24.019608, 24.038462, 24.074074, 24.09091, 24.107143, 24.122807, 24.152542, 24.180328, 24.404762, 24.468084, 24.479166, 24.489796, 27.894737, 28.891376, 28.947369, 29.085873, 29.111841, 29.186604, 29.290617, 29.355078, 29.401089, 29.425837, 29.438002, 29.473684, 29.496819, 29.504131, 29.513035, 29.519451, 29.550941, 29.56327, 29.570747, 29.587482, 29.605263, 29.645542, 29.650461, 29.653402, 29.65675, 29.665071, 29.67742, 29.70297, 29.707602, 29.721363, 29.736841, 29.739397, 29.748283, 29.757086, 29.764065, 29.776674, 29.779112, 29.78177, 29.794827, 29.799852, 29.807692, 29.813665, 29.824562, 29.834253, 29.838709, 29.840656, 29.848595, 29.856459, 29.8627, 29.864254, 29.871977, 29.878542, 29.881155, 29.887218, 29.89011, 29.891523, 29.894737, 29.899216, 29.910269, 29.916897, 29.9293, 29.93135, 29.938482, 29.94152, 29.945553, 29.950901, 29.951166, 29.959515, 29.967777, 29.96942, 29.97003, 29.972752, 29.973238, 29.975, 29.97543, 29.975826, 29.97621, 29.978586, 29.978888, 29.980013, 29.980532, 29.980782, 29.981262, 29.981493, 29.98405, 29.986732, 29.987185, 29.98864, 29.99007, 30.0, 30.003, 30.013, 30.015633, 30.019493, 30.025, 30.025885, 30.03096, 30.033125, 30.038, 30.038511, 30.042675, 30.045988, 30.050934, 30.05707, 30.060728, 30.063158, 30.065, 30.074257, 30.075188, 30.083103, 30.084349, 30.087029, 30.089375, 30.092878, 30.094044, 30.103296, 30.103806, 30.110159, 30.116959, 30.121458, 30.12704, 30.130371, 30.13561, 30.143541, 30.152802, 30.154333, 30.159668, 30.164965, 30.175438, 30.17988, 30.185759, 30.190863, 30.193905, 30.194805, 30.198019, 30.200308, 30.20595, 30.215828, 30.217787, 30.225563, 30.233767, 30.235163, 30.240856, 30.244625, 30.249308, 30.2521, 30.263159, 30.269524, 30.27027, 30.281183, 30.30303, 30.31579, 30.316742, 30.328297, 30.33241, 30.340557, 30.343512, 30.34682, 30.35343, 30.357143, 30.364372, 30.379747, 30.393997, 30.424528, 30.430622, 30.440588, 30.443975, 30.451128, 30.470915, 30.50109, 30.584707, 30.76923, 30.882353, 59.677418, 59.94006, 60.0, 60.007]

# %% [markdown]
# ## Process Side View (Enhanced - Raw Landmarks + Features)

# %%
print("="*60)
print("PROCESSING SIDE VIEW (Enhanced v2)")
print("="*60)

side_output_path = OUTPUT_DIR / 'pose_data_side_19_features.npz'

# Use the new extraction function
side_dataset, side_stats, side_failed = extract_raw_pose_landmarks(
    clips_path=str(CLIPS_PATH),
    view='side',
    T_fixed=T_FIXED,
    output_path=str(side_output_path),
    version_tag=VERSION
)

print("\n" + "="*60)
print("SIDE VIEW SUMMARY")
print("="*60)
print(f"Total reps extracted: {side_stats['total_reps']}")
print(f"Unique subjects: {side_stats['unique_subjects']}")
print(f"Unique exercises: {side_stats['unique_exercises']}")
print(f"Videos processed: {side_stats['total_videos_processed']}")
print(f"Total frames extracted: {side_stats['total_frames_extracted']}")
print(f"Failed videos: {side_stats['failed_videos']}")
print(f"\n📐 Feature shapes:")
print(f"  Raw landmarks: {side_stats['landmarks_shape']} (N, T, 33 landmarks, xyz)")
print(f"  Angles only:   {side_stats['angles_shape']} (N, T, 13 angles)")
print(f"  Distances:     {side_stats['distances_shape']} (N, T, 6 distances)")
print(f"  All features:  {side_stats['all_features_shape']} (N, T, 19 features)")
print(f"\n⏱️ Tempo Statistics:")
print(f"  Duration (mean/median): {side_stats['tempo_stats']['duration_mean']:.2f}s / {side_stats['tempo_stats']['duration_median']:.2f}s")
print(f"  Frame count (mean/median): {side_stats['tempo_stats']['frame_count_mean']:.1f} / {side_stats['tempo_stats']['frame_count_median']:.0f}")
print(f"  FPS values: {side_stats['tempo_stats']['fps_unique']}")
print(f"\n📁 Output File: {side_stats.get('output_file', 'N/A')}")
# Out:
# INFO - Scanning clips directory for side view...
# ============================================================
# PROCESSING SIDE VIEW (Enhanced v2)
# ============================================================
# Scanning side videos: 100%|██████████| 15/15 [00:04<00:00,  3.71it/s]
# INFO - [scan_clips_directory] Scanned side view: 149 samples, 1571 videos, 49 subjects, 15 exercises
# INFO - Found 149 sample(s) to process
# Extracting side landmarks:   0%|          | 0/149 [00:00<?, ?it/s]INFO -
# Processing: Dumbbell shoulder press / volunteer_001
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:   1%|          | 1/149 [00:19<48:16, 19.57s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_010
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:   1%|▏         | 2/149 [00:40<50:17, 20.53s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_002
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:   2%|▏         | 3/149 [00:54<42:41, 17.55s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_003
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:   3%|▎         | 4/149 [01:10<40:45, 16.87s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_031
# INFO -   ✓ Extracted 8 rep(s)
# Extracting side landmarks:   3%|▎         | 5/149 [01:17<32:13, 13.43s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_004
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:   4%|▍         | 6/149 [01:29<30:30, 12.80s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_046
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:   5%|▍         | 7/149 [01:44<31:41, 13.39s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_005
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:   5%|▌         | 8/149 [01:56<30:30, 12.98s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_050
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:   6%|▌         | 9/149 [02:08<29:46, 12.76s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_006
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:   7%|▋         | 10/149 [02:24<31:56, 13.79s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_007
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:   7%|▋         | 11/149 [02:44<36:12, 15.74s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_008
# INFO -   ✓ Extracted 9 rep(s)
# Extracting side landmarks:   8%|▊         | 12/149 [03:02<37:14, 16.31s/it]INFO -
# Processing: Dumbbell shoulder press / volunteer_009
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:   9%|▊         | 13/149 [03:14<34:21, 15.16s/it]INFO -
# Processing: Weighted Sqauts / volunteer_014
# INFO -   ✓ Extracted 8 rep(s)
# Extracting side landmarks:   9%|▉         | 14/149 [03:23<29:22, 13.06s/it]INFO -
# Processing: Weighted Sqauts / volunteer_015
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  10%|█         | 15/149 [03:38<30:27, 13.64s/it]INFO -
# Processing: Weighted Sqauts / volunteer_020
# INFO -   ✓ Extracted 9 rep(s)
# Extracting side landmarks:  11%|█         | 16/149 [03:57<33:57, 15.32s/it]INFO -
# Processing: Weighted Sqauts / volunteer_021
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  11%|█▏        | 17/149 [04:19<38:07, 17.33s/it]INFO -
# Processing: Weighted Sqauts / volunteer_022
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  12%|█▏        | 18/149 [04:37<38:27, 17.62s/it]INFO -
# Processing: Weighted Sqauts / volunteer_023
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  13%|█▎        | 19/149 [04:54<37:44, 17.42s/it]INFO -
# Processing: Weighted Sqauts / volunteer_029
# INFO -   ✓ Extracted 9 rep(s)
# Extracting side landmarks:  13%|█▎        | 20/149 [05:09<35:44, 16.62s/it]INFO -
# Processing: Weighted Sqauts / volunteer_030
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  14%|█▍        | 21/149 [05:24<34:47, 16.31s/it]INFO -
# Processing: Weighted Sqauts / volunteer_032
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  15%|█▍        | 22/149 [05:37<32:04, 15.15s/it]INFO -
# Processing: Seated biceps curls / volunteer_031
# INFO -   ✓ Extracted 8 rep(s)
# Extracting side landmarks:  15%|█▌        | 23/149 [05:44<27:02, 12.88s/it]INFO -
# Processing: Seated biceps curls / volunteer_038
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  16%|█▌        | 24/149 [05:56<26:14, 12.60s/it]INFO -
# Processing: Seated biceps curls / volunteer_039
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  17%|█▋        | 25/149 [06:09<25:48, 12.49s/it]INFO -
# Processing: Seated biceps curls / volunteer_040
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  17%|█▋        | 26/149 [06:19<24:29, 11.95s/it]INFO -
# Processing: Seated biceps curls / volunteer_041
# INFO -   ✓ Extracted 9 rep(s)
# Extracting side landmarks:  18%|█▊        | 27/149 [06:31<24:07, 11.86s/it]INFO -
# Processing: Seated biceps curls / volunteer_042
# INFO -   ✓ Extracted 14 rep(s)
# Extracting side landmarks:  19%|█▉        | 28/149 [06:55<31:05, 15.42s/it]INFO -
# Processing: Seated biceps curls / volunteer_043
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  19%|█▉        | 29/149 [07:03<26:46, 13.39s/it]INFO -
# Processing: Seated biceps curls / volunteer_044
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  20%|██        | 30/149 [07:18<27:12, 13.72s/it]INFO -
# Processing: Seated biceps curls / volunteer_045
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  21%|██        | 31/149 [07:31<26:40, 13.56s/it]INFO -
# Processing: Triceps Kickbacks / volunteer_031
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  21%|██▏       | 32/149 [07:39<23:05, 11.84s/it]INFO -
# Processing: Triceps Kickbacks / volunteer_038
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  22%|██▏       | 33/149 [07:49<21:53, 11.32s/it]INFO -
# Processing: Triceps Kickbacks / volunteer_039
# INFO -   ✓ Extracted 6 rep(s)
# Extracting side landmarks:  23%|██▎       | 34/149 [07:54<18:24,  9.60s/it]INFO -
# Processing: Triceps Kickbacks / volunteer_040
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  23%|██▎       | 35/149 [08:04<18:14,  9.60s/it]INFO -
# Processing: Triceps Kickbacks / volunteer_041
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  24%|██▍       | 36/149 [08:13<17:29,  9.29s/it]INFO -
# Processing: Triceps Kickbacks / volunteer_042
# INFO -   ✓ Extracted 9 rep(s)
# Extracting side landmarks:  25%|██▍       | 37/149 [08:21<16:55,  9.07s/it]INFO -
# Processing: Triceps Kickbacks / volunteer_043
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  26%|██▌       | 38/149 [08:29<16:11,  8.75s/it]INFO -
# Processing: Triceps Kickbacks / volunteer_044
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  26%|██▌       | 39/149 [08:40<16:56,  9.24s/it]INFO -
# Processing: Triceps Kickbacks / volunteer_045
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  27%|██▋       | 40/149 [08:50<17:10,  9.46s/it]INFO -
# Processing: Rows / volunteer_031
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side landmarks:  28%|██▊       | 41/149 [08:59<16:50,  9.35s/it]INFO -
# Processing: Rows / volunteer_038
# INFO -   ✓ Extracted 13 rep(s)
# Extracting side landmarks:  28%|██▊       | 42/149 [09:10<17:46,  9.97s/it]INFO -
# Processing: Rows / volunteer_039
# INFO -   ✓ Extracted 8 rep(s)
# Extracting side landmarks:  29%|██▉       | 43/149 [09:17<15:57,  9.03s/it]INFO -
# Processing: Rows / volunteer_040
# INFO -   ✓ Extracted 13 rep(s)
# Extracting side landmarks:  30%|██▉       | 44/149 [09:28<16:48,  9.61s/it]INFO -
# Processing: Rows / volunteer_041
# INFO -   ✓ Extracted 14 rep(s)
# Extracting side landmarks:  30%|███       | 45/149 [09:39<17:17,  9.98s/it]INFO -
# Processing: Rows / volunteer_042
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side landmarks:  31%|███       | 46/149 [09:53<19:06, 11.13s/it]INFO -
# Processing: Rows / volunteer_043
# INFO -   ✓ Extracted 13 rep(s)
# Extracting side landmarks:  32%|███▏      | 47/149 [10:00<17:05, 10.06s/it]INFO -
# Processing: Rows / volunteer_044
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  32%|███▏      | 48/149 [10:10<16:53, 10.04s/it]INFO -
# Processing: Rows / volunteer_045
# INFO -   ✓ Extracted 13 rep(s)
# Extracting side landmarks:  33%|███▎      | 49/149 [10:22<17:34, 10.54s/it]INFO -
# Processing: Deadlift / volunteer_031
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  34%|███▎      | 50/149 [10:35<18:29, 11.20s/it]INFO -
# Processing: Deadlift / volunteer_038
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side landmarks:  34%|███▍      | 51/149 [10:48<19:21, 11.85s/it]INFO -
# Processing: Deadlift / volunteer_039
# INFO -   ✓ Extracted 13 rep(s)
# Extracting side landmarks:  35%|███▍      | 52/149 [11:05<21:44, 13.45s/it]INFO -
# Processing: Deadlift / volunteer_040
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  36%|███▌      | 53/149 [11:16<20:13, 12.64s/it]INFO -
# Processing: Deadlift / volunteer_041
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side landmarks:  36%|███▌      | 54/149 [11:30<20:51, 13.18s/it]INFO -
# Processing: Deadlift / volunteer_043
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  37%|███▋      | 55/149 [11:39<18:28, 11.80s/it]INFO -
# Processing: Deadlift / volunteer_044
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  38%|███▊      | 56/149 [11:57<21:20, 13.77s/it]INFO -
# Processing: Deadlift / volunteer_045
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  38%|███▊      | 57/149 [12:19<24:41, 16.10s/it]INFO -
# Processing: Calf raises / volunteer_031
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side landmarks:  39%|███▉      | 58/149 [12:25<19:57, 13.16s/it]INFO -
# Processing: Calf raises / volunteer_038
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side landmarks:  40%|███▉      | 59/149 [12:37<19:08, 12.77s/it]INFO -
# Processing: Calf raises / volunteer_039
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side landmarks:  40%|████      | 60/149 [12:49<18:36, 12.55s/it]INFO -
# Processing: Calf raises / volunteer_040
# INFO -   ✓ Extracted 9 rep(s)
# Extracting side landmarks:  41%|████      | 61/149 [12:54<15:01, 10.25s/it]INFO -
# Processing: Calf raises / volunteer_041
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  42%|████▏     | 62/149 [13:00<13:03,  9.01s/it]INFO -
# Processing: Calf raises / volunteer_042
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side landmarks:  42%|████▏     | 63/149 [13:10<13:32,  9.44s/it]INFO -
# Processing: Calf raises / volunteer_043
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  43%|████▎     | 64/149 [13:18<12:33,  8.87s/it]INFO -
# Processing: Calf raises / volunteer_044
# INFO -   ✓ Extracted 9 rep(s)
# Extracting side landmarks:  44%|████▎     | 65/149 [13:25<11:52,  8.48s/it]INFO -
# Processing: Calf raises / volunteer_045
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side landmarks:  44%|████▍     | 66/149 [13:36<12:27,  9.00s/it]INFO -
# Processing: Hummer curls / volunteer_001
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  45%|████▍     | 67/149 [13:47<13:23,  9.80s/it]INFO -
# Processing: Hummer curls / volunteer_010
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  46%|████▌     | 68/149 [14:14<20:04, 14.87s/it]INFO -
# Processing: Hummer curls / volunteer_002
# INFO -   ✓ Extracted 15 rep(s)
# Extracting side landmarks:  46%|████▋     | 69/149 [14:31<20:51, 15.64s/it]INFO -
# Processing: Hummer curls / volunteer_003
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  47%|████▋     | 70/149 [14:57<24:27, 18.57s/it]INFO -
# Processing: Hummer curls / volunteer_004
# INFO -   ✓ Extracted 9 rep(s)
# Extracting side landmarks:  48%|████▊     | 71/149 [15:13<23:05, 17.76s/it]INFO -
# Processing: Hummer curls / volunteer_046
# INFO -   ✓ Extracted 13 rep(s)
# Extracting side landmarks:  48%|████▊     | 72/149 [15:27<21:29, 16.75s/it]INFO -
# Processing: Hummer curls / volunteer_005
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  49%|████▉     | 73/149 [15:36<18:15, 14.42s/it]INFO -
# Processing: Hummer curls / volunteer_050
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side landmarks:  50%|████▉     | 74/149 [15:48<17:06, 13.69s/it]INFO -
# Processing: Hummer curls / volunteer_006
# INFO -   ✓ Extracted 9 rep(s)
# Extracting side landmarks:  50%|█████     | 75/149 [16:03<17:20, 14.06s/it]INFO -
# Processing: Hummer curls / volunteer_007
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  51%|█████     | 76/149 [16:19<17:42, 14.55s/it]INFO -
# Processing: Hummer curls / volunteer_008
# INFO -   ✓ Extracted 8 rep(s)
# Extracting side landmarks:  52%|█████▏    | 77/149 [16:29<16:04, 13.40s/it]INFO -
# Processing: Hummer curls / volunteer_009
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  52%|█████▏    | 78/149 [16:39<14:29, 12.24s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_001
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side landmarks:  53%|█████▎    | 79/149 [17:29<27:27, 23.53s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_010
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  54%|█████▎    | 80/149 [18:06<31:43, 27.58s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_002
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side landmarks:  54%|█████▍    | 81/149 [18:32<30:53, 27.25s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_039
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  55%|█████▌    | 82/149 [18:59<30:08, 27.00s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_004
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  56%|█████▌    | 83/149 [19:17<26:54, 24.46s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_046
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  56%|█████▋    | 84/149 [19:39<25:29, 23.53s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_049
# INFO -   ✓ Extracted 5 rep(s)
# Extracting side landmarks:  57%|█████▋    | 85/149 [19:59<23:56, 22.45s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_005
# INFO -   ✓ Extracted 6 rep(s)
# Extracting side landmarks:  58%|█████▊    | 86/149 [20:19<23:02, 21.95s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_050
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  58%|█████▊    | 87/149 [20:40<22:18, 21.59s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_006
# INFO -   ✓ Extracted 7 rep(s)
# Extracting side landmarks:  59%|█████▉    | 88/149 [21:05<22:55, 22.54s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_007
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  60%|█████▉    | 89/149 [21:39<26:04, 26.07s/it]INFO -
# Processing: Standing Dumbbell Front Raises / volunteer_008
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  60%|██████    | 90/149 [22:06<25:54, 26.35s/it]INFO -
# Processing: Lateral Raises / volunteer_001
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  61%|██████    | 91/149 [22:25<23:25, 24.22s/it]INFO -
# Processing: Lateral Raises / volunteer_010
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  62%|██████▏   | 92/149 [22:47<22:11, 23.36s/it]INFO -
# Processing: Lateral Raises / volunteer_002
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side landmarks:  62%|██████▏   | 93/149 [23:02<19:26, 20.83s/it]INFO -
# Processing: Lateral Raises / volunteer_003
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  63%|██████▎   | 94/149 [23:16<17:12, 18.77s/it]INFO -
# Processing: Lateral Raises / volunteer_031
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  64%|██████▍   | 95/149 [23:24<14:06, 15.68s/it]INFO -
# Processing: Lateral Raises / volunteer_004
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  64%|██████▍   | 96/149 [23:34<12:18, 13.93s/it]INFO -
# Processing: Lateral Raises / volunteer_046
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  65%|██████▌   | 97/149 [23:48<12:06, 13.97s/it]INFO -
# Processing: Lateral Raises / volunteer_005
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  66%|██████▌   | 98/149 [24:00<11:22, 13.38s/it]INFO -
# Processing: Lateral Raises / volunteer_050
# INFO -   ✓ Extracted 14 rep(s)
# Extracting side landmarks:  66%|██████▋   | 99/149 [24:14<11:22, 13.65s/it]INFO -
# Processing: Lateral Raises / volunteer_007
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  67%|██████▋   | 100/149 [24:36<13:01, 15.96s/it]INFO -
# Processing: Lateral Raises / volunteer_008
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  68%|██████▊   | 101/149 [24:50<12:16, 15.33s/it]INFO -
# Processing: Bulgarian split squat / volunteer_003
# INFO -   ✓ Extracted 7 rep(s)
# Extracting side landmarks:  68%|██████▊   | 102/149 [24:56<09:53, 12.62s/it]INFO -
# Processing: Bulgarian split squat / volunteer_031
# INFO -   ✓ Extracted 7 rep(s)
# Extracting side landmarks:  69%|██████▉   | 103/149 [25:02<08:07, 10.60s/it]INFO -
# Processing: Bulgarian split squat / volunteer_039
# INFO -   ✓ Extracted 9 rep(s)
# Extracting side landmarks:  70%|██████▉   | 104/149 [25:15<08:31, 11.37s/it]INFO -
# Processing: Bulgarian split squat / volunteer_004
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  70%|███████   | 105/149 [25:32<09:35, 13.08s/it]INFO -
# Processing: Bulgarian split squat / volunteer_046
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  71%|███████   | 106/149 [25:47<09:47, 13.67s/it]INFO -
# Processing: Bulgarian split squat / volunteer_047
# INFO -   ✓ Extracted 9 rep(s)
# Extracting side landmarks:  72%|███████▏  | 107/149 [26:07<10:48, 15.45s/it]INFO -
# Processing: Bulgarian split squat / volunteer_048
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  72%|███████▏  | 108/149 [26:25<11:12, 16.40s/it]INFO -
# Processing: Bulgarian split squat / volunteer_005
# INFO -   ✓ Extracted 8 rep(s)
# Extracting side landmarks:  73%|███████▎  | 109/149 [26:39<10:19, 15.48s/it]INFO -
# Processing: Bulgarian split squat / volunteer_050
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  74%|███████▍  | 110/149 [26:54<10:04, 15.50s/it]INFO -
# Processing: EZ Bar Curls / volunteer_011
# INFO -   ✓ Extracted 14 rep(s)
# Extracting side landmarks:  74%|███████▍  | 111/149 [27:45<16:35, 26.20s/it]INFO -
# Processing: EZ Bar Curls / volunteer_012
# INFO -   ✓ Extracted 13 rep(s)
# Extracting side landmarks:  75%|███████▌  | 112/149 [28:17<17:13, 27.94s/it]INFO -
# Processing: EZ Bar Curls / volunteer_013
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  76%|███████▌  | 113/149 [28:58<19:00, 31.68s/it]INFO -
# Processing: EZ Bar Curls / volunteer_014
# INFO -   ✓ Extracted 8 rep(s)
# Extracting side landmarks:  77%|███████▋  | 114/149 [29:23<17:18, 29.67s/it]INFO -
# Processing: EZ Bar Curls / volunteer_015
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  77%|███████▋  | 115/149 [29:46<15:44, 27.79s/it]INFO -
# Processing: EZ Bar Curls / volunteer_020
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side landmarks:  78%|███████▊  | 116/149 [30:04<13:43, 24.95s/it]INFO -
# Processing: EZ Bar Curls / volunteer_022
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  79%|███████▊  | 117/149 [30:21<12:01, 22.54s/it]INFO -
# Processing: EZ Bar Curls / volunteer_023
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  79%|███████▉  | 118/149 [30:39<10:52, 21.06s/it]INFO -
# Processing: EZ Bar Curls / volunteer_024
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  80%|███████▉  | 119/149 [30:52<09:23, 18.79s/it]INFO -
# Processing: EZ Bar Curls / volunteer_025
# INFO -   ✓ Extracted 9 rep(s)
# Extracting side landmarks:  81%|████████  | 120/149 [31:07<08:27, 17.49s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_011
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  81%|████████  | 121/149 [31:23<08:01, 17.21s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_012
# INFO -   ✓ Extracted 16 rep(s)
# Extracting side landmarks:  82%|████████▏ | 122/149 [31:40<07:39, 17.03s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_014
# INFO -   ✓ Extracted 8 rep(s)
# Extracting side landmarks:  83%|████████▎ | 123/149 [31:50<06:29, 14.99s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_015
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side landmarks:  83%|████████▎ | 124/149 [32:10<06:47, 16.30s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_016
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  84%|████████▍ | 125/149 [32:30<07:03, 17.64s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_017
# INFO -   ✓ Extracted 17 rep(s)
# Extracting side landmarks:  85%|████████▍ | 126/149 [32:50<06:58, 18.21s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_018
# INFO -   ✓ Extracted 13 rep(s)
# Extracting side landmarks:  85%|████████▌ | 127/149 [33:09<06:45, 18.41s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_022
# INFO -   ✓ Extracted 8 rep(s)
# Extracting side landmarks:  86%|████████▌ | 128/149 [33:25<06:09, 17.62s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_023
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  87%|████████▋ | 129/149 [33:43<05:54, 17.73s/it]INFO -
# Processing: Inclined Dumbbell Bench Press / volunteer_026
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side landmarks:  87%|████████▋ | 130/149 [33:58<05:23, 17.01s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_014
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side landmarks:  88%|████████▊ | 131/149 [34:15<05:09, 17.17s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_015
# INFO -   ✓ Extracted 13 rep(s)
# Extracting side landmarks:  89%|████████▊ | 132/149 [34:37<05:16, 18.59s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_016
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  89%|████████▉ | 133/149 [34:59<05:12, 19.53s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_019
# INFO -   ✓ Extracted 13 rep(s)
# Extracting side landmarks:  90%|████████▉ | 134/149 [35:19<04:56, 19.76s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_020
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  91%|█████████ | 135/149 [35:44<04:55, 21.08s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_021
# INFO -   ✓ Extracted 8 rep(s)
# Extracting side landmarks:  91%|█████████▏| 136/149 [36:02<04:23, 20.24s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_022
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  92%|█████████▏| 137/149 [36:24<04:10, 20.84s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_023
# INFO -   ✓ Extracted 11 rep(s)
# Extracting side landmarks:  93%|█████████▎| 138/149 [36:48<03:59, 21.78s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_027
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  93%|█████████▎| 139/149 [37:04<03:19, 19.97s/it]INFO -
# Processing: Overhead Triceps Extension / volunteer_028
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  94%|█████████▍| 140/149 [37:14<02:33, 17.02s/it]INFO -
# Processing: Shrugs / volunteer_014
# INFO -   ✓ Extracted 6 rep(s)
# Extracting side landmarks:  95%|█████████▍| 141/149 [37:21<01:52, 14.07s/it]INFO -
# Processing: Shrugs / volunteer_015
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side landmarks:  95%|█████████▌| 142/149 [37:38<01:44, 14.98s/it]INFO -
# Processing: Shrugs / volunteer_020
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side landmarks:  96%|█████████▌| 143/149 [37:55<01:33, 15.60s/it]INFO -
# Processing: Shrugs / volunteer_022
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side landmarks:  97%|█████████▋| 144/149 [38:22<01:34, 18.82s/it]INFO -
# Processing: Shrugs / volunteer_023
# INFO -   ✓ Extracted 12 rep(s)
# Extracting side landmarks:  97%|█████████▋| 145/149 [38:36<01:10, 17.59s/it]INFO -
# Processing: Shrugs / volunteer_033
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks:  98%|█████████▊| 146/149 [38:51<00:50, 16.71s/it]INFO -
# Processing: Shrugs / volunteer_034
# INFO -   ✓ Extracted 9 rep(s)
# Extracting side landmarks:  99%|█████████▊| 147/149 [39:09<00:34, 17.21s/it]INFO -
# Processing: Shrugs / volunteer_035
# INFO -   ✓ Extracted 14 rep(s)
# Extracting side landmarks:  99%|█████████▉| 148/149 [39:25<00:16, 16.68s/it]INFO -
# Processing: Shrugs / volunteer_036
# INFO -   ✓ Extracted 10 rep(s)
# Extracting side landmarks: 100%|██████████| 149/149 [39:42<00:00, 15.99s/it]
# INFO -
# ✓ Successfully extracted 1571 reps from 1571 videos
# INFO - Building temporal landmarks (T_fixed=50)...
# INFO - Computing feature representations from landmarks...
# INFO -   - Angles: (1571, 50, 13) (13 features)
# INFO -   - Distances: (1571, 50, 6) (6 features)
# INFO -   - All features: (1571, 50, 19) (19 features)
# INFO -
# ============================================================
# [extract_raw_pose_landmarks] Completed side view:
#   - Total reps: 1571
#   - Videos processed: 1571
#   - Frames extracted: 126361
#   - Unique subjects: 49
#   - Unique exercises: 15
#   - Failed videos: 0
#   - Landmarks: (1571, 50, 33, 3)
#   - Angles (13): (1571, 50, 13)
#   - Distances (6): (1571, 50, 6)
#   - All features (19): (1571, 50, 19)
# ============================================================
# INFO - Saving to /mnt/d/Graduation Project/ai-virtual-coach/datasets/Mediapipe pose estimates/pose_data_side_19_features_19features.npz...
# INFO - ✓ Saved landmarks and features to /mnt/d/Graduation Project/ai-virtual-coach/datasets/Mediapipe pose estimates/pose_data_side_19_features_19features.npz
# ============================================================
# SIDE VIEW SUMMARY
# ============================================================
# Total reps extracted: 1571
# Unique subjects: 49
# Unique exercises: 15
# Videos processed: 1571
# Total frames extracted: 126361
# Failed videos: 0
#
# 📐 Feature shapes:
#   Raw landmarks: (1571, 50, 33, 3) (N, T, 33 landmarks, xyz)
#   Angles only:   (1571, 50, 13) (N, T, 13 angles)
#   Distances:     (1571, 50, 6) (N, T, 6 distances)
#   All features:  (1571, 50, 19) (N, T, 19 features)
#
# ⏱️ Tempo Statistics:
#   Duration (mean/median): 2.53s / 2.37s
#   Frame count (mean/median): 82.2 / 73
#   FPS values: [28.921568, 29.23077, 29.282297, 29.285715, 29.387754, 29.425837, 29.519451, 29.545454, 29.571428, 29.605263, 29.61039, 29.620564, 29.637096, 29.642857, 29.651163, 29.65909, 29.662077, 29.68421, 29.6875, 29.719625, 29.727272, 29.732143, 29.73913, 29.741379, 29.76704, 29.767443, 29.774437, 29.77612, 29.777779, 29.8, 29.850746, 29.864254, 29.885057, 29.91453, 29.916897, 29.918034, 29.938482, 29.962547, 29.96942, 29.97003, 29.971182, 29.972248, 29.972752, 29.973238, 29.973707, 29.974598, 29.97543, 29.97729, 29.979181, 29.983343, 29.98405, 29.984545, 29.996, 29.997, 30.0, 30.003, 30.01305, 30.017, 30.026, 30.027298, 30.031948, 30.033, 30.034, 30.038511, 30.069124, 30.11583, 30.123457, 30.143541, 30.15873, 30.175438, 30.215828, 30.221624, 30.237154, 30.24, 30.24055, 30.240856, 30.241936, 30.244625, 30.285715, 30.288462, 30.30303, 30.343512, 30.352942, 30.357143, 30.379747, 30.405405, 30.422535, 30.456852, 30.46045, 30.633802, 31.304348, 59.42857, 59.55224, 59.664806, 59.732143, 59.74026, 59.94006, 60.0]
#
# 📁 Output File: /mnt/d/Graduation Project/ai-virtual-coach/datasets/Mediapipe pose estimates/pose_data_side_19_features_19features.npz

# %% [markdown]
# ### Failed Videos (Side)

# %%
if side_failed:
    print(f"\n⚠️ {len(side_failed)} samples failed to process:")
    for item in side_failed[:10]:  # Show first 10
        print(f"  - {item['exercise']} / {item['subject']}: {item['error']}")
    if len(side_failed) > 10:
        print(f"  ... and {len(side_failed) - 10} more")
else:
    print("✅ All side view samples processed successfully!")
# Out:
# ✅ All side view samples processed successfully!

# %% [markdown]
# ## Combined Summary

# %%
print("="*60)
print("COMBINED SUMMARY (FRONT + SIDE)")
print("="*60)

total_reps = front_stats['total_reps'] + side_stats['total_reps']
total_videos = front_stats['total_videos_processed'] + side_stats['total_videos_processed']
total_frames = front_stats['total_frames_extracted'] + side_stats['total_frames_extracted']
total_failed = front_stats['failed_videos'] + side_stats['failed_videos']

# Combined unique counts
all_subjects = set(front_dataset['subject_ids']) | set(side_dataset['subject_ids'])
all_exercises = set(front_dataset['exercise_names']) | set(side_dataset['exercise_names'])

print(f"\n📄 Dataset Statistics:")
print(f"  Total reps: {total_reps}")
print(f"  Total videos: {total_videos}")
print(f"  Total frames: {total_frames}")
print(f"  Unique volunteers: {len(all_subjects)}")
print(f"  Unique exercises: {len(all_exercises)}")
print(f"  Failed samples: {total_failed}")

print(f"\n📁 Output Files:")
print(f"  Front Temporal: {front_stats.get('temporal_file', 'N/A')}")
print(f"  Side Temporal:  {side_stats.get('temporal_file', 'N/A')}")

print(f"\n✅ Preprocessing complete!")
# Out:
# ============================================================
# COMBINED SUMMARY (FRONT + SIDE)
# ============================================================
#
# 📄 Dataset Statistics:
#   Total reps: 3145
#   Total videos: 3145
#   Total frames: 263157
#   Unique volunteers: 49
#   Unique exercises: 15
#   Failed samples: 0
#
# 📁 Output Files:
#   Front Temporal: N/A
#   Side Temporal:  N/A
#
# ✅ Preprocessing complete!

# %% [markdown]
# ## Verify Output Files

# %%
# Load and inspect saved enhanced NPZ files
print("Verifying saved enhanced NPZ files...\n")

for view in ['front', 'side']:
    stats = front_stats if view == 'front' else side_stats
    
    output_file = stats.get('output_file')
    if output_file and os.path.exists(output_file):
        print(f"\n{'='*60}")
        print(f"{view.upper()} VIEW - ENHANCED FEATURES (v2)")
        print(f"{'='*60}")
        data = np.load(output_file, allow_pickle=True)
        print(f"  File: {os.path.basename(output_file)}")
        print(f"  Keys: {list(data.keys())}")
        print(f"\n  📊 Feature Arrays:")
        print(f"    X_landmarks:    {data['X_landmarks'].shape} - {data['X_landmarks'].dtype}")
        print(f"    X_angles:       {data['X_angles'].shape} - {data['X_angles'].dtype}")
        print(f"    X_distances:    {data['X_distances'].shape} - {data['X_distances'].dtype}")
        print(f"    X_all_features: {data['X_all_features'].shape} - {data['X_all_features'].dtype}")
        print(f"\n  📝 Metadata:")
        print(f"    exercise_names: {data['exercise_names'].shape}")
        print(f"    subject_ids:    {data['subject_ids'].shape}")
        print(f"    view:           {data['view']}")
        print(f"    T_fixed:        {data['T_fixed']}")
        print(f"\n  📐 Feature Names:")
        print(f"    angle_names ({len(data['angle_names'])}): {list(data['angle_names'])}")
        print(f"    distance_names ({len(data['distance_names'])}): {list(data['distance_names'])}")

print("\n✅ All files verified successfully!")
# Out:
# Verifying saved enhanced NPZ files...
#
#
# ============================================================
# FRONT VIEW - ENHANCED FEATURES (v2)
# ============================================================
#   File: pose_data_front_19features.npz
#   Keys: ['X_landmarks', 'X_angles', 'X_distances', 'X_all_features', 'exercise_names', 'subject_ids', 'tempo_duration_sec', 'tempo_frame_count', 'tempo_fps', 'view', 'T_fixed', 'angle_names', 'distance_names', 'all_feature_names']
#
#   📊 Feature Arrays:
#     X_landmarks:    (1574, 50, 33, 3) - float32
#     X_angles:       (1574, 50, 13) - float32
#     X_distances:    (1574, 50, 6) - float32
#     X_all_features: (1574, 50, 19) - float32
#
#   📝 Metadata:
#     exercise_names: (1574,)
#     subject_ids:    (1574,)
#     view:           front
#     T_fixed:        50
#
#   📐 Feature Names:
#     angle_names (13): ['left_elbow', 'right_elbow', 'left_shoulder', 'right_shoulder', 'left_hip', 'right_hip', 'left_knee', 'right_knee', 'torso_lean', 'left_ankle', 'right_ankle', 'left_wrist', 'right_wrist']
#     distance_names (6): ['left_ear_shoulder_vert', 'right_ear_shoulder_vert', 'left_wrist_shoulder_dist', 'right_wrist_shoulder_dist', 'left_elbow_hip_dist', 'right_elbow_hip_dist']
#
# ============================================================
# SIDE VIEW - ENHANCED FEATURES (v2)
# ============================================================
#   File: pose_data_side_19_features_19features.npz
#   Keys: ['X_landmarks', 'X_angles', 'X_distances', 'X_all_features', 'exercise_names', 'subject_ids', 'tempo_duration_sec', 'tempo_frame_count', 'tempo_fps', 'view', 'T_fixed', 'angle_names', 'distance_names', 'all_feature_names']
#
#   📊 Feature Arrays:
#     X_landmarks:    (1571, 50, 33, 3) - float32
#     X_angles:       (1571, 50, 13) - float32
#     X_distances:    (1571, 50, 6) - float32
#     X_all_features: (1571, 50, 19) - float32
#
#   📝 Metadata:
#     exercise_names: (1571,)
#     subject_ids:    (1571,)
#     view:           side
#     T_fixed:        50
#
#   📐 Feature Names:
#     angle_names (13): ['left_elbow', 'right_elbow', 'left_shoulder', 'right_shoulder', 'left_hip', 'right_hip', 'left_knee', 'right_knee', 'torso_lean', 'left_ankle', 'right_ankle', 'left_wrist', 'right_wrist']
#     distance_names (6): ['left_ear_shoulder_vert', 'right_ear_shoulder_vert', 'left_wrist_shoulder_dist', 'right_wrist_shoulder_dist', 'left_elbow_hip_dist', 'right_elbow_hip_dist']
#
# ✅ All files verified successfully!

# %% [markdown]
# ## Sample Data Inspection

# %%
# Inspect first few samples and new distance features
print("Sample data from front view:\n")
print("First 5 exercises:")
for i in range(min(5, len(front_dataset['exercise_names']))):
    print(f"  {i+1}. {front_dataset['exercise_names'][i]} (Subject {front_dataset['subject_ids'][i]})")

print("\n" + "="*60)
print("SAMPLE: All 19 Features (first rep, first 3 frames)")
print("="*60)
sample_all = front_dataset['X_all_features'][0, :3, :]
print(f"Shape: {sample_all.shape}")
print("\nFeature values:")
for t in range(3):
    print(f"\n  Frame {t}:")
    # Angles (0-12)
    print(f"    Angles: L_elbow={sample_all[t,0]:.1f}° R_elbow={sample_all[t,1]:.1f}°")
    print(f"            L_shoulder={sample_all[t,2]:.1f}° R_shoulder={sample_all[t,3]:.1f}°")
    print(f"            torso_lean={sample_all[t,8]:.1f}°")
    # Distances (13-18) - these are normalized by torso length
    print(f"    Distances: L_ear_shoulder={sample_all[t,13]:.3f} R_ear_shoulder={sample_all[t,14]:.3f}")
    print(f"               L_wrist_shoulder={sample_all[t,15]:.3f} R_wrist_shoulder={sample_all[t,16]:.3f}")
    print(f"               L_elbow_hip={sample_all[t,17]:.3f} R_elbow_hip={sample_all[t,18]:.3f}")

print("\n" + "="*60)
print("COMPARISON: Distance Features vs Angles")
print("="*60)
print("\nDistance features are normalized by torso length (scale-invariant):")
print("  - ear_shoulder_vert: Vertical distance from ear to shoulder")
print("    (smaller value = shoulder raised, useful for SHRUGS)")
print("  - wrist_shoulder_dist: 3D distance from wrist to shoulder")
print("    (captures arm extension in curls)")
print("  - elbow_hip_dist: 3D distance from elbow to hip")
print("    (differentiates arm position in CURL variants)")
# Out:
# Sample data from front view:
#
# First 5 exercises:
#   1. Dumbbell shoulder press (Subject 1)
#   2. Dumbbell shoulder press (Subject 1)
#   3. Dumbbell shoulder press (Subject 1)
#   4. Dumbbell shoulder press (Subject 1)
#   5. Dumbbell shoulder press (Subject 1)
#
# Static features (first rep, first 10 values):
# [128.39922   15.510805 101.697075 148.72682   47.029747 131.1648
#   19.645264  85.70126  161.67555   75.97429 ]
#
# Temporal features (first rep, first 5 frames):
# [[125.94949  131.30444  105.06773   94.97147  160.69958  130.76443
#   143.02394  166.71664   16.87413 ]
#  [116.06957  129.82344  101.49968   97.248924 164.11037  133.51707
#   134.34184  167.17041   16.920328]
#  [114.22898  130.19913  100.61363   98.5807   164.7034   135.01562
#   132.62128  167.30406   17.278519]
#  [114.594    130.73834  100.55692   99.13356  164.43755  135.65314
#   132.97652  167.35484   17.50489 ]
#  [115.18252  131.93718  100.53263   99.74887  164.18378  136.31961
#   133.1552   167.35368   17.760881]]

# %% [markdown]
# ## Phase 2: Regenerate with Specialized Features
#
# Regenerate NPZ files with Phase 2 specialized features (confusion cluster discrimination).

# %%
# Phase 2 Configuration
VERSION_EXTENDED = "37features"  # v3: includes 19 base + 18 specialized features

# Import specialized feature names from main preprocessing module
from preprocessing.preprocess_pose_RGB import (
    SPECIALIZED_FEATURE_NAMES,
    ALL_EXTENDED_FEATURE_NAMES,
)

print(f"Phase 2 Feature Sets:")
print(f"  - Specialized ({len(SPECIALIZED_FEATURE_NAMES)}): {list(SPECIALIZED_FEATURE_NAMES)}")
print(f"\n📊 Full feature breakdown (37 total):")
print(f"  - 13 joint angles")
print(f"  - 6 distance features")
print(f"  - 18 specialized discrimination features")
print(f"  - Total: 37 features per frame × 50 frames = 1850 features (flattened)")

# %%
# Process Front View with Extended Features (Phase 2)
print("="*60)
print("PROCESSING FRONT VIEW (Phase 2 - Extended Features)")
print("="*60)

front_output_path_v3 = OUTPUT_DIR / 'pose_data_front.npz'

# Use the updated extraction function (now includes extended features)
front_dataset_v3, front_stats_v3, front_failed_v3 = extract_raw_pose_landmarks(
    clips_path=str(CLIPS_PATH),
    view='front',
    T_fixed=T_FIXED,
    output_path=str(front_output_path_v3),
    version_tag=VERSION_EXTENDED
)

print("\n" + "="*60)
print("FRONT VIEW SUMMARY (Phase 2)")
print("="*60)
print(f"Total reps extracted: {front_stats_v3['total_reps']}")
print(f"Unique subjects: {front_stats_v3['unique_subjects']}")
print(f"Unique exercises: {front_stats_v3['unique_exercises']}")
print(f"\n📐 Base Feature shapes:")
print(f"  Raw landmarks: {front_stats_v3['landmarks_shape']}")
print(f"  Angles only:   {front_stats_v3['angles_shape']}")
print(f"  Distances:     {front_stats_v3['distances_shape']}")
print(f"  All features:  {front_stats_v3['all_features_shape']}")

if 'specialized_shape' in front_stats_v3:
    print(f"\n📐 Extended Feature shapes (Phase 2):")
    print(f"  Specialized:  {front_stats_v3['specialized_shape']} (14 features)")
    print(f"  Velocity:     {front_stats_v3['velocity_shape']} (7 features)")
    print(f"  Extended:     {front_stats_v3['extended_shape']} (21 features)")
    print(f"\n✅ Phase 2 extended features successfully computed!")
else:
    print(f"\n⚠️ Extended features not available in output")

# %%
# Process Side View with Specialized Features (Phase 2)
print("="*60)
print("PROCESSING SIDE VIEW (Phase 2 - Specialized Features)")
print("="*60)

side_output_path_v3 = OUTPUT_DIR / 'pose_data_side.npz'

side_dataset_v3, side_stats_v3, side_failed_v3 = extract_raw_pose_landmarks(
    clips_path=str(CLIPS_PATH),
    view='side',
    T_fixed=T_FIXED,
    output_path=str(side_output_path_v3),
    version_tag=VERSION_EXTENDED
)

print("\n" + "="*60)
print("SIDE VIEW SUMMARY (Phase 2)")
print("="*60)
print(f"Total reps extracted: {side_stats_v3['total_reps']}")
print(f"Unique subjects: {side_stats_v3['unique_subjects']}")
print(f"Unique exercises: {side_stats_v3['unique_exercises']}")
print(f"\n📐 Base Feature shapes:")
print(f"  Raw landmarks: {side_stats_v3['landmarks_shape']}")
print(f"  Angles:        {side_stats_v3['angles_shape']}")
print(f"  Distances:     {side_stats_v3['distances_shape']}")
print(f"  All features:  {side_stats_v3['all_features_shape']}")

if 'specialized_shape' in side_stats_v3:
    print(f"\n📐 Specialized Feature shapes (Phase 2):")
    print(f"  Specialized:  {side_stats_v3['specialized_shape']}")
    print(f"\n✅ Phase 2 specialized features successfully computed!")
else:
    print(f"\n⚠️ Specialized features not available")

# %%
# Verify Phase 2 NPZ files
print("Verifying Phase 2 NPZ files with specialized features...\n")

for view in ['front', 'side']:
    stats = front_stats_v3 if view == 'front' else side_stats_v3
    
    output_file = stats.get('output_file')
    if output_file and os.path.exists(output_file):
        print(f"\n{'='*60}")
        print(f"{view.upper()} VIEW - PHASE 2 SPECIALIZED FEATURES")
        print(f"{'='*60}")
        data = np.load(output_file, allow_pickle=True)
        print(f"  File: {os.path.basename(output_file)}")
        print(f"  Keys: {list(data.keys())}")
        
        print(f"\n  📊 Base Feature Arrays:")
        print(f"    X_landmarks:    {data['X_landmarks'].shape}")
        print(f"    X_all_features: {data['X_all_features'].shape}")
        
        if 'X_specialized' in data:
            print(f"\n  📊 Specialized Feature Arrays (Phase 2):")
            print(f"    X_specialized:  {data['X_specialized'].shape}")
            
            print(f"\n  📐 Feature Names:")
            print(f"    specialized ({len(data['specialized_feature_names'])}): {list(data['specialized_feature_names'])[:5]}...")
        else:
            print(f"\n  ⚠️ Specialized features not found in file")

print("\n✅ Phase 2 NPZ verification complete!")
